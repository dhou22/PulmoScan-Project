# %%
import os
import pandas as pd
import numpy as np

# %%
# !pip install xlrd

# %% [markdown]
# ## Putting All Together

# %% [markdown]
# ### Join all dataframes from the features extraction notebooks in a single one called data_std_limit

# %%
import pandas as pd

# Path to the Excel file
file_path = 'C:/Users/user/Desktop/PI_project/tcia-diagnosis-data-2012-04-20.xls'

# Read the Excel file
diagnosis_data = pd.read_excel(file_path)

# Display the loaded data
diagnosis_data
# Out:
#     TCIA Patient ID  \
# 0    LIDC-IDRI-0068
# 1    LIDC-IDRI-0071
# 2    LIDC-IDRI-0072
# 3    LIDC-IDRI-0088
# 4    LIDC-IDRI-0090
# ..              ...
# 152  LIDC-IDRI-0994
# 153  LIDC-IDRI-1002
# 154  LIDC-IDRI-1004
# 155  LIDC-IDRI-1010
# 156  LIDC-IDRI-1011
#
#      Diagnosis at the Patient Level\n0=Unknown\n1=benign or non-malignant disease\n2= malignant, primary lung cancer\n3 = malignant metastatic\n  \
# 0                                                    3
# 1                                                    3
# 2                                                    2
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 152                                                  2
# 153                                                  2
# 154                                                  2
# 155                                                  0
# ...

# %% [markdown]
# #### std_limit = 0.5

# %%
# %cd "C:\Users\user\Desktop\PI_project\std_limit_0.5"
# Out:
# C:\Users\user\Desktop\PI_project\std_limit_0.5

# %%
features_radiomics_05 = pd.read_csv(r'C:\Users\user\Desktop\PI_project\std_limit_0.5\features_radiomics_2d_0.5.csv')
features_xml_05 = pd.read_csv(r'C:\Users\user\Desktop\PI_project\features_pylidc_0.5.csv')

# %%
data = pd.merge(features_xml_05, features_radiomics_05, on='Nodule_id', how='inner')
data_05 = data.merge(diagnosis_data, left_on=data.iloc[:, 1], right_on='TCIA Patient ID', how='left')
data_05.to_csv('C:/Users/user/Desktop/PI_project/data_0.5.csv', index=False)
data_05
# Out:
#      Nodule_id      Patient_id  Subtlety  Internalstructure  Calcification  \
# 0            3  LIDC-IDRI-0003         1                  1              6
# 1           10  LIDC-IDRI-0005         3                  1              6
# 2           11  LIDC-IDRI-0006         3                  1              6
# 3           13  LIDC-IDRI-0006         1                  1              6
# 4           16  LIDC-IDRI-0007         4                  1              6
# ..         ...             ...       ...                ...            ...
# 961       2642  LIDC-IDRI-1008         5                  1              3
# 962       2644  LIDC-IDRI-1008         3                  1              6
# 963       2645  LIDC-IDRI-1009         3                  1              6
# 964       2646  LIDC-IDRI-1010         3                  1              6
# 965       2650  LIDC-IDRI-1011         1                  1              6
#
#      Sphericity  Margin  Lobulation  Spiculation  Texture  ...  \
# ...

# %% [markdown]
# #### std_limit = 1.0

# %%
# %cd "C:\Users\user\Desktop\PI_project\std_limit_1.0"
# Out:
# C:\Users\user\Desktop\PI_project\std_limit_1.0

# %%
features_radiomics_10 = pd.read_csv(r'C:\Users\user\Desktop\PI_project\std_limit_1.0\features_radiomics_2d_1.0.csv')
features_xml_10 = pd.read_csv(r'C:\Users\user\Desktop\PI_project\features_pylidc_1.0.csv')

# %%
data = pd.merge(features_xml_10, features_radiomics_10, on='Nodule_id', how='inner')
data_10 = data.merge(diagnosis_data, left_on=data.iloc[:, 1], right_on='TCIA Patient ID', how='left')
data_10.to_csv('C:/Users/user/Desktop/PI_project/data_1.0.csv', index=False)
data_10
# Out:
#       Nodule_id      Patient_id  Subtlety  Internalstructure  Calcification  \
# 0             2  LIDC-IDRI-0002         2                  1              6
# 1             3  LIDC-IDRI-0003         1                  1              6
# 2             9  LIDC-IDRI-0005         4                  1              6
# 3            10  LIDC-IDRI-0005         3                  1              6
# 4            11  LIDC-IDRI-0006         3                  1              6
# ...         ...             ...       ...                ...            ...
# 1651       2642  LIDC-IDRI-1008         5                  1              3
# 1652       2644  LIDC-IDRI-1008         3                  1              6
# 1653       2645  LIDC-IDRI-1009         3                  1              6
# 1654       2646  LIDC-IDRI-1010         3                  1              6
# 1655       2650  LIDC-IDRI-1011         1                  1              6
#
# ...

# %% [markdown]
# #### std_limit = 1.5

# %%
# %cd "C:\Users\user\Desktop\PI_project\std_limit_1.5"
# Out:
# C:\Users\user\Desktop\PI_project\std_limit_1.5

# %%
features_radiomics_15 = pd.read_csv(r'C:\Users\user\Desktop\PI_project\std_limit_1.5\features_radiomics_2d_1.5.csv')
features_xml_15 = pd.read_csv(r'C:\Users\user\Desktop\PI_project\features_pylidc_1.5.csv')

# %%
data = pd.merge(features_xml_15, features_radiomics_15, on='Nodule_id', how='inner')
data_15 = data.merge(diagnosis_data, left_on=data.iloc[:, 1], right_on='TCIA Patient ID', how='left')
data_15.to_csv('C:/Users/user/Desktop/PI_project/data_1.5.csv', index=False)
data_15
# Out:
#       Nodule_id      Patient_id  Subtlety  Internalstructure  Calcification  \
# 0             1  LIDC-IDRI-0001         5                  1              6
# 1             2  LIDC-IDRI-0002         2                  1              6
# 2             3  LIDC-IDRI-0003         1                  1              6
# 3             4  LIDC-IDRI-0003         5                  1              6
# 4             5  LIDC-IDRI-0003         4                  1              6
# ...         ...             ...       ...                ...            ...
# 2435       2645  LIDC-IDRI-1009         3                  1              6
# 2436       2646  LIDC-IDRI-1010         3                  1              6
# 2437       2648  LIDC-IDRI-1011         5                  1              6
# 2438       2649  LIDC-IDRI-1011         3                  1              6
# 2439       2650  LIDC-IDRI-1011         1                  1              6
#
# ...
