# %% [markdown]
# # XML Feature Extraction - 2D and 3D

# %% [markdown]
# #### Environment with numpy==1.20.3 e pylidc==0.2.2 (new_env kernel)

# %%
import os
import six
import pickle
import pandas as pd
import SimpleITK as sitk
from functools import reduce
import numpy as np
from scipy.stats import mode
from skimage.measure import find_contours
from skimage import io
import pydicom
import pylidc as pl
from pylidc.utils import consensus
import matplotlib.pyplot as plt

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\user\anaconda3\envs\new_env\python.exe

# %% [markdown]
# #### std_limit = 0.5

# %%
import os
import six
import pickle
import pandas as pd
import SimpleITK as sitk
from functools import reduce
import numpy as np
from scipy.stats import mode
from skimage.measure import find_contours
from skimage import io
import pydicom
import pylidc as pl
from pylidc.utils import consensus
import matplotlib.pyplot as plt

# %%
import os
import numpy as np
import pandas as pd
import pylidc as pl
from pylidc.utils import consensus

# Paths
input_directory = "C:/Users/user/Desktop/PI_project/images/LIDC-IDRI"
params_file = "C:/Users/user/Desktop/PI_project/radiomics_config/Params.yaml"
path = "C:/Users/user/Desktop/PI_project/std_limit_0.5"
external_drive_path = "C:/Users/user/Desktop/PI_project"  # Path to save CSV

# ✅ Ensure output folder exists
os.makedirs(path, exist_ok=True)

# Initialize patient folders
patient_folders = sorted(os.listdir(input_directory))
nodule_id = 0

# Dictionary to collect nodule data
nodule_data = {
    'Nodule_id': [],
    'Patient_id': [],
    'Subtlety': [],
    'Internalstructure': [],
    'Calcification': [],
    'Sphericity': [],
    'Margin': [],
    'Lobulation': [],
    'Spiculation': [],
    'Texture': [],
    'Malignancy': []
}

malignancy_names = {
    1: "1-Highly Unlikely",
    2: "2-Moderately Unlikely",
    3: "3-Indeterminate",
    4: "4-Moderately Suspicious",
    5: "5-Highly Suspicious"
}

std_limit = 0.5

# Process each patient
for patient_folder in patient_folders:
    patient_folder_path = os.path.join(input_directory, patient_folder)
    patient_id = os.path.basename(patient_folder_path)
    print(f"Processing patient: {patient_id}")
    
    patient_scans = pl.query(pl.Scan).filter(pl.Scan.patient_id == patient_id, pl.Scan.annotations.any()).all()
    
    for scan in patient_scans:
        nods = scan.cluster_annotations()
        
        for anns in nods:
            nodule_id += 1
            nodule_characteristics = []

            # 50% consensus mask
            cmask, cbbox, masks = consensus(anns, clevel=0.5, pad=[(20, 20), (20, 20), (0, 0)])

            for i, mask in enumerate(masks):
                characteristics = anns[i].feature_vals()
                nodule_characteristics.append(characteristics)

            if nodule_characteristics:
                std_deviations = [np.std(characteristic) for characteristic in zip(*nodule_characteristics)]
                
                # Skip if any feature has std > limit
                if any(std > std_limit for std in std_deviations):
                    print(f"Skipped Nodule ID {nodule_id} due to high std.")
                    continue

                # ✅ Save cmask
                filename = os.path.join(path, f"{nodule_id}_cmask.npy")
                np.save(filename, cmask)

                # Optional volume save — uncomment if needed and storage allows
                # volume = anns[0].scan.to_volume()
                # filename = os.path.join(path, f"{nodule_id}_volume.npy")
                # np.save(filename, volume)

                # Extract characteristics (from first annotation)
                feature_values = {
                    'Nodule_id': nodule_id,
                    'Patient_id': patient_id,
                    'Subtlety': nodule_characteristics[0][0],
                    'Internalstructure': nodule_characteristics[0][1],
                    'Calcification': nodule_characteristics[0][2],
                    'Sphericity': nodule_characteristics[0][3],
                    'Margin': nodule_characteristics[0][4],
                    'Lobulation': nodule_characteristics[0][5],
                    'Spiculation': nodule_characteristics[0][6],
                    'Texture': nodule_characteristics[0][7],
                    'Malignancy': malignancy_names.get(nodule_characteristics[0][8])
                }

                for key, value in feature_values.items():
                    nodule_data[key].append(value)

# Save features to CSV
features = pd.DataFrame(nodule_data)
csv_filename = os.path.join(external_drive_path, 'features_pylidc_0.5.csv')
features.to_csv(csv_filename, index=False)

print("✅ Feature extraction complete and CSV saved.")
# Out:
# Processing patient: LICENSE
# Processing patient: LIDC-IDRI-0001
# Skipped Nodule ID 1 due to high std.
# Processing patient: LIDC-IDRI-0002
# Skipped Nodule ID 2 due to high std.
# Processing patient: LIDC-IDRI-0003
# Skipped Nodule ID 4 due to high std.
# Skipped Nodule ID 5 due to high std.
# Skipped Nodule ID 6 due to high std.
# Processing patient: LIDC-IDRI-0004
# Skipped Nodule ID 7 due to high std.
# Processing patient: LIDC-IDRI-0005
# Skipped Nodule ID 8 due to high std.
# Skipped Nodule ID 9 due to high std.
# Processing patient: LIDC-IDRI-0006
# Skipped Nodule ID 12 due to high std.
# Skipped Nodule ID 14 due to high std.
# Processing patient: LIDC-IDRI-0007
# Skipped Nodule ID 15 due to high std.
# Processing patient: LIDC-IDRI-0008
# Skipped Nodule ID 17 due to high std.
# Skipped Nodule ID 18 due to high std.
# Processing patient: LIDC-IDRI-0009
# Processing patient: LIDC-IDRI-0010
# Skipped Nodule ID 22 due to high std.
# Skipped Nodule ID 23 due to high std.
# Processing patient: LIDC-IDRI-0011
# Skipped Nodule ID 24 due to high std.
# Skipped Nodule ID 25 due to high std.
# Skipped Nodule ID 29 due to high std.
# Skipped Nodule ID 33 due to high std.
# Processing patient: LIDC-IDRI-0012
# Skipped Nodule ID 35 due to high std.
# Skipped Nodule ID 36 due to high std.
# Skipped Nodule ID 37 due to high std.
# Skipped Nodule ID 39 due to high std.
# Skipped Nodule ID 40 due to high std.
# Skipped Nodule ID 42 due to high std.
# Skipped Nodule ID 43 due to high std.
# Skipped Nodule ID 44 due to high std.
# Processing patient: LIDC-IDRI-0013
# Skipped Nodule ID 46 due to high std.
# Skipped Nodule ID 47 due to high std.
# Skipped Nodule ID 48 due to high std.
# Processing patient: LIDC-IDRI-0014
# Skipped Nodule ID 49 due to high std.
# Processing patient: LIDC-IDRI-0015
# Skipped Nodule ID 50 due to high std.
# Processing patient: LIDC-IDRI-0016
# Skipped Nodule ID 51 due to high std.
# Skipped Nodule ID 52 due to high std.
# Skipped Nodule ID 54 due to high std.
# Skipped Nodule ID 55 due to high std.
# Skipped Nodule ID 56 due to high std.
# Processing patient: LIDC-IDRI-0017
# Skipped Nodule ID 57 due to high std.
# Processing patient: LIDC-IDRI-0018
# Skipped Nodule ID 59 due to high std.
# Skipped Nodule ID 60 due to high std.
# Skipped Nodule ID 61 due to high std.
# Processing patient: LIDC-IDRI-0019
# Skipped Nodule ID 62 due to high std.
# Processing patient: LIDC-IDRI-0020
# Skipped Nodule ID 64 due to high std.
# Processing patient: LIDC-IDRI-0021
# Skipped Nodule ID 67 due to high std.
# Processing patient: LIDC-IDRI-0022
# Processing patient: LIDC-IDRI-0023
# Skipped Nodule ID 69 due to high std.
# Processing patient: LIDC-IDRI-0024
# Skipped Nodule ID 70 due to high std.
# Skipped Nodule ID 71 due to high std.
# Skipped Nodule ID 72 due to high std.
# Skipped Nodule ID 73 due to high std.
# Processing patient: LIDC-IDRI-0025
# Processing patient: LIDC-IDRI-0026
# Processing patient: LIDC-IDRI-0027
# Skipped Nodule ID 77 due to high std.
# Skipped Nodule ID 79 due to high std.
# Skipped Nodule ID 80 due to high std.
# Skipped Nodule ID 81 due to high std.
# Skipped Nodule ID 82 due to high std.
# Processing patient: LIDC-IDRI-0029
# Processing patient: LIDC-IDRI-0030
# Skipped Nodule ID 85 due to high std.
# Skipped Nodule ID 86 due to high std.
# Processing patient: LIDC-IDRI-0031
# Skipped Nodule ID 89 due to high std.
# Skipped Nodule ID 90 due to high std.
# Skipped Nodule ID 91 due to high std.
# Processing patient: LIDC-IDRI-0033
# Skipped Nodule ID 92 due to high std.
# Processing patient: LIDC-IDRI-0034
# Skipped Nodule ID 94 due to high std.
# Processing patient: LIDC-IDRI-0035
# Skipped Nodule ID 95 due to high std.
# Processing patient: LIDC-IDRI-0036
# Skipped Nodule ID 97 due to high std.
# Processing patient: LIDC-IDRI-0037
# Skipped Nodule ID 98 due to high std.
# Skipped Nodule ID 99 due to high std.
# Processing patient: LIDC-IDRI-0038
# Processing patient: LIDC-IDRI-0039
# Skipped Nodule ID 101 due to high std.
# Skipped Nodule ID 102 due to high std.
# Skipped Nodule ID 103 due to high std.
# Skipped Nodule ID 104 due to high std.
# Processing patient: LIDC-IDRI-0040
# Skipped Nodule ID 107 due to high std.
# Processing patient: LIDC-IDRI-0041
# Skipped Nodule ID 110 due to high std.
# Skipped Nodule ID 112 due to high std.
# Processing patient: LIDC-IDRI-0042
# Skipped Nodule ID 113 due to high std.
# Skipped Nodule ID 114 due to high std.
# Skipped Nodule ID 115 due to high std.
# Skipped Nodule ID 116 due to high std.
# Skipped Nodule ID 120 due to high std.
# Skipped Nodule ID 121 due to high std.
# Skipped Nodule ID 122 due to high std.
# Processing patient: LIDC-IDRI-0043
# Skipped Nodule ID 123 due to high std.
# Skipped Nodule ID 124 due to high std.
# Skipped Nodule ID 125 due to high std.
# Processing patient: LIDC-IDRI-0044
# Skipped Nodule ID 127 due to high std.
# Skipped Nodule ID 128 due to high std.
# Skipped Nodule ID 129 due to high std.
# Processing patient: LIDC-IDRI-0045
# Skipped Nodule ID 130 due to high std.
# Skipped Nodule ID 132 due to high std.
# Skipped Nodule ID 133 due to high std.
# Skipped Nodule ID 134 due to high std.
# Skipped Nodule ID 135 due to high std.
# Skipped Nodule ID 139 due to high std.
# Skipped Nodule ID 140 due to high std.
# Skipped Nodule ID 141 due to high std.
# Processing patient: LIDC-IDRI-0046
# Skipped Nodule ID 143 due to high std.
# Skipped Nodule ID 144 due to high std.
# Skipped Nodule ID 145 due to high std.
# Skipped Nodule ID 146 due to high std.
# Skipped Nodule ID 147 due to high std.
# Skipped Nodule ID 148 due to high std.
# Processing patient: LIDC-IDRI-0047
# Skipped Nodule ID 149 due to high std.
# Processing patient: LIDC-IDRI-0048
# Skipped Nodule ID 150 due to high std.
# Skipped Nodule ID 151 due to high std.
# Skipped Nodule ID 152 due to high std.
# Processing patient: LIDC-IDRI-0049
# Skipped Nodule ID 154 due to high std.
# Skipped Nodule ID 155 due to high std.
# Skipped Nodule ID 158 due to high std.
# Skipped Nodule ID 160 due to high std.
# Skipped Nodule ID 161 due to high std.
# Skipped Nodule ID 162 due to high std.
# Skipped Nodule ID 163 due to high std.
# Skipped Nodule ID 164 due to high std.
# Skipped Nodule ID 165 due to high std.
# Skipped Nodule ID 167 due to high std.
# Processing patient: LIDC-IDRI-0050
# Skipped Nodule ID 168 due to high std.
# Processing patient: LIDC-IDRI-0051
# Skipped Nodule ID 170 due to high std.
# Skipped Nodule ID 171 due to high std.
# Processing patient: LIDC-IDRI-0052
# Skipped Nodule ID 172 due to high std.
# Skipped Nodule ID 173 due to high std.
# Processing patient: LIDC-IDRI-0053
# Skipped Nodule ID 174 due to high std.
# Skipped Nodule ID 175 due to high std.
# Processing patient: LIDC-IDRI-0054
# Skipped Nodule ID 176 due to high std.
# Processing patient: LIDC-IDRI-0055
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 177 due to high std.
# Skipped Nodule ID 178 due to high std.
# Skipped Nodule ID 181 due to high std.
# Skipped Nodule ID 183 due to high std.
# Processing patient: LIDC-IDRI-0056
# Skipped Nodule ID 184 due to high std.
# Skipped Nodule ID 185 due to high std.
# Skipped Nodule ID 186 due to high std.
# Processing patient: LIDC-IDRI-0057
# Skipped Nodule ID 187 due to high std.
# Processing patient: LIDC-IDRI-0058
# Skipped Nodule ID 188 due to high std.
# Skipped Nodule ID 189 due to high std.
# Skipped Nodule ID 190 due to high std.
# Processing patient: LIDC-IDRI-0059
# Skipped Nodule ID 191 due to high std.
# Processing patient: LIDC-IDRI-0060
# Skipped Nodule ID 192 due to high std.
# Skipped Nodule ID 195 due to high std.
# Skipped Nodule ID 197 due to high std.
# Processing patient: LIDC-IDRI-0061
# Skipped Nodule ID 198 due to high std.
# Skipped Nodule ID 200 due to high std.
# Skipped Nodule ID 201 due to high std.
# Skipped Nodule ID 202 due to high std.
# Skipped Nodule ID 203 due to high std.
# Processing patient: LIDC-IDRI-0063
# Skipped Nodule ID 205 due to high std.
# Processing patient: LIDC-IDRI-0064
# Skipped Nodule ID 208 due to high std.
# Skipped Nodule ID 209 due to high std.
# Processing patient: LIDC-IDRI-0065
# Processing patient: LIDC-IDRI-0066
# Skipped Nodule ID 211 due to high std.
# Skipped Nodule ID 212 due to high std.
# Skipped Nodule ID 213 due to high std.
# Processing patient: LIDC-IDRI-0067
# Skipped Nodule ID 214 due to high std.
# Skipped Nodule ID 215 due to high std.
# Skipped Nodule ID 216 due to high std.
# Skipped Nodule ID 217 due to high std.
# Processing patient: LIDC-IDRI-0068
# Skipped Nodule ID 218 due to high std.
# Skipped Nodule ID 219 due to high std.
# Skipped Nodule ID 220 due to high std.
# Skipped Nodule ID 222 due to high std.
# Skipped Nodule ID 223 due to high std.
# Processing patient: LIDC-IDRI-0069
# Skipped Nodule ID 224 due to high std.
# Skipped Nodule ID 226 due to high std.
# Processing patient: LIDC-IDRI-0070
# Skipped Nodule ID 227 due to high std.
# Skipped Nodule ID 228 due to high std.
# Processing patient: LIDC-IDRI-0072
# Skipped Nodule ID 230 due to high std.
# Processing patient: LIDC-IDRI-0073
# Skipped Nodule ID 232 due to high std.
# Skipped Nodule ID 233 due to high std.
# Processing patient: LIDC-IDRI-0074
# Skipped Nodule ID 234 due to high std.
# Processing patient: LIDC-IDRI-0075
# Skipped Nodule ID 236 due to high std.
# Skipped Nodule ID 238 due to high std.
# Processing patient: LIDC-IDRI-0076
# Skipped Nodule ID 239 due to high std.
# Skipped Nodule ID 240 due to high std.
# Processing patient: LIDC-IDRI-0077
# Skipped Nodule ID 241 due to high std.
# Processing patient: LIDC-IDRI-0078
# Skipped Nodule ID 243 due to high std.
# Skipped Nodule ID 244 due to high std.
# Skipped Nodule ID 246 due to high std.
# Processing patient: LIDC-IDRI-0079
# Skipped Nodule ID 247 due to high std.
# Processing patient: LIDC-IDRI-0080
# Skipped Nodule ID 248 due to high std.
# Skipped Nodule ID 249 due to high std.
# Processing patient: LIDC-IDRI-0081
# Skipped Nodule ID 250 due to high std.
# Skipped Nodule ID 251 due to high std.
# Processing patient: LIDC-IDRI-0082
# Skipped Nodule ID 252 due to high std.
# Processing patient: LIDC-IDRI-0083
# Skipped Nodule ID 253 due to high std.
# Processing patient: LIDC-IDRI-0084
# Skipped Nodule ID 256 due to high std.
# Skipped Nodule ID 257 due to high std.
# Skipped Nodule ID 259 due to high std.
# Skipped Nodule ID 260 due to high std.
# Processing patient: LIDC-IDRI-0085
# Skipped Nodule ID 261 due to high std.
# Processing patient: LIDC-IDRI-0086
# Processing patient: LIDC-IDRI-0087
# Skipped Nodule ID 264 due to high std.
# Processing patient: LIDC-IDRI-0088
# Skipped Nodule ID 266 due to high std.
# Skipped Nodule ID 267 due to high std.
# Skipped Nodule ID 268 due to high std.
# Processing patient: LIDC-IDRI-0089
# Skipped Nodule ID 269 due to high std.
# Processing patient: LIDC-IDRI-0090
# Skipped Nodule ID 270 due to high std.
# Processing patient: LIDC-IDRI-0091
# Skipped Nodule ID 272 due to high std.
# Skipped Nodule ID 273 due to high std.
# Skipped Nodule ID 274 due to high std.
# Skipped Nodule ID 275 due to high std.
# Processing patient: LIDC-IDRI-0092
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 276 due to high std.
# Skipped Nodule ID 277 due to high std.
# Skipped Nodule ID 278 due to high std.
# Skipped Nodule ID 279 due to high std.
# Processing patient: LIDC-IDRI-0093
# Skipped Nodule ID 281 due to high std.
# Processing patient: LIDC-IDRI-0094
# Skipped Nodule ID 282 due to high std.
# Processing patient: LIDC-IDRI-0095
# Skipped Nodule ID 283 due to high std.
# Skipped Nodule ID 285 due to high std.
# Processing patient: LIDC-IDRI-0096
# Skipped Nodule ID 286 due to high std.
# Processing patient: LIDC-IDRI-0097
# Processing patient: LIDC-IDRI-0098
# Skipped Nodule ID 288 due to high std.
# Processing patient: LIDC-IDRI-0099
# Skipped Nodule ID 289 due to high std.
# Skipped Nodule ID 291 due to high std.
# Processing patient: LIDC-IDRI-0101
# Skipped Nodule ID 293 due to high std.
# Processing patient: LIDC-IDRI-0102
# Processing patient: LIDC-IDRI-0103
# Skipped Nodule ID 296 due to high std.
# Processing patient: LIDC-IDRI-0104
# Skipped Nodule ID 298 due to high std.
# Processing patient: LIDC-IDRI-0105
# Processing patient: LIDC-IDRI-0106
# Skipped Nodule ID 302 due to high std.
# Skipped Nodule ID 304 due to high std.
# Processing patient: LIDC-IDRI-0107
# Skipped Nodule ID 309 due to high std.
# Processing patient: LIDC-IDRI-0108
# Skipped Nodule ID 310 due to high std.
# Skipped Nodule ID 311 due to high std.
# Processing patient: LIDC-IDRI-0109
# Skipped Nodule ID 312 due to high std.
# Processing patient: LIDC-IDRI-0110
# Skipped Nodule ID 313 due to high std.
# Skipped Nodule ID 314 due to high std.
# Processing patient: LIDC-IDRI-0111
# Skipped Nodule ID 315 due to high std.
# Skipped Nodule ID 316 due to high std.
# Skipped Nodule ID 317 due to high std.
# Skipped Nodule ID 318 due to high std.
# Processing patient: LIDC-IDRI-0112
# Skipped Nodule ID 321 due to high std.
# Processing patient: LIDC-IDRI-0113
# Skipped Nodule ID 322 due to high std.
# Processing patient: LIDC-IDRI-0114
# Skipped Nodule ID 323 due to high std.
# Processing patient: LIDC-IDRI-0115
# Skipped Nodule ID 324 due to high std.
# Processing patient: LIDC-IDRI-0116
# Skipped Nodule ID 326 due to high std.
# Processing patient: LIDC-IDRI-0117
# Skipped Nodule ID 327 due to high std.
# Processing patient: LIDC-IDRI-0118
# Skipped Nodule ID 328 due to high std.
# Skipped Nodule ID 331 due to high std.
# Skipped Nodule ID 333 due to high std.
# Processing patient: LIDC-IDRI-0119
# Skipped Nodule ID 334 due to high std.
# Skipped Nodule ID 335 due to high std.
# Processing patient: LIDC-IDRI-0120
# Skipped Nodule ID 336 due to high std.
# Skipped Nodule ID 337 due to high std.
# Skipped Nodule ID 338 due to high std.
# Skipped Nodule ID 339 due to high std.
# Processing patient: LIDC-IDRI-0121
# Skipped Nodule ID 340 due to high std.
# Skipped Nodule ID 341 due to high std.
# Processing patient: LIDC-IDRI-0122
# Skipped Nodule ID 342 due to high std.
# Processing patient: LIDC-IDRI-0123
# Processing patient: LIDC-IDRI-0124
# Skipped Nodule ID 345 due to high std.
# Skipped Nodule ID 348 due to high std.
# Skipped Nodule ID 349 due to high std.
# Skipped Nodule ID 356 due to high std.
# Skipped Nodule ID 357 due to high std.
# Skipped Nodule ID 358 due to high std.
# Processing patient: LIDC-IDRI-0125
# Skipped Nodule ID 360 due to high std.
# Processing patient: LIDC-IDRI-0126
# Skipped Nodule ID 362 due to high std.
# Skipped Nodule ID 363 due to high std.
# Processing patient: LIDC-IDRI-0127
# Skipped Nodule ID 364 due to high std.
# Processing patient: LIDC-IDRI-0128
# Skipped Nodule ID 367 due to high std.
# Processing patient: LIDC-IDRI-0129
# Skipped Nodule ID 368 due to high std.
# Skipped Nodule ID 369 due to high std.
# Skipped Nodule ID 371 due to high std.
# Skipped Nodule ID 372 due to high std.
# Skipped Nodule ID 374 due to high std.
# Skipped Nodule ID 375 due to high std.
# Skipped Nodule ID 376 due to high std.
# Skipped Nodule ID 377 due to high std.
# Skipped Nodule ID 378 due to high std.
# Skipped Nodule ID 379 due to high std.
# Skipped Nodule ID 380 due to high std.
# Skipped Nodule ID 381 due to high std.
# Skipped Nodule ID 382 due to high std.
# Processing patient: LIDC-IDRI-0130
# Skipped Nodule ID 383 due to high std.
# Skipped Nodule ID 384 due to high std.
# Processing patient: LIDC-IDRI-0131
# Skipped Nodule ID 386 due to high std.
# Processing patient: LIDC-IDRI-0132
# Skipped Nodule ID 387 due to high std.
# Skipped Nodule ID 388 due to high std.
# Skipped Nodule ID 390 due to high std.
# Skipped Nodule ID 394 due to high std.
# Skipped Nodule ID 396 due to high std.
# Skipped Nodule ID 397 due to high std.
# Skipped Nodule ID 399 due to high std.
# Skipped Nodule ID 400 due to high std.
# Processing patient: LIDC-IDRI-0133
# Skipped Nodule ID 402 due to high std.
# Processing patient: LIDC-IDRI-0134
# Skipped Nodule ID 403 due to high std.
# Skipped Nodule ID 404 due to high std.
# Processing patient: LIDC-IDRI-0135
# Skipped Nodule ID 406 due to high std.
# Skipped Nodule ID 407 due to high std.
# Skipped Nodule ID 408 due to high std.
# Skipped Nodule ID 409 due to high std.
# Skipped Nodule ID 410 due to high std.
# Skipped Nodule ID 411 due to high std.
# Processing patient: LIDC-IDRI-0136
# Skipped Nodule ID 412 due to high std.
# Skipped Nodule ID 413 due to high std.
# Skipped Nodule ID 414 due to high std.
# Skipped Nodule ID 415 due to high std.
# Skipped Nodule ID 417 due to high std.
# Skipped Nodule ID 418 due to high std.
# Skipped Nodule ID 419 due to high std.
# Skipped Nodule ID 420 due to high std.
# Processing patient: LIDC-IDRI-0137
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 422 due to high std.
# Skipped Nodule ID 423 due to high std.
# Processing patient: LIDC-IDRI-0138
# Processing patient: LIDC-IDRI-0139
# Skipped Nodule ID 425 due to high std.
# Skipped Nodule ID 426 due to high std.
# Skipped Nodule ID 427 due to high std.
# Processing patient: LIDC-IDRI-0140
# Skipped Nodule ID 429 due to high std.
# Processing patient: LIDC-IDRI-0141
# Skipped Nodule ID 430 due to high std.
# Skipped Nodule ID 431 due to high std.
# Skipped Nodule ID 433 due to high std.
# Skipped Nodule ID 434 due to high std.
# Processing patient: LIDC-IDRI-0142
# Skipped Nodule ID 435 due to high std.
# Skipped Nodule ID 436 due to high std.
# Skipped Nodule ID 437 due to high std.
# Processing patient: LIDC-IDRI-0144
# Skipped Nodule ID 439 due to high std.
# Skipped Nodule ID 440 due to high std.
# Skipped Nodule ID 442 due to high std.
# Skipped Nodule ID 443 due to high std.
# Processing patient: LIDC-IDRI-0145
# Skipped Nodule ID 445 due to high std.
# Processing patient: LIDC-IDRI-0146
# Skipped Nodule ID 447 due to high std.
# Processing patient: LIDC-IDRI-0147
# Skipped Nodule ID 448 due to high std.
# Skipped Nodule ID 450 due to high std.
# Skipped Nodule ID 452 due to high std.
# Skipped Nodule ID 454 due to high std.
# Processing patient: LIDC-IDRI-0148
# Skipped Nodule ID 456 due to high std.
# Skipped Nodule ID 457 due to high std.
# Processing patient: LIDC-IDRI-0149
# Skipped Nodule ID 459 due to high std.
# Skipped Nodule ID 462 due to high std.
# Processing patient: LIDC-IDRI-0150
# Skipped Nodule ID 466 due to high std.
# Skipped Nodule ID 467 due to high std.
# Processing patient: LIDC-IDRI-0151
# Skipped Nodule ID 468 due to high std.
# Skipped Nodule ID 469 due to high std.
# Processing patient: LIDC-IDRI-0152
# Skipped Nodule ID 470 due to high std.
# Processing patient: LIDC-IDRI-0153
# Skipped Nodule ID 471 due to high std.
# Skipped Nodule ID 472 due to high std.
# Processing patient: LIDC-IDRI-0154
# Skipped Nodule ID 474 due to high std.
# Processing patient: LIDC-IDRI-0155
# Skipped Nodule ID 475 due to high std.
# Processing patient: LIDC-IDRI-0156
# Skipped Nodule ID 476 due to high std.
# Processing patient: LIDC-IDRI-0157
# Skipped Nodule ID 477 due to high std.
# Processing patient: LIDC-IDRI-0158
# Skipped Nodule ID 479 due to high std.
# Skipped Nodule ID 480 due to high std.
# Skipped Nodule ID 481 due to high std.
# Processing patient: LIDC-IDRI-0159
# Skipped Nodule ID 482 due to high std.
# Skipped Nodule ID 483 due to high std.
# Processing patient: LIDC-IDRI-0160
# Skipped Nodule ID 484 due to high std.
# Skipped Nodule ID 485 due to high std.
# Skipped Nodule ID 486 due to high std.
# Skipped Nodule ID 487 due to high std.
# Processing patient: LIDC-IDRI-0161
# Skipped Nodule ID 488 due to high std.
# Skipped Nodule ID 489 due to high std.
# Skipped Nodule ID 490 due to high std.
# Processing patient: LIDC-IDRI-0162
# Skipped Nodule ID 493 due to high std.
# Processing patient: LIDC-IDRI-0163
# Skipped Nodule ID 494 due to high std.
# Processing patient: LIDC-IDRI-0164
# Skipped Nodule ID 495 due to high std.
# Skipped Nodule ID 496 due to high std.
# Skipped Nodule ID 497 due to high std.
# Skipped Nodule ID 498 due to high std.
# Skipped Nodule ID 499 due to high std.
# Skipped Nodule ID 500 due to high std.
# Skipped Nodule ID 501 due to high std.
# Skipped Nodule ID 503 due to high std.
# Skipped Nodule ID 505 due to high std.
# Processing patient: LIDC-IDRI-0165
# Processing patient: LIDC-IDRI-0166
# Processing patient: LIDC-IDRI-0167
# Skipped Nodule ID 509 due to high std.
# Skipped Nodule ID 510 due to high std.
# Processing patient: LIDC-IDRI-0168
# Skipped Nodule ID 511 due to high std.
# Skipped Nodule ID 512 due to high std.
# Processing patient: LIDC-IDRI-0169
# Skipped Nodule ID 513 due to high std.
# Skipped Nodule ID 514 due to high std.
# Skipped Nodule ID 515 due to high std.
# Processing patient: LIDC-IDRI-0170
# Skipped Nodule ID 516 due to high std.
# Skipped Nodule ID 517 due to high std.
# Processing patient: LIDC-IDRI-0171
# Skipped Nodule ID 518 due to high std.
# Skipped Nodule ID 519 due to high std.
# Skipped Nodule ID 520 due to high std.
# Skipped Nodule ID 521 due to high std.
# Processing patient: LIDC-IDRI-0172
# Skipped Nodule ID 524 due to high std.
# Processing patient: LIDC-IDRI-0173
# Processing patient: LIDC-IDRI-0175
# Skipped Nodule ID 526 due to high std.
# Processing patient: LIDC-IDRI-0176
# Skipped Nodule ID 527 due to high std.
# Skipped Nodule ID 529 due to high std.
# Processing patient: LIDC-IDRI-0177
# Skipped Nodule ID 530 due to high std.
# Processing patient: LIDC-IDRI-0178
# Skipped Nodule ID 531 due to high std.
# Processing patient: LIDC-IDRI-0179
# Skipped Nodule ID 532 due to high std.
# Skipped Nodule ID 534 due to high std.
# Skipped Nodule ID 535 due to high std.
# Skipped Nodule ID 540 due to high std.
# Skipped Nodule ID 542 due to high std.
# Processing patient: LIDC-IDRI-0180
# Processing patient: LIDC-IDRI-0181
# Skipped Nodule ID 544 due to high std.
# Skipped Nodule ID 545 due to high std.
# Skipped Nodule ID 546 due to high std.
# Skipped Nodule ID 547 due to high std.
# Skipped Nodule ID 550 due to high std.
# Skipped Nodule ID 551 due to high std.
# Processing patient: LIDC-IDRI-0182
# Skipped Nodule ID 554 due to high std.
# Processing patient: LIDC-IDRI-0183
# Skipped Nodule ID 555 due to high std.
# Skipped Nodule ID 556 due to high std.
# Processing patient: LIDC-IDRI-0184
# Skipped Nodule ID 557 due to high std.
# Processing patient: LIDC-IDRI-0185
# Skipped Nodule ID 558 due to high std.
# Skipped Nodule ID 559 due to high std.
# Skipped Nodule ID 560 due to high std.
# Skipped Nodule ID 561 due to high std.
# Skipped Nodule ID 562 due to high std.
# Skipped Nodule ID 563 due to high std.
# Processing patient: LIDC-IDRI-0186
# Skipped Nodule ID 564 due to high std.
# Skipped Nodule ID 566 due to high std.
# Skipped Nodule ID 568 due to high std.
# Processing patient: LIDC-IDRI-0187
# Skipped Nodule ID 570 due to high std.
# Skipped Nodule ID 572 due to high std.
# Processing patient: LIDC-IDRI-0188
# Skipped Nodule ID 576 due to high std.
# Skipped Nodule ID 577 due to high std.
# Skipped Nodule ID 578 due to high std.
# Skipped Nodule ID 579 due to high std.
# Skipped Nodule ID 580 due to high std.
# Skipped Nodule ID 581 due to high std.
# Processing patient: LIDC-IDRI-0190
# Skipped Nodule ID 583 due to high std.
# Skipped Nodule ID 584 due to high std.
# Processing patient: LIDC-IDRI-0191
# Skipped Nodule ID 585 due to high std.
# Processing patient: LIDC-IDRI-0192
# Skipped Nodule ID 588 due to high std.
# Processing patient: LIDC-IDRI-0193
# Skipped Nodule ID 591 due to high std.
# Processing patient: LIDC-IDRI-0194
# Skipped Nodule ID 592 due to high std.
# Skipped Nodule ID 593 due to high std.
# Skipped Nodule ID 594 due to high std.
# Processing patient: LIDC-IDRI-0195
# Skipped Nodule ID 595 due to high std.
# Skipped Nodule ID 596 due to high std.
# Skipped Nodule ID 597 due to high std.
# Skipped Nodule ID 598 due to high std.
# Skipped Nodule ID 599 due to high std.
# Skipped Nodule ID 600 due to high std.
# Skipped Nodule ID 601 due to high std.
# Processing patient: LIDC-IDRI-0196
# Skipped Nodule ID 602 due to high std.
# Processing patient: LIDC-IDRI-0198
# Skipped Nodule ID 603 due to high std.
# Processing patient: LIDC-IDRI-0199
# Skipped Nodule ID 605 due to high std.
# Skipped Nodule ID 607 due to high std.
# Processing patient: LIDC-IDRI-0200
# Skipped Nodule ID 609 due to high std.
# Processing patient: LIDC-IDRI-0201
# Skipped Nodule ID 611 due to high std.
# Skipped Nodule ID 613 due to high std.
# Processing patient: LIDC-IDRI-0202
# Skipped Nodule ID 618 due to high std.
# Processing patient: LIDC-IDRI-0203
# Skipped Nodule ID 619 due to high std.
# Skipped Nodule ID 620 due to high std.
# Processing patient: LIDC-IDRI-0204
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 621 due to high std.
# Processing patient: LIDC-IDRI-0206
# Skipped Nodule ID 622 due to high std.
# Skipped Nodule ID 623 due to high std.
# Skipped Nodule ID 625 due to high std.
# Processing patient: LIDC-IDRI-0207
# Skipped Nodule ID 626 due to high std.
# Processing patient: LIDC-IDRI-0208
# Skipped Nodule ID 628 due to high std.
# Skipped Nodule ID 629 due to high std.
# Skipped Nodule ID 630 due to high std.
# Processing patient: LIDC-IDRI-0209
# Skipped Nodule ID 631 due to high std.
# Processing patient: LIDC-IDRI-0210
# Skipped Nodule ID 632 due to high std.
# Processing patient: LIDC-IDRI-0211
# Skipped Nodule ID 633 due to high std.
# Processing patient: LIDC-IDRI-0212
# Skipped Nodule ID 635 due to high std.
# Processing patient: LIDC-IDRI-0213
# Skipped Nodule ID 636 due to high std.
# Processing patient: LIDC-IDRI-0215
# Skipped Nodule ID 638 due to high std.
# Skipped Nodule ID 639 due to high std.
# Skipped Nodule ID 640 due to high std.
# Processing patient: LIDC-IDRI-0216
# Skipped Nodule ID 641 due to high std.
# Skipped Nodule ID 642 due to high std.
# Processing patient: LIDC-IDRI-0217
# Skipped Nodule ID 643 due to high std.
# Skipped Nodule ID 644 due to high std.
# Skipped Nodule ID 645 due to high std.
# Processing patient: LIDC-IDRI-0219
# Skipped Nodule ID 646 due to high std.
# Processing patient: LIDC-IDRI-0220
# Skipped Nodule ID 647 due to high std.
# Skipped Nodule ID 648 due to high std.
# Skipped Nodule ID 649 due to high std.
# Processing patient: LIDC-IDRI-0221
# Skipped Nodule ID 650 due to high std.
# Processing patient: LIDC-IDRI-0222
# Skipped Nodule ID 651 due to high std.
# Processing patient: LIDC-IDRI-0223
# Skipped Nodule ID 652 due to high std.
# Skipped Nodule ID 654 due to high std.
# Processing patient: LIDC-IDRI-0227
# Skipped Nodule ID 655 due to high std.
# Processing patient: LIDC-IDRI-0228
# Skipped Nodule ID 656 due to high std.
# Processing patient: LIDC-IDRI-0229
# Skipped Nodule ID 657 due to high std.
# Skipped Nodule ID 658 due to high std.
# Skipped Nodule ID 659 due to high std.
# Skipped Nodule ID 660 due to high std.
# Skipped Nodule ID 662 due to high std.
# Skipped Nodule ID 663 due to high std.
# Processing patient: LIDC-IDRI-0230
# Skipped Nodule ID 664 due to high std.
# Processing patient: LIDC-IDRI-0231
# Processing patient: LIDC-IDRI-0232
# Skipped Nodule ID 669 due to high std.
# Processing patient: LIDC-IDRI-0233
# Skipped Nodule ID 670 due to high std.
# Skipped Nodule ID 671 due to high std.
# Processing patient: LIDC-IDRI-0234
# Skipped Nodule ID 672 due to high std.
# Processing patient: LIDC-IDRI-0235
# Skipped Nodule ID 674 due to high std.
# Processing patient: LIDC-IDRI-0236
# Skipped Nodule ID 676 due to high std.
# Processing patient: LIDC-IDRI-0237
# Skipped Nodule ID 678 due to high std.
# Skipped Nodule ID 679 due to high std.
# Skipped Nodule ID 680 due to high std.
# Processing patient: LIDC-IDRI-0240
# Skipped Nodule ID 681 due to high std.
# Skipped Nodule ID 685 due to high std.
# Processing patient: LIDC-IDRI-0241
# Skipped Nodule ID 686 due to high std.
# Skipped Nodule ID 689 due to high std.
# Skipped Nodule ID 690 due to high std.
# Processing patient: LIDC-IDRI-0242
# Skipped Nodule ID 691 due to high std.
# Processing patient: LIDC-IDRI-0243
# Processing patient: LIDC-IDRI-0244
# Skipped Nodule ID 694 due to high std.
# Skipped Nodule ID 695 due to high std.
# Skipped Nodule ID 696 due to high std.
# Processing patient: LIDC-IDRI-0245
# Skipped Nodule ID 697 due to high std.
# Processing patient: LIDC-IDRI-0246
# Skipped Nodule ID 698 due to high std.
# Processing patient: LIDC-IDRI-0247
# Skipped Nodule ID 699 due to high std.
# Processing patient: LIDC-IDRI-0248
# Skipped Nodule ID 700 due to high std.
# Processing patient: LIDC-IDRI-0249
# Skipped Nodule ID 701 due to high std.
# Skipped Nodule ID 702 due to high std.
# Processing patient: LIDC-IDRI-0250
# Skipped Nodule ID 703 due to high std.
# Skipped Nodule ID 704 due to high std.
# Processing patient: LIDC-IDRI-0251
# Skipped Nodule ID 706 due to high std.
# Processing patient: LIDC-IDRI-0252
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 707 due to high std.
# Processing patient: LIDC-IDRI-0254
# Skipped Nodule ID 708 due to high std.
# Skipped Nodule ID 709 due to high std.
# Skipped Nodule ID 710 due to high std.
# Processing patient: LIDC-IDRI-0255
# Skipped Nodule ID 711 due to high std.
# Skipped Nodule ID 712 due to high std.
# Processing patient: LIDC-IDRI-0256
# Skipped Nodule ID 713 due to high std.
# Processing patient: LIDC-IDRI-0257
# Skipped Nodule ID 715 due to high std.
# Processing patient: LIDC-IDRI-0258
# Skipped Nodule ID 716 due to high std.
# Skipped Nodule ID 717 due to high std.
# Processing patient: LIDC-IDRI-0259
# Skipped Nodule ID 718 due to high std.
# Processing patient: LIDC-IDRI-0260
# Skipped Nodule ID 719 due to high std.
# Skipped Nodule ID 721 due to high std.
# Skipped Nodule ID 722 due to high std.
# Processing patient: LIDC-IDRI-0262
# Skipped Nodule ID 723 due to high std.
# Processing patient: LIDC-IDRI-0263
# Skipped Nodule ID 724 due to high std.
# Processing patient: LIDC-IDRI-0264
# Skipped Nodule ID 725 due to high std.
# Skipped Nodule ID 726 due to high std.
# Processing patient: LIDC-IDRI-0265
# Skipped Nodule ID 727 due to high std.
# Processing patient: LIDC-IDRI-0266
# Skipped Nodule ID 728 due to high std.
# Processing patient: LIDC-IDRI-0267
# Skipped Nodule ID 729 due to high std.
# Processing patient: LIDC-IDRI-0268
# Processing patient: LIDC-IDRI-0269
# Skipped Nodule ID 732 due to high std.
# Processing patient: LIDC-IDRI-0270
# Skipped Nodule ID 733 due to high std.
# Processing patient: LIDC-IDRI-0271
# Skipped Nodule ID 734 due to high std.
# Processing patient: LIDC-IDRI-0272
# Skipped Nodule ID 735 due to high std.
# Processing patient: LIDC-IDRI-0273
# Skipped Nodule ID 736 due to high std.
# Skipped Nodule ID 737 due to high std.
# Processing patient: LIDC-IDRI-0274
# Skipped Nodule ID 738 due to high std.
# Processing patient: LIDC-IDRI-0275
# Processing patient: LIDC-IDRI-0276
# Skipped Nodule ID 740 due to high std.
# Processing patient: LIDC-IDRI-0277
# Skipped Nodule ID 742 due to high std.
# Processing patient: LIDC-IDRI-0278
# Skipped Nodule ID 743 due to high std.
# Skipped Nodule ID 744 due to high std.
# Processing patient: LIDC-IDRI-0280
# Processing patient: LIDC-IDRI-0281
# Skipped Nodule ID 746 due to high std.
# Processing patient: LIDC-IDRI-0282
# Skipped Nodule ID 747 due to high std.
# Processing patient: LIDC-IDRI-0283
# Processing patient: LIDC-IDRI-0284
# Skipped Nodule ID 750 due to high std.
# Skipped Nodule ID 752 due to high std.
# Processing patient: LIDC-IDRI-0285
# Skipped Nodule ID 753 due to high std.
# Skipped Nodule ID 754 due to high std.
# Processing patient: LIDC-IDRI-0286
# Skipped Nodule ID 755 due to high std.
# Processing patient: LIDC-IDRI-0287
# Skipped Nodule ID 757 due to high std.
# Processing patient: LIDC-IDRI-0288
# Skipped Nodule ID 758 due to high std.
# Skipped Nodule ID 759 due to high std.
# Processing patient: LIDC-IDRI-0289
# Skipped Nodule ID 760 due to high std.
# Skipped Nodule ID 761 due to high std.
# Processing patient: LIDC-IDRI-0290
# Processing patient: LIDC-IDRI-0291
# Skipped Nodule ID 766 due to high std.
# Processing patient: LIDC-IDRI-0292
# Skipped Nodule ID 767 due to high std.
# Processing patient: LIDC-IDRI-0294
# Skipped Nodule ID 769 due to high std.
# Processing patient: LIDC-IDRI-0296
# Processing patient: LIDC-IDRI-0297
# Processing patient: LIDC-IDRI-0298
# Skipped Nodule ID 773 due to high std.
# Skipped Nodule ID 774 due to high std.
# Skipped Nodule ID 775 due to high std.
# Skipped Nodule ID 776 due to high std.
# Skipped Nodule ID 777 due to high std.
# Skipped Nodule ID 778 due to high std.
# Skipped Nodule ID 779 due to high std.
# Processing patient: LIDC-IDRI-0299
# Skipped Nodule ID 781 due to high std.
# Skipped Nodule ID 782 due to high std.
# Processing patient: LIDC-IDRI-0300
# Skipped Nodule ID 785 due to high std.
# Skipped Nodule ID 786 due to high std.
# Skipped Nodule ID 787 due to high std.
# Skipped Nodule ID 788 due to high std.
# Processing patient: LIDC-IDRI-0301
# Skipped Nodule ID 789 due to high std.
# Skipped Nodule ID 790 due to high std.
# Processing patient: LIDC-IDRI-0302
# Processing patient: LIDC-IDRI-0303
# Skipped Nodule ID 792 due to high std.
# Processing patient: LIDC-IDRI-0304
# Skipped Nodule ID 793 due to high std.
# Processing patient: LIDC-IDRI-0305
# Skipped Nodule ID 794 due to high std.
# Skipped Nodule ID 795 due to high std.
# Skipped Nodule ID 796 due to high std.
# Skipped Nodule ID 797 due to high std.
# Skipped Nodule ID 799 due to high std.
# Skipped Nodule ID 801 due to high std.
# Processing patient: LIDC-IDRI-0308
# Skipped Nodule ID 803 due to high std.
# Processing patient: LIDC-IDRI-0309
# Skipped Nodule ID 806 due to high std.
# Processing patient: LIDC-IDRI-0310
# Skipped Nodule ID 809 due to high std.
# Processing patient: LIDC-IDRI-0311
# Skipped Nodule ID 810 due to high std.
# Skipped Nodule ID 811 due to high std.
# Processing patient: LIDC-IDRI-0312
# Skipped Nodule ID 815 due to high std.
# Processing patient: LIDC-IDRI-0313
# Skipped Nodule ID 816 due to high std.
# Processing patient: LIDC-IDRI-0314
# Skipped Nodule ID 817 due to high std.
# Processing patient: LIDC-IDRI-0315
# Skipped Nodule ID 821 due to high std.
# Skipped Nodule ID 822 due to high std.
# Skipped Nodule ID 823 due to high std.
# Skipped Nodule ID 824 due to high std.
# Skipped Nodule ID 825 due to high std.
# Skipped Nodule ID 826 due to high std.
# Skipped Nodule ID 827 due to high std.
# Skipped Nodule ID 828 due to high std.
# Skipped Nodule ID 829 due to high std.
# Processing patient: LIDC-IDRI-0317
# Skipped Nodule ID 830 due to high std.
# Processing patient: LIDC-IDRI-0318
# Skipped Nodule ID 831 due to high std.
# Processing patient: LIDC-IDRI-0319
# Skipped Nodule ID 832 due to high std.
# Processing patient: LIDC-IDRI-0320
# Processing patient: LIDC-IDRI-0321
# Skipped Nodule ID 836 due to high std.
# Skipped Nodule ID 837 due to high std.
# Processing patient: LIDC-IDRI-0323
# Skipped Nodule ID 839 due to high std.
# Skipped Nodule ID 840 due to high std.
# Skipped Nodule ID 841 due to high std.
# Processing patient: LIDC-IDRI-0324
# Skipped Nodule ID 843 due to high std.
# Processing patient: LIDC-IDRI-0325
# Skipped Nodule ID 844 due to high std.
# Processing patient: LIDC-IDRI-0326
# Skipped Nodule ID 845 due to high std.
# Skipped Nodule ID 846 due to high std.
# Processing patient: LIDC-IDRI-0328
# Processing patient: LIDC-IDRI-0329
# Skipped Nodule ID 851 due to high std.
# Processing patient: LIDC-IDRI-0332
# Skipped Nodule ID 852 due to high std.
# Skipped Nodule ID 853 due to high std.
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 854 due to high std.
# Skipped Nodule ID 855 due to high std.
# Processing patient: LIDC-IDRI-0334
# Skipped Nodule ID 858 due to high std.
# Skipped Nodule ID 860 due to high std.
# Skipped Nodule ID 863 due to high std.
# Skipped Nodule ID 864 due to high std.
# Skipped Nodule ID 865 due to high std.
# Skipped Nodule ID 866 due to high std.
# Skipped Nodule ID 867 due to high std.
# Processing patient: LIDC-IDRI-0335
# Skipped Nodule ID 868 due to high std.
# Skipped Nodule ID 870 due to high std.
# Skipped Nodule ID 871 due to high std.
# Skipped Nodule ID 872 due to high std.
# Processing patient: LIDC-IDRI-0337
# Skipped Nodule ID 873 due to high std.
# Skipped Nodule ID 874 due to high std.
# Processing patient: LIDC-IDRI-0338
# Skipped Nodule ID 875 due to high std.
# Processing patient: LIDC-IDRI-0339
# Skipped Nodule ID 876 due to high std.
# Processing patient: LIDC-IDRI-0340
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 878 due to high std.
# Processing patient: LIDC-IDRI-0341
# Skipped Nodule ID 880 due to high std.
# Skipped Nodule ID 881 due to high std.
# Skipped Nodule ID 882 due to high std.
# Skipped Nodule ID 883 due to high std.
# Skipped Nodule ID 884 due to high std.
# Processing patient: LIDC-IDRI-0343
# Skipped Nodule ID 885 due to high std.
# Processing patient: LIDC-IDRI-0344
# Skipped Nodule ID 887 due to high std.
# Skipped Nodule ID 889 due to high std.
# Processing patient: LIDC-IDRI-0345
# Skipped Nodule ID 890 due to high std.
# Skipped Nodule ID 891 due to high std.
# Processing patient: LIDC-IDRI-0346
# Skipped Nodule ID 892 due to high std.
# Skipped Nodule ID 893 due to high std.
# Skipped Nodule ID 894 due to high std.
# Skipped Nodule ID 895 due to high std.
# Processing patient: LIDC-IDRI-0347
# Skipped Nodule ID 897 due to high std.
# Skipped Nodule ID 899 due to high std.
# Skipped Nodule ID 900 due to high std.
# Processing patient: LIDC-IDRI-0348
# Skipped Nodule ID 902 due to high std.
# Processing patient: LIDC-IDRI-0350
# Skipped Nodule ID 903 due to high std.
# Processing patient: LIDC-IDRI-0351
# Processing patient: LIDC-IDRI-0352
# Skipped Nodule ID 908 due to high std.
# Processing patient: LIDC-IDRI-0353
# Skipped Nodule ID 909 due to high std.
# Skipped Nodule ID 910 due to high std.
# Skipped Nodule ID 911 due to high std.
# Processing patient: LIDC-IDRI-0354
# Skipped Nodule ID 912 due to high std.
# Processing patient: LIDC-IDRI-0355
# Skipped Nodule ID 916 due to high std.
# Processing patient: LIDC-IDRI-0356
# Skipped Nodule ID 917 due to high std.
# Skipped Nodule ID 918 due to high std.
# Skipped Nodule ID 920 due to high std.
# Skipped Nodule ID 921 due to high std.
# Processing patient: LIDC-IDRI-0357
# Processing patient: LIDC-IDRI-0358
# Skipped Nodule ID 926 due to high std.
# Skipped Nodule ID 930 due to high std.
# Skipped Nodule ID 931 due to high std.
# Skipped Nodule ID 932 due to high std.
# Skipped Nodule ID 933 due to high std.
# Processing patient: LIDC-IDRI-0359
# Skipped Nodule ID 934 due to high std.
# Skipped Nodule ID 935 due to high std.
# Processing patient: LIDC-IDRI-0360
# Skipped Nodule ID 936 due to high std.
# Skipped Nodule ID 937 due to high std.
# Skipped Nodule ID 938 due to high std.
# Skipped Nodule ID 939 due to high std.
# Processing patient: LIDC-IDRI-0362
# Skipped Nodule ID 941 due to high std.
# Processing patient: LIDC-IDRI-0363
# Skipped Nodule ID 942 due to high std.
# Processing patient: LIDC-IDRI-0365
# Skipped Nodule ID 943 due to high std.
# Skipped Nodule ID 944 due to high std.
# Processing patient: LIDC-IDRI-0366
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 945 due to high std.
# Processing patient: LIDC-IDRI-0367
# Processing patient: LIDC-IDRI-0368
# Skipped Nodule ID 948 due to high std.
# Skipped Nodule ID 949 due to high std.
# Skipped Nodule ID 952 due to high std.
# Skipped Nodule ID 953 due to high std.
# Processing patient: LIDC-IDRI-0369
# Skipped Nodule ID 954 due to high std.
# Processing patient: LIDC-IDRI-0370
# Processing patient: LIDC-IDRI-0371
# Skipped Nodule ID 957 due to high std.
# Processing patient: LIDC-IDRI-0372
# Skipped Nodule ID 959 due to high std.
# Processing patient: LIDC-IDRI-0373
# Skipped Nodule ID 960 due to high std.
# Processing patient: LIDC-IDRI-0374
# Skipped Nodule ID 962 due to high std.
# Processing patient: LIDC-IDRI-0375
# Skipped Nodule ID 965 due to high std.
# Processing patient: LIDC-IDRI-0376
# Skipped Nodule ID 966 due to high std.
# Skipped Nodule ID 967 due to high std.
# Processing patient: LIDC-IDRI-0377
# Skipped Nodule ID 968 due to high std.
# Skipped Nodule ID 969 due to high std.
# Processing patient: LIDC-IDRI-0378
# Skipped Nodule ID 971 due to high std.
# Processing patient: LIDC-IDRI-0379
# Skipped Nodule ID 972 due to high std.
# Skipped Nodule ID 974 due to high std.
# Skipped Nodule ID 975 due to high std.
# Skipped Nodule ID 976 due to high std.
# Processing patient: LIDC-IDRI-0380
# Skipped Nodule ID 977 due to high std.
# Skipped Nodule ID 978 due to high std.
# Skipped Nodule ID 979 due to high std.
# Processing patient: LIDC-IDRI-0381
# Skipped Nodule ID 980 due to high std.
# Processing patient: LIDC-IDRI-0384
# Skipped Nodule ID 982 due to high std.
# Processing patient: LIDC-IDRI-0385
# Skipped Nodule ID 984 due to high std.
# Processing patient: LIDC-IDRI-0386
# Skipped Nodule ID 987 due to high std.
# Skipped Nodule ID 989 due to high std.
# Skipped Nodule ID 990 due to high std.
# Processing patient: LIDC-IDRI-0387
# Skipped Nodule ID 992 due to high std.
# Skipped Nodule ID 993 due to high std.
# Processing patient: LIDC-IDRI-0388
# Skipped Nodule ID 994 due to high std.
# Skipped Nodule ID 995 due to high std.
# Processing patient: LIDC-IDRI-0390
# Skipped Nodule ID 999 due to high std.
# Skipped Nodule ID 1000 due to high std.
# Skipped Nodule ID 1001 due to high std.
# Skipped Nodule ID 1003 due to high std.
# Skipped Nodule ID 1004 due to high std.
# Skipped Nodule ID 1005 due to high std.
# Skipped Nodule ID 1006 due to high std.
# Processing patient: LIDC-IDRI-0392
# Skipped Nodule ID 1007 due to high std.
# Skipped Nodule ID 1009 due to high std.
# Processing patient: LIDC-IDRI-0393
# Skipped Nodule ID 1010 due to high std.
# Processing patient: LIDC-IDRI-0394
# Skipped Nodule ID 1012 due to high std.
# Skipped Nodule ID 1013 due to high std.
# Skipped Nodule ID 1014 due to high std.
# Skipped Nodule ID 1015 due to high std.
# Skipped Nodule ID 1016 due to high std.
# Processing patient: LIDC-IDRI-0395
# Skipped Nodule ID 1019 due to high std.
# Skipped Nodule ID 1021 due to high std.
# Skipped Nodule ID 1022 due to high std.
# Processing patient: LIDC-IDRI-0396
# Processing patient: LIDC-IDRI-0397
# Skipped Nodule ID 1027 due to high std.
# Processing patient: LIDC-IDRI-0398
# Skipped Nodule ID 1029 due to high std.
# Skipped Nodule ID 1031 due to high std.
# Skipped Nodule ID 1034 due to high std.
# Skipped Nodule ID 1038 due to high std.
# Skipped Nodule ID 1040 due to high std.
# Processing patient: LIDC-IDRI-0399
# Skipped Nodule ID 1041 due to high std.
# Processing patient: LIDC-IDRI-0400
# Skipped Nodule ID 1043 due to high std.
# Skipped Nodule ID 1044 due to high std.
# Skipped Nodule ID 1045 due to high std.
# Processing patient: LIDC-IDRI-0402
# Skipped Nodule ID 1047 due to high std.
# Skipped Nodule ID 1048 due to high std.
# Skipped Nodule ID 1049 due to high std.
# Skipped Nodule ID 1050 due to high std.
# Skipped Nodule ID 1051 due to high std.
# Skipped Nodule ID 1052 due to high std.
# Skipped Nodule ID 1053 due to high std.
# Skipped Nodule ID 1056 due to high std.
# Processing patient: LIDC-IDRI-0403
# Skipped Nodule ID 1057 due to high std.
# Processing patient: LIDC-IDRI-0404
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 1058 due to high std.
# Skipped Nodule ID 1059 due to high std.
# Skipped Nodule ID 1060 due to high std.
# Skipped Nodule ID 1061 due to high std.
# Skipped Nodule ID 1062 due to high std.
# Skipped Nodule ID 1063 due to high std.
# Processing patient: LIDC-IDRI-0405
# Skipped Nodule ID 1064 due to high std.
# Skipped Nodule ID 1065 due to high std.
# Processing patient: LIDC-IDRI-0406
# Skipped Nodule ID 1069 due to high std.
# Skipped Nodule ID 1070 due to high std.
# Processing patient: LIDC-IDRI-0407
# Skipped Nodule ID 1071 due to high std.
# Skipped Nodule ID 1072 due to high std.
# Skipped Nodule ID 1073 due to high std.
# Processing patient: LIDC-IDRI-0408
# Skipped Nodule ID 1075 due to high std.
# Skipped Nodule ID 1076 due to high std.
# Processing patient: LIDC-IDRI-0409
# Skipped Nodule ID 1078 due to high std.
# Skipped Nodule ID 1079 due to high std.
# Skipped Nodule ID 1081 due to high std.
# Processing patient: LIDC-IDRI-0411
# Skipped Nodule ID 1085 due to high std.
# Skipped Nodule ID 1086 due to high std.
# Processing patient: LIDC-IDRI-0412
# Skipped Nodule ID 1087 due to high std.
# Skipped Nodule ID 1088 due to high std.
# Skipped Nodule ID 1089 due to high std.
# Processing patient: LIDC-IDRI-0413
# Skipped Nodule ID 1090 due to high std.
# Skipped Nodule ID 1091 due to high std.
# Processing patient: LIDC-IDRI-0414
# Skipped Nodule ID 1093 due to high std.
# Processing patient: LIDC-IDRI-0415
# Skipped Nodule ID 1094 due to high std.
# Skipped Nodule ID 1096 due to high std.
# Skipped Nodule ID 1097 due to high std.
# Skipped Nodule ID 1098 due to high std.
# Skipped Nodule ID 1099 due to high std.
# Skipped Nodule ID 1100 due to high std.
# Skipped Nodule ID 1101 due to high std.
# Processing patient: LIDC-IDRI-0416
# Skipped Nodule ID 1102 due to high std.
# Skipped Nodule ID 1103 due to high std.
# Processing patient: LIDC-IDRI-0419
# Skipped Nodule ID 1104 due to high std.
# Skipped Nodule ID 1105 due to high std.
# Processing patient: LIDC-IDRI-0420
# Skipped Nodule ID 1106 due to high std.
# Skipped Nodule ID 1107 due to high std.
# Processing patient: LIDC-IDRI-0421
# Skipped Nodule ID 1108 due to high std.
# Skipped Nodule ID 1109 due to high std.
# Processing patient: LIDC-IDRI-0423
# Skipped Nodule ID 1110 due to high std.
# Processing patient: LIDC-IDRI-0424
# Skipped Nodule ID 1112 due to high std.
# Skipped Nodule ID 1113 due to high std.
# Processing patient: LIDC-IDRI-0426
# Skipped Nodule ID 1116 due to high std.
# Processing patient: LIDC-IDRI-0427
# Skipped Nodule ID 1117 due to high std.
# Skipped Nodule ID 1118 due to high std.
# Skipped Nodule ID 1120 due to high std.
# Processing patient: LIDC-IDRI-0429
# Skipped Nodule ID 1121 due to high std.
# Skipped Nodule ID 1122 due to high std.
# Processing patient: LIDC-IDRI-0430
# Skipped Nodule ID 1124 due to high std.
# Skipped Nodule ID 1125 due to high std.
# Processing patient: LIDC-IDRI-0431
# Processing patient: LIDC-IDRI-0432
# Processing patient: LIDC-IDRI-0433
# Skipped Nodule ID 1130 due to high std.
# Skipped Nodule ID 1131 due to high std.
# Processing patient: LIDC-IDRI-0434
# Skipped Nodule ID 1133 due to high std.
# Skipped Nodule ID 1134 due to high std.
# Skipped Nodule ID 1135 due to high std.
# Processing patient: LIDC-IDRI-0435
# Skipped Nodule ID 1136 due to high std.
# Skipped Nodule ID 1137 due to high std.
# Skipped Nodule ID 1138 due to high std.
# Skipped Nodule ID 1140 due to high std.
# Skipped Nodule ID 1141 due to high std.
# Skipped Nodule ID 1142 due to high std.
# Processing patient: LIDC-IDRI-0436
# Skipped Nodule ID 1143 due to high std.
# Skipped Nodule ID 1144 due to high std.
# Processing patient: LIDC-IDRI-0437
# Skipped Nodule ID 1145 due to high std.
# Skipped Nodule ID 1146 due to high std.
# Skipped Nodule ID 1147 due to high std.
# Skipped Nodule ID 1148 due to high std.
# Processing patient: LIDC-IDRI-0438
# Skipped Nodule ID 1150 due to high std.
# Processing patient: LIDC-IDRI-0439
# Skipped Nodule ID 1151 due to high std.
# Skipped Nodule ID 1152 due to high std.
# Processing patient: LIDC-IDRI-0440
# Skipped Nodule ID 1153 due to high std.
# Skipped Nodule ID 1154 due to high std.
# Processing patient: LIDC-IDRI-0442
# Skipped Nodule ID 1156 due to high std.
# Skipped Nodule ID 1157 due to high std.
# Skipped Nodule ID 1158 due to high std.
# Skipped Nodule ID 1159 due to high std.
# Skipped Nodule ID 1160 due to high std.
# Skipped Nodule ID 1161 due to high std.
# Processing patient: LIDC-IDRI-0443
# Skipped Nodule ID 1162 due to high std.
# Skipped Nodule ID 1163 due to high std.
# Processing patient: LIDC-IDRI-0444
# Skipped Nodule ID 1164 due to high std.
# Processing patient: LIDC-IDRI-0445
# Skipped Nodule ID 1166 due to high std.
# Processing patient: LIDC-IDRI-0447
# Skipped Nodule ID 1168 due to high std.
# Skipped Nodule ID 1169 due to high std.
# Processing patient: LIDC-IDRI-0448
# Skipped Nodule ID 1173 due to high std.
# Skipped Nodule ID 1174 due to high std.
# Skipped Nodule ID 1175 due to high std.
# Processing patient: LIDC-IDRI-0449
# Skipped Nodule ID 1176 due to high std.
# Skipped Nodule ID 1177 due to high std.
# Processing patient: LIDC-IDRI-0450
# Skipped Nodule ID 1178 due to high std.
# Skipped Nodule ID 1180 due to high std.
# Skipped Nodule ID 1181 due to high std.
# Skipped Nodule ID 1183 due to high std.
# Skipped Nodule ID 1184 due to high std.
# Skipped Nodule ID 1185 due to high std.
# Skipped Nodule ID 1186 due to high std.
# Processing patient: LIDC-IDRI-0451
# Skipped Nodule ID 1187 due to high std.
# Processing patient: LIDC-IDRI-0452
# Skipped Nodule ID 1188 due to high std.
# Skipped Nodule ID 1190 due to high std.
# Processing patient: LIDC-IDRI-0453
# Skipped Nodule ID 1191 due to high std.
# Processing patient: LIDC-IDRI-0454
# Skipped Nodule ID 1192 due to high std.
# Skipped Nodule ID 1193 due to high std.
# Skipped Nodule ID 1194 due to high std.
# Skipped Nodule ID 1195 due to high std.
# Skipped Nodule ID 1197 due to high std.
# Skipped Nodule ID 1198 due to high std.
# Processing patient: LIDC-IDRI-0456
# Skipped Nodule ID 1199 due to high std.
# Skipped Nodule ID 1200 due to high std.
# Skipped Nodule ID 1201 due to high std.
# ...
# Processing patient: LIDC-IDRI-0838
# Skipped Nodule ID 2209 due to high std.
# Skipped Nodule ID 2210 due to high std.
# Skipped Nodule ID 2211 due to high std.
# Skipped Nodule ID 2213 due to high std.
# Processing patient: LIDC-IDRI-0840
# Processing patient: LIDC-IDRI-0841
# Skipped Nodule ID 2215 due to high std.
# Processing patient: LIDC-IDRI-0842
# Skipped Nodule ID 2216 due to high std.
# Processing patient: LIDC-IDRI-0843
# Skipped Nodule ID 2219 due to high std.
# Skipped Nodule ID 2220 due to high std.
# Skipped Nodule ID 2221 due to high std.
# Skipped Nodule ID 2222 due to high std.
# Skipped Nodule ID 2223 due to high std.
# Skipped Nodule ID 2225 due to high std.
# Processing patient: LIDC-IDRI-0844
# Skipped Nodule ID 2226 due to high std.
# Skipped Nodule ID 2227 due to high std.
# Skipped Nodule ID 2228 due to high std.
# Processing patient: LIDC-IDRI-0845
# Skipped Nodule ID 2229 due to high std.
# Processing patient: LIDC-IDRI-0846
# Skipped Nodule ID 2231 due to high std.
# Skipped Nodule ID 2232 due to high std.
# Processing patient: LIDC-IDRI-0847
# Processing patient: LIDC-IDRI-0848
# Skipped Nodule ID 2234 due to high std.
# Processing patient: LIDC-IDRI-0849
# Skipped Nodule ID 2236 due to high std.
# Skipped Nodule ID 2237 due to high std.
# Skipped Nodule ID 2239 due to high std.
# Processing patient: LIDC-IDRI-0850
# Skipped Nodule ID 2242 due to high std.
# Skipped Nodule ID 2244 due to high std.
# Processing patient: LIDC-IDRI-0851
# Skipped Nodule ID 2245 due to high std.
# Skipped Nodule ID 2246 due to high std.
# Processing patient: LIDC-IDRI-0852
# Skipped Nodule ID 2249 due to high std.
# Skipped Nodule ID 2250 due to high std.
# Processing patient: LIDC-IDRI-0854
# Skipped Nodule ID 2252 due to high std.
# Skipped Nodule ID 2253 due to high std.
# Skipped Nodule ID 2254 due to high std.
# Processing patient: LIDC-IDRI-0855
# Skipped Nodule ID 2257 due to high std.
# Skipped Nodule ID 2258 due to high std.
# Skipped Nodule ID 2259 due to high std.
# Skipped Nodule ID 2261 due to high std.
# Skipped Nodule ID 2262 due to high std.
# Skipped Nodule ID 2263 due to high std.
# Skipped Nodule ID 2264 due to high std.
# Skipped Nodule ID 2265 due to high std.
# Skipped Nodule ID 2266 due to high std.
# Skipped Nodule ID 2268 due to high std.
# Skipped Nodule ID 2270 due to high std.
# Skipped Nodule ID 2271 due to high std.
# Skipped Nodule ID 2272 due to high std.
# Processing patient: LIDC-IDRI-0856
# Processing patient: LIDC-IDRI-0857
# Skipped Nodule ID 2274 due to high std.
# Processing patient: LIDC-IDRI-0858
# Skipped Nodule ID 2278 due to high std.
# Skipped Nodule ID 2279 due to high std.
# Skipped Nodule ID 2280 due to high std.
# Skipped Nodule ID 2282 due to high std.
# Skipped Nodule ID 2286 due to high std.
# Skipped Nodule ID 2288 due to high std.
# Processing patient: LIDC-IDRI-0859
# Skipped Nodule ID 2289 due to high std.
# Processing patient: LIDC-IDRI-0860
# Skipped Nodule ID 2290 due to high std.
# Skipped Nodule ID 2291 due to high std.
# Processing patient: LIDC-IDRI-0861
# Skipped Nodule ID 2292 due to high std.
# Skipped Nodule ID 2293 due to high std.
# Processing patient: LIDC-IDRI-0863
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 2294 due to high std.
# Skipped Nodule ID 2295 due to high std.
# Processing patient: LIDC-IDRI-0864
# Processing patient: LIDC-IDRI-0865
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 2299 due to high std.
# Processing patient: LIDC-IDRI-0866
# Skipped Nodule ID 2300 due to high std.
# Skipped Nodule ID 2301 due to high std.
# Skipped Nodule ID 2302 due to high std.
# Skipped Nodule ID 2308 due to high std.
# Processing patient: LIDC-IDRI-0867
# Skipped Nodule ID 2309 due to high std.
# Skipped Nodule ID 2310 due to high std.
# Processing patient: LIDC-IDRI-0868
# Skipped Nodule ID 2312 due to high std.
# Processing patient: LIDC-IDRI-0869
# Skipped Nodule ID 2313 due to high std.
# Skipped Nodule ID 2314 due to high std.
# Skipped Nodule ID 2315 due to high std.
# Processing patient: LIDC-IDRI-0870
# Skipped Nodule ID 2317 due to high std.
# Skipped Nodule ID 2318 due to high std.
# Skipped Nodule ID 2319 due to high std.
# Skipped Nodule ID 2320 due to high std.
# Skipped Nodule ID 2321 due to high std.
# Skipped Nodule ID 2322 due to high std.
# Skipped Nodule ID 2323 due to high std.
# Skipped Nodule ID 2324 due to high std.
# Skipped Nodule ID 2325 due to high std.
# Skipped Nodule ID 2326 due to high std.
# Skipped Nodule ID 2327 due to high std.
# Processing patient: LIDC-IDRI-0871
# Skipped Nodule ID 2330 due to high std.
# Skipped Nodule ID 2331 due to high std.
# Skipped Nodule ID 2333 due to high std.
# Skipped Nodule ID 2334 due to high std.
# Processing patient: LIDC-IDRI-0872
# Skipped Nodule ID 2337 due to high std.
# Processing patient: LIDC-IDRI-0873
# Processing patient: LIDC-IDRI-0874
# Skipped Nodule ID 2340 due to high std.
# Skipped Nodule ID 2342 due to high std.
# Processing patient: LIDC-IDRI-0875
# Skipped Nodule ID 2345 due to high std.
# Processing patient: LIDC-IDRI-0879
# Skipped Nodule ID 2346 due to high std.
# Skipped Nodule ID 2350 due to high std.
# Skipped Nodule ID 2353 due to high std.
# Processing patient: LIDC-IDRI-0880
# Processing patient: LIDC-IDRI-0882
# Skipped Nodule ID 2358 due to high std.
# Processing patient: LIDC-IDRI-0883
# Processing patient: LIDC-IDRI-0884
# Skipped Nodule ID 2364 due to high std.
# Processing patient: LIDC-IDRI-0886
# Skipped Nodule ID 2365 due to high std.
# Skipped Nodule ID 2366 due to high std.
# Skipped Nodule ID 2367 due to high std.
# Processing patient: LIDC-IDRI-0888
# Skipped Nodule ID 2368 due to high std.
# Processing patient: LIDC-IDRI-0890
# Skipped Nodule ID 2369 due to high std.
# Skipped Nodule ID 2371 due to high std.
# Processing patient: LIDC-IDRI-0892
# Skipped Nodule ID 2372 due to high std.
# Skipped Nodule ID 2373 due to high std.
# Skipped Nodule ID 2374 due to high std.
# Skipped Nodule ID 2375 due to high std.
# Processing patient: LIDC-IDRI-0893
# Skipped Nodule ID 2377 due to high std.
# Processing patient: LIDC-IDRI-0894
# Skipped Nodule ID 2379 due to high std.
# Skipped Nodule ID 2380 due to high std.
# Skipped Nodule ID 2381 due to high std.
# Skipped Nodule ID 2383 due to high std.
# Processing patient: LIDC-IDRI-0895
# Skipped Nodule ID 2386 due to high std.
# Processing patient: LIDC-IDRI-0896
# Skipped Nodule ID 2387 due to high std.
# Skipped Nodule ID 2388 due to high std.
# Processing patient: LIDC-IDRI-0898
# Skipped Nodule ID 2389 due to high std.
# Skipped Nodule ID 2391 due to high std.
# Processing patient: LIDC-IDRI-0899
# Skipped Nodule ID 2393 due to high std.
# Processing patient: LIDC-IDRI-0902
# Skipped Nodule ID 2394 due to high std.
# Skipped Nodule ID 2396 due to high std.
# Processing patient: LIDC-IDRI-0904
# Skipped Nodule ID 2397 due to high std.
# Skipped Nodule ID 2399 due to high std.
# Skipped Nodule ID 2400 due to high std.
# Processing patient: LIDC-IDRI-0905
# Skipped Nodule ID 2401 due to high std.
# Processing patient: LIDC-IDRI-0906
# Skipped Nodule ID 2403 due to high std.
# Skipped Nodule ID 2405 due to high std.
# Processing patient: LIDC-IDRI-0907
# Skipped Nodule ID 2406 due to high std.
# Skipped Nodule ID 2408 due to high std.
# Processing patient: LIDC-IDRI-0908
# Skipped Nodule ID 2409 due to high std.
# Processing patient: LIDC-IDRI-0909
# Skipped Nodule ID 2411 due to high std.
# Processing patient: LIDC-IDRI-0910
# Skipped Nodule ID 2412 due to high std.
# Skipped Nodule ID 2413 due to high std.
# Processing patient: LIDC-IDRI-0911
# Skipped Nodule ID 2414 due to high std.
# Processing patient: LIDC-IDRI-0912
# Skipped Nodule ID 2416 due to high std.
# Skipped Nodule ID 2417 due to high std.
# Skipped Nodule ID 2418 due to high std.
# Skipped Nodule ID 2420 due to high std.
# Skipped Nodule ID 2421 due to high std.
# Processing patient: LIDC-IDRI-0913
# Skipped Nodule ID 2423 due to high std.
# Skipped Nodule ID 2425 due to high std.
# Processing patient: LIDC-IDRI-0914
# Skipped Nodule ID 2426 due to high std.
# Processing patient: LIDC-IDRI-0915
# Skipped Nodule ID 2427 due to high std.
# Processing patient: LIDC-IDRI-0916
# Skipped Nodule ID 2428 due to high std.
# Skipped Nodule ID 2429 due to high std.
# Skipped Nodule ID 2430 due to high std.
# Skipped Nodule ID 2432 due to high std.
# Skipped Nodule ID 2434 due to high std.
# Skipped Nodule ID 2435 due to high std.
# Processing patient: LIDC-IDRI-0917
# Skipped Nodule ID 2437 due to high std.
# Skipped Nodule ID 2439 due to high std.
# Processing patient: LIDC-IDRI-0919
# Skipped Nodule ID 2441 due to high std.
# Processing patient: LIDC-IDRI-0920
# Processing patient: LIDC-IDRI-0921
# Skipped Nodule ID 2443 due to high std.
# Skipped Nodule ID 2444 due to high std.
# Skipped Nodule ID 2446 due to high std.
# Skipped Nodule ID 2447 due to high std.
# Processing patient: LIDC-IDRI-0922
# Skipped Nodule ID 2448 due to high std.
# Processing patient: LIDC-IDRI-0923
# Skipped Nodule ID 2450 due to high std.
# Processing patient: LIDC-IDRI-0924
# Skipped Nodule ID 2451 due to high std.
# Processing patient: LIDC-IDRI-0925
# Skipped Nodule ID 2453 due to high std.
# Processing patient: LIDC-IDRI-0926
# Skipped Nodule ID 2454 due to high std.
# Processing patient: LIDC-IDRI-0928
# Skipped Nodule ID 2455 due to high std.
# Skipped Nodule ID 2456 due to high std.
# Processing patient: LIDC-IDRI-0929
# Processing patient: LIDC-IDRI-0932
# Skipped Nodule ID 2458 due to high std.
# Processing patient: LIDC-IDRI-0933
# Skipped Nodule ID 2461 due to high std.
# Skipped Nodule ID 2462 due to high std.
# Skipped Nodule ID 2464 due to high std.
# Processing patient: LIDC-IDRI-0935
# Processing patient: LIDC-IDRI-0936
# Skipped Nodule ID 2471 due to high std.
# Skipped Nodule ID 2472 due to high std.
# Processing patient: LIDC-IDRI-0938
# Skipped Nodule ID 2473 due to high std.
# Processing patient: LIDC-IDRI-0939
# Skipped Nodule ID 2476 due to high std.
# Processing patient: LIDC-IDRI-0940
# Skipped Nodule ID 2477 due to high std.
# Processing patient: LIDC-IDRI-0941
# Skipped Nodule ID 2479 due to high std.
# Processing patient: LIDC-IDRI-0942
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 2480 due to high std.
# Skipped Nodule ID 2481 due to high std.
# Skipped Nodule ID 2483 due to high std.
# Processing patient: LIDC-IDRI-0943
# Processing patient: LIDC-IDRI-0944
# Skipped Nodule ID 2486 due to high std.
# Processing patient: LIDC-IDRI-0945
# Processing patient: LIDC-IDRI-0946
# Skipped Nodule ID 2488 due to high std.
# Processing patient: LIDC-IDRI-0947
# Skipped Nodule ID 2491 due to high std.
# Skipped Nodule ID 2493 due to high std.
# Processing patient: LIDC-IDRI-0949
# Skipped Nodule ID 2496 due to high std.
# Skipped Nodule ID 2497 due to high std.
# Processing patient: LIDC-IDRI-0950
# Processing patient: LIDC-IDRI-0951
# Skipped Nodule ID 2501 due to high std.
# Skipped Nodule ID 2503 due to high std.
# Processing patient: LIDC-IDRI-0953
# Skipped Nodule ID 2506 due to high std.
# Processing patient: LIDC-IDRI-0955
# Skipped Nodule ID 2507 due to high std.
# Processing patient: LIDC-IDRI-0956
# Skipped Nodule ID 2508 due to high std.
# Skipped Nodule ID 2509 due to high std.
# Skipped Nodule ID 2510 due to high std.
# Processing patient: LIDC-IDRI-0957
# Skipped Nodule ID 2511 due to high std.
# Skipped Nodule ID 2512 due to high std.
# Processing patient: LIDC-IDRI-0958
# Processing patient: LIDC-IDRI-0959
# Processing patient: LIDC-IDRI-0961
# Skipped Nodule ID 2517 due to high std.
# Skipped Nodule ID 2519 due to high std.
# Skipped Nodule ID 2523 due to high std.
# Skipped Nodule ID 2524 due to high std.
# Processing patient: LIDC-IDRI-0962
# Skipped Nodule ID 2525 due to high std.
# Processing patient: LIDC-IDRI-0963
# Skipped Nodule ID 2527 due to high std.
# Processing patient: LIDC-IDRI-0965
# Skipped Nodule ID 2528 due to high std.
# Processing patient: LIDC-IDRI-0966
# Skipped Nodule ID 2529 due to high std.
# Skipped Nodule ID 2530 due to high std.
# Skipped Nodule ID 2531 due to high std.
# Processing patient: LIDC-IDRI-0968
# Skipped Nodule ID 2533 due to high std.
# Processing patient: LIDC-IDRI-0969
# Skipped Nodule ID 2534 due to high std.
# Skipped Nodule ID 2535 due to high std.
# Skipped Nodule ID 2536 due to high std.
# Processing patient: LIDC-IDRI-0971
# Processing patient: LIDC-IDRI-0972
# Skipped Nodule ID 2540 due to high std.
# Processing patient: LIDC-IDRI-0973
# Skipped Nodule ID 2541 due to high std.
# Skipped Nodule ID 2542 due to high std.
# Skipped Nodule ID 2543 due to high std.
# Processing patient: LIDC-IDRI-0974
# Skipped Nodule ID 2545 due to high std.
# Processing patient: LIDC-IDRI-0976
# Skipped Nodule ID 2548 due to high std.
# Processing patient: LIDC-IDRI-0977
# Processing patient: LIDC-IDRI-0978
# Skipped Nodule ID 2552 due to high std.
# Skipped Nodule ID 2555 due to high std.
# Processing patient: LIDC-IDRI-0980
# Skipped Nodule ID 2556 due to high std.
# Skipped Nodule ID 2558 due to high std.
# Processing patient: LIDC-IDRI-0981
# Skipped Nodule ID 2559 due to high std.
# Processing patient: LIDC-IDRI-0982
# Skipped Nodule ID 2560 due to high std.
# Skipped Nodule ID 2561 due to high std.
# Processing patient: LIDC-IDRI-0983
# Skipped Nodule ID 2563 due to high std.
# Processing patient: LIDC-IDRI-0984
# Skipped Nodule ID 2564 due to high std.
# Processing patient: LIDC-IDRI-0985
# Skipped Nodule ID 2565 due to high std.
# Processing patient: LIDC-IDRI-0986
# Skipped Nodule ID 2568 due to high std.
# Skipped Nodule ID 2570 due to high std.
# Processing patient: LIDC-IDRI-0987
# Skipped Nodule ID 2571 due to high std.
# Skipped Nodule ID 2573 due to high std.
# Processing patient: LIDC-IDRI-0989
# Processing patient: LIDC-IDRI-0990
# Skipped Nodule ID 2575 due to high std.
# Processing patient: LIDC-IDRI-0991
# Skipped Nodule ID 2576 due to high std.
# Processing patient: LIDC-IDRI-0993
# Skipped Nodule ID 2577 due to high std.
# Processing patient: LIDC-IDRI-0994
# Skipped Nodule ID 2579 due to high std.
# Skipped Nodule ID 2581 due to high std.
# Skipped Nodule ID 2582 due to high std.
# Processing patient: LIDC-IDRI-0996
# Processing patient: LIDC-IDRI-0997
# Skipped Nodule ID 2586 due to high std.
# Skipped Nodule ID 2588 due to high std.
# Skipped Nodule ID 2589 due to high std.
# Processing patient: LIDC-IDRI-0998
# Skipped Nodule ID 2596 due to high std.
# Skipped Nodule ID 2597 due to high std.
# Skipped Nodule ID 2598 due to high std.
# Skipped Nodule ID 2599 due to high std.
# Skipped Nodule ID 2600 due to high std.
# Processing patient: LIDC-IDRI-0999
# Skipped Nodule ID 2601 due to high std.
# Skipped Nodule ID 2602 due to high std.
# Skipped Nodule ID 2604 due to high std.
# Processing patient: LIDC-IDRI-1000
# Skipped Nodule ID 2606 due to high std.
# Skipped Nodule ID 2608 due to high std.
# Skipped Nodule ID 2609 due to high std.
# Processing patient: LIDC-IDRI-1001
# Skipped Nodule ID 2611 due to high std.
# Skipped Nodule ID 2612 due to high std.
# Processing patient: LIDC-IDRI-1002
# Skipped Nodule ID 2613 due to high std.
# Skipped Nodule ID 2614 due to high std.
# Skipped Nodule ID 2615 due to high std.
# Skipped Nodule ID 2616 due to high std.
# Processing patient: LIDC-IDRI-1003
# Skipped Nodule ID 2618 due to high std.
# Skipped Nodule ID 2619 due to high std.
# Skipped Nodule ID 2620 due to high std.
# Skipped Nodule ID 2621 due to high std.
# Skipped Nodule ID 2622 due to high std.
# Skipped Nodule ID 2623 due to high std.
# Processing patient: LIDC-IDRI-1004
# Skipped Nodule ID 2625 due to high std.
# Skipped Nodule ID 2627 due to high std.
# Skipped Nodule ID 2628 due to high std.
# Processing patient: LIDC-IDRI-1005
# Skipped Nodule ID 2629 due to high std.
# Skipped Nodule ID 2634 due to high std.
# Processing patient: LIDC-IDRI-1006
# Processing patient: LIDC-IDRI-1007
# Skipped Nodule ID 2637 due to high std.
# Skipped Nodule ID 2638 due to high std.
# Processing patient: LIDC-IDRI-1008
# Skipped Nodule ID 2640 due to high std.
# Skipped Nodule ID 2641 due to high std.
# Skipped Nodule ID 2643 due to high std.
# Processing patient: LIDC-IDRI-1009
# Processing patient: LIDC-IDRI-1010
# Processing patient: LIDC-IDRI-1011
# Skipped Nodule ID 2647 due to high std.
# Skipped Nodule ID 2648 due to high std.
# Skipped Nodule ID 2649 due to high std.
# Processing patient: LIDC-IDRI-1012
# Skipped Nodule ID 2651 due to high std.
# ✅ Feature extraction complete and CSV saved.

# %% [markdown]
# #### std_limit = 1.0

# %%
import os
import numpy as np
import pandas as pd
import pylidc as pl
from pylidc.utils import consensus

# Paths
input_directory = "C:/Users/user/Desktop/PI_project/images/LIDC-IDRI"
params_file = "C:/Users/user/Desktop/PI_project/radiomics_config/Params.yaml"
path = "C:/Users/user/Desktop/PI_project/std_limit_1.0"
external_drive_path = "C:/Users/user/Desktop/PI_project"  # Path to save CSV

# ✅ Ensure output folder exists
os.makedirs(path, exist_ok=True)

# Initialize patient folders
patient_folders = sorted(os.listdir(input_directory))
nodule_id = 0

# Dictionary to collect nodule data
nodule_data = {
    'Nodule_id': [],
    'Patient_id': [],
    'Subtlety': [],
    'Internalstructure': [],
    'Calcification': [],
    'Sphericity': [],
    'Margin': [],
    'Lobulation': [],
    'Spiculation': [],
    'Texture': [],
    'Malignancy': []
}

malignancy_names = {
    1: "1-Highly Unlikely",
    2: "2-Moderately Unlikely",
    3: "3-Indeterminate",
    4: "4-Moderately Suspicious",
    5: "5-Highly Suspicious"
}

std_limit = 1.0

# Process each patient
for patient_folder in patient_folders:
    patient_folder_path = os.path.join(input_directory, patient_folder)
    patient_id = os.path.basename(patient_folder_path)
    print(f"Processing patient: {patient_id}")
    
    patient_scans = pl.query(pl.Scan).filter(pl.Scan.patient_id == patient_id, pl.Scan.annotations.any()).all()
    
    for scan in patient_scans:
        nods = scan.cluster_annotations()
        
        for anns in nods:
            nodule_id += 1
            nodule_characteristics = []

            # 50% consensus mask
            cmask, cbbox, masks = consensus(anns, clevel=0.5, pad=[(20, 20), (20, 20), (0, 0)])

            for i, mask in enumerate(masks):
                characteristics = anns[i].feature_vals()
                nodule_characteristics.append(characteristics)

            if nodule_characteristics:
                std_deviations = [np.std(characteristic) for characteristic in zip(*nodule_characteristics)]
                
                # Skip if any feature has std > limit
                if any(std > std_limit for std in std_deviations):
                    print(f"Skipped Nodule ID {nodule_id} due to high std.")
                    continue

                # ✅ Save cmask
                filename = os.path.join(path, f"{nodule_id}_cmask.npy")
                np.save(filename, cmask)

                # Optional volume save — uncomment if needed and storage allows
                # volume = anns[0].scan.to_volume()
                # filename = os.path.join(path, f"{nodule_id}_volume.npy")
                # np.save(filename, volume)

                # Extract characteristics (from first annotation)
                feature_values = {
                    'Nodule_id': nodule_id,
                    'Patient_id': patient_id,
                    'Subtlety': nodule_characteristics[0][0],
                    'Internalstructure': nodule_characteristics[0][1],
                    'Calcification': nodule_characteristics[0][2],
                    'Sphericity': nodule_characteristics[0][3],
                    'Margin': nodule_characteristics[0][4],
                    'Lobulation': nodule_characteristics[0][5],
                    'Spiculation': nodule_characteristics[0][6],
                    'Texture': nodule_characteristics[0][7],
                    'Malignancy': malignancy_names.get(nodule_characteristics[0][8])
                }

                for key, value in feature_values.items():
                    nodule_data[key].append(value)

# Save features to CSV
features = pd.DataFrame(nodule_data)
csv_filename = os.path.join(external_drive_path, 'features_pylidc_1.0.csv')
features.to_csv(csv_filename, index=False)

print("✅ Feature extraction complete and CSV saved.")
# Out:
# Processing patient: LICENSE
# Processing patient: LIDC-IDRI-0001
# Skipped Nodule ID 1 due to high std.
# Processing patient: LIDC-IDRI-0002
# Processing patient: LIDC-IDRI-0003
# Skipped Nodule ID 4 due to high std.
# Skipped Nodule ID 5 due to high std.
# Skipped Nodule ID 6 due to high std.
# Processing patient: LIDC-IDRI-0004
# Skipped Nodule ID 7 due to high std.
# Processing patient: LIDC-IDRI-0005
# Skipped Nodule ID 8 due to high std.
# Processing patient: LIDC-IDRI-0006
# Skipped Nodule ID 14 due to high std.
# Processing patient: LIDC-IDRI-0007
# Skipped Nodule ID 15 due to high std.
# Processing patient: LIDC-IDRI-0008
# Skipped Nodule ID 17 due to high std.
# Skipped Nodule ID 18 due to high std.
# Processing patient: LIDC-IDRI-0009
# Processing patient: LIDC-IDRI-0010
# Skipped Nodule ID 23 due to high std.
# Processing patient: LIDC-IDRI-0011
# Skipped Nodule ID 25 due to high std.
# Skipped Nodule ID 29 due to high std.
# Skipped Nodule ID 33 due to high std.
# Processing patient: LIDC-IDRI-0012
# Skipped Nodule ID 35 due to high std.
# Skipped Nodule ID 37 due to high std.
# Skipped Nodule ID 44 due to high std.
# Processing patient: LIDC-IDRI-0013
# Skipped Nodule ID 47 due to high std.
# Skipped Nodule ID 48 due to high std.
# Processing patient: LIDC-IDRI-0014
# Skipped Nodule ID 49 due to high std.
# Processing patient: LIDC-IDRI-0015
# Skipped Nodule ID 50 due to high std.
# Processing patient: LIDC-IDRI-0016
# Skipped Nodule ID 54 due to high std.
# Skipped Nodule ID 55 due to high std.
# Skipped Nodule ID 56 due to high std.
# Processing patient: LIDC-IDRI-0017
# Processing patient: LIDC-IDRI-0018
# Skipped Nodule ID 59 due to high std.
# Skipped Nodule ID 61 due to high std.
# Processing patient: LIDC-IDRI-0019
# Skipped Nodule ID 62 due to high std.
# Processing patient: LIDC-IDRI-0020
# Skipped Nodule ID 64 due to high std.
# Processing patient: LIDC-IDRI-0021
# Skipped Nodule ID 67 due to high std.
# Processing patient: LIDC-IDRI-0022
# Processing patient: LIDC-IDRI-0023
# Skipped Nodule ID 69 due to high std.
# Processing patient: LIDC-IDRI-0024
# Skipped Nodule ID 73 due to high std.
# Processing patient: LIDC-IDRI-0025
# Processing patient: LIDC-IDRI-0026
# Processing patient: LIDC-IDRI-0027
# Skipped Nodule ID 80 due to high std.
# Skipped Nodule ID 81 due to high std.
# Processing patient: LIDC-IDRI-0029
# Processing patient: LIDC-IDRI-0030
# Skipped Nodule ID 85 due to high std.
# Skipped Nodule ID 86 due to high std.
# Processing patient: LIDC-IDRI-0031
# Skipped Nodule ID 91 due to high std.
# Processing patient: LIDC-IDRI-0033
# Skipped Nodule ID 92 due to high std.
# Processing patient: LIDC-IDRI-0034
# Processing patient: LIDC-IDRI-0035
# Skipped Nodule ID 95 due to high std.
# Processing patient: LIDC-IDRI-0036
# Processing patient: LIDC-IDRI-0037
# Skipped Nodule ID 98 due to high std.
# Skipped Nodule ID 99 due to high std.
# Processing patient: LIDC-IDRI-0038
# Processing patient: LIDC-IDRI-0039
# Skipped Nodule ID 101 due to high std.
# Skipped Nodule ID 102 due to high std.
# Skipped Nodule ID 103 due to high std.
# Skipped Nodule ID 104 due to high std.
# Processing patient: LIDC-IDRI-0040
# Skipped Nodule ID 107 due to high std.
# Processing patient: LIDC-IDRI-0041
# Skipped Nodule ID 110 due to high std.
# Skipped Nodule ID 112 due to high std.
# Processing patient: LIDC-IDRI-0042
# Skipped Nodule ID 113 due to high std.
# Skipped Nodule ID 115 due to high std.
# Skipped Nodule ID 116 due to high std.
# Skipped Nodule ID 122 due to high std.
# Processing patient: LIDC-IDRI-0043
# Skipped Nodule ID 123 due to high std.
# Skipped Nodule ID 124 due to high std.
# Skipped Nodule ID 125 due to high std.
# Processing patient: LIDC-IDRI-0044
# Skipped Nodule ID 127 due to high std.
# Skipped Nodule ID 128 due to high std.
# Skipped Nodule ID 129 due to high std.
# Processing patient: LIDC-IDRI-0045
# Skipped Nodule ID 132 due to high std.
# Skipped Nodule ID 133 due to high std.
# Skipped Nodule ID 134 due to high std.
# Skipped Nodule ID 135 due to high std.
# Skipped Nodule ID 139 due to high std.
# Processing patient: LIDC-IDRI-0046
# Skipped Nodule ID 143 due to high std.
# Skipped Nodule ID 144 due to high std.
# Skipped Nodule ID 145 due to high std.
# Skipped Nodule ID 146 due to high std.
# Skipped Nodule ID 147 due to high std.
# Skipped Nodule ID 148 due to high std.
# Processing patient: LIDC-IDRI-0047
# Skipped Nodule ID 149 due to high std.
# Processing patient: LIDC-IDRI-0048
# Skipped Nodule ID 150 due to high std.
# Skipped Nodule ID 152 due to high std.
# Processing patient: LIDC-IDRI-0049
# Skipped Nodule ID 154 due to high std.
# Skipped Nodule ID 155 due to high std.
# Skipped Nodule ID 158 due to high std.
# Skipped Nodule ID 160 due to high std.
# Skipped Nodule ID 161 due to high std.
# Skipped Nodule ID 162 due to high std.
# Skipped Nodule ID 163 due to high std.
# Skipped Nodule ID 164 due to high std.
# Skipped Nodule ID 165 due to high std.
# Skipped Nodule ID 167 due to high std.
# Processing patient: LIDC-IDRI-0050
# Skipped Nodule ID 168 due to high std.
# Processing patient: LIDC-IDRI-0051
# Skipped Nodule ID 170 due to high std.
# Skipped Nodule ID 171 due to high std.
# Processing patient: LIDC-IDRI-0052
# Skipped Nodule ID 173 due to high std.
# Processing patient: LIDC-IDRI-0053
# Processing patient: LIDC-IDRI-0054
# Skipped Nodule ID 176 due to high std.
# Processing patient: LIDC-IDRI-0055
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 177 due to high std.
# Skipped Nodule ID 178 due to high std.
# Skipped Nodule ID 181 due to high std.
# Skipped Nodule ID 183 due to high std.
# Processing patient: LIDC-IDRI-0056
# Skipped Nodule ID 184 due to high std.
# Processing patient: LIDC-IDRI-0057
# Skipped Nodule ID 187 due to high std.
# Processing patient: LIDC-IDRI-0058
# Skipped Nodule ID 188 due to high std.
# Skipped Nodule ID 190 due to high std.
# Processing patient: LIDC-IDRI-0059
# Skipped Nodule ID 191 due to high std.
# Processing patient: LIDC-IDRI-0060
# Skipped Nodule ID 195 due to high std.
# Skipped Nodule ID 197 due to high std.
# Processing patient: LIDC-IDRI-0061
# Skipped Nodule ID 198 due to high std.
# Skipped Nodule ID 200 due to high std.
# Skipped Nodule ID 203 due to high std.
# Processing patient: LIDC-IDRI-0063
# Skipped Nodule ID 205 due to high std.
# Processing patient: LIDC-IDRI-0064
# Skipped Nodule ID 209 due to high std.
# Processing patient: LIDC-IDRI-0065
# Processing patient: LIDC-IDRI-0066
# Skipped Nodule ID 211 due to high std.
# Skipped Nodule ID 212 due to high std.
# Skipped Nodule ID 213 due to high std.
# Processing patient: LIDC-IDRI-0067
# Skipped Nodule ID 215 due to high std.
# Skipped Nodule ID 216 due to high std.
# Skipped Nodule ID 217 due to high std.
# Processing patient: LIDC-IDRI-0068
# Skipped Nodule ID 220 due to high std.
# Skipped Nodule ID 222 due to high std.
# Skipped Nodule ID 223 due to high std.
# Processing patient: LIDC-IDRI-0069
# Skipped Nodule ID 224 due to high std.
# Skipped Nodule ID 226 due to high std.
# Processing patient: LIDC-IDRI-0070
# Skipped Nodule ID 228 due to high std.
# Processing patient: LIDC-IDRI-0072
# Skipped Nodule ID 230 due to high std.
# Processing patient: LIDC-IDRI-0073
# Skipped Nodule ID 233 due to high std.
# Processing patient: LIDC-IDRI-0074
# Skipped Nodule ID 234 due to high std.
# Processing patient: LIDC-IDRI-0075
# Skipped Nodule ID 236 due to high std.
# Skipped Nodule ID 238 due to high std.
# Processing patient: LIDC-IDRI-0076
# Skipped Nodule ID 239 due to high std.
# Skipped Nodule ID 240 due to high std.
# Processing patient: LIDC-IDRI-0077
# Skipped Nodule ID 241 due to high std.
# Processing patient: LIDC-IDRI-0078
# Skipped Nodule ID 243 due to high std.
# Skipped Nodule ID 244 due to high std.
# Skipped Nodule ID 246 due to high std.
# Processing patient: LIDC-IDRI-0079
# Processing patient: LIDC-IDRI-0080
# Skipped Nodule ID 248 due to high std.
# Skipped Nodule ID 249 due to high std.
# Processing patient: LIDC-IDRI-0081
# Skipped Nodule ID 250 due to high std.
# Skipped Nodule ID 251 due to high std.
# Processing patient: LIDC-IDRI-0082
# Skipped Nodule ID 252 due to high std.
# Processing patient: LIDC-IDRI-0083
# Processing patient: LIDC-IDRI-0084
# Skipped Nodule ID 256 due to high std.
# Skipped Nodule ID 257 due to high std.
# Skipped Nodule ID 259 due to high std.
# Processing patient: LIDC-IDRI-0085
# Skipped Nodule ID 261 due to high std.
# Processing patient: LIDC-IDRI-0086
# Processing patient: LIDC-IDRI-0087
# Skipped Nodule ID 264 due to high std.
# Processing patient: LIDC-IDRI-0088
# Skipped Nodule ID 266 due to high std.
# Skipped Nodule ID 267 due to high std.
# Skipped Nodule ID 268 due to high std.
# Processing patient: LIDC-IDRI-0089
# Processing patient: LIDC-IDRI-0090
# Processing patient: LIDC-IDRI-0091
# Skipped Nodule ID 273 due to high std.
# Skipped Nodule ID 274 due to high std.
# Skipped Nodule ID 275 due to high std.
# Processing patient: LIDC-IDRI-0092
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 277 due to high std.
# Skipped Nodule ID 278 due to high std.
# Processing patient: LIDC-IDRI-0093
# Skipped Nodule ID 281 due to high std.
# Processing patient: LIDC-IDRI-0094
# Processing patient: LIDC-IDRI-0095
# Skipped Nodule ID 283 due to high std.
# Skipped Nodule ID 285 due to high std.
# Processing patient: LIDC-IDRI-0096
# Processing patient: LIDC-IDRI-0097
# Processing patient: LIDC-IDRI-0098
# Skipped Nodule ID 288 due to high std.
# Processing patient: LIDC-IDRI-0099
# Skipped Nodule ID 289 due to high std.
# Processing patient: LIDC-IDRI-0101
# Processing patient: LIDC-IDRI-0102
# Processing patient: LIDC-IDRI-0103
# Skipped Nodule ID 296 due to high std.
# Processing patient: LIDC-IDRI-0104
# Skipped Nodule ID 298 due to high std.
# Processing patient: LIDC-IDRI-0105
# Processing patient: LIDC-IDRI-0106
# Processing patient: LIDC-IDRI-0107
# Skipped Nodule ID 309 due to high std.
# Processing patient: LIDC-IDRI-0108
# Skipped Nodule ID 310 due to high std.
# Skipped Nodule ID 311 due to high std.
# Processing patient: LIDC-IDRI-0109
# Skipped Nodule ID 312 due to high std.
# Processing patient: LIDC-IDRI-0110
# Skipped Nodule ID 313 due to high std.
# Processing patient: LIDC-IDRI-0111
# Skipped Nodule ID 316 due to high std.
# Skipped Nodule ID 317 due to high std.
# Skipped Nodule ID 318 due to high std.
# Processing patient: LIDC-IDRI-0112
# Skipped Nodule ID 321 due to high std.
# Processing patient: LIDC-IDRI-0113
# Processing patient: LIDC-IDRI-0114
# Skipped Nodule ID 323 due to high std.
# Processing patient: LIDC-IDRI-0115
# Processing patient: LIDC-IDRI-0116
# Skipped Nodule ID 326 due to high std.
# Processing patient: LIDC-IDRI-0117
# Skipped Nodule ID 327 due to high std.
# Processing patient: LIDC-IDRI-0118
# Skipped Nodule ID 328 due to high std.
# Skipped Nodule ID 333 due to high std.
# Processing patient: LIDC-IDRI-0119
# Skipped Nodule ID 335 due to high std.
# Processing patient: LIDC-IDRI-0120
# Skipped Nodule ID 338 due to high std.
# Processing patient: LIDC-IDRI-0121
# Skipped Nodule ID 340 due to high std.
# Skipped Nodule ID 341 due to high std.
# Processing patient: LIDC-IDRI-0122
# Skipped Nodule ID 342 due to high std.
# Processing patient: LIDC-IDRI-0123
# Processing patient: LIDC-IDRI-0124
# Skipped Nodule ID 349 due to high std.
# Skipped Nodule ID 356 due to high std.
# Processing patient: LIDC-IDRI-0125
# Processing patient: LIDC-IDRI-0126
# Processing patient: LIDC-IDRI-0127
# Skipped Nodule ID 364 due to high std.
# Processing patient: LIDC-IDRI-0128
# Skipped Nodule ID 367 due to high std.
# Processing patient: LIDC-IDRI-0129
# Skipped Nodule ID 369 due to high std.
# Skipped Nodule ID 371 due to high std.
# Skipped Nodule ID 377 due to high std.
# Skipped Nodule ID 379 due to high std.
# Skipped Nodule ID 381 due to high std.
# Processing patient: LIDC-IDRI-0130
# Skipped Nodule ID 383 due to high std.
# Skipped Nodule ID 384 due to high std.
# Processing patient: LIDC-IDRI-0131
# Skipped Nodule ID 386 due to high std.
# Processing patient: LIDC-IDRI-0132
# Skipped Nodule ID 390 due to high std.
# Skipped Nodule ID 394 due to high std.
# Skipped Nodule ID 396 due to high std.
# Skipped Nodule ID 397 due to high std.
# Skipped Nodule ID 399 due to high std.
# Processing patient: LIDC-IDRI-0133
# Processing patient: LIDC-IDRI-0134
# Skipped Nodule ID 403 due to high std.
# Processing patient: LIDC-IDRI-0135
# Skipped Nodule ID 407 due to high std.
# Processing patient: LIDC-IDRI-0136
# Skipped Nodule ID 413 due to high std.
# Processing patient: LIDC-IDRI-0137
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 422 due to high std.
# Skipped Nodule ID 423 due to high std.
# Processing patient: LIDC-IDRI-0138
# Processing patient: LIDC-IDRI-0139
# Skipped Nodule ID 427 due to high std.
# Processing patient: LIDC-IDRI-0140
# Processing patient: LIDC-IDRI-0141
# Skipped Nodule ID 430 due to high std.
# Skipped Nodule ID 431 due to high std.
# Processing patient: LIDC-IDRI-0142
# Skipped Nodule ID 436 due to high std.
# Skipped Nodule ID 437 due to high std.
# Processing patient: LIDC-IDRI-0144
# Skipped Nodule ID 439 due to high std.
# Skipped Nodule ID 440 due to high std.
# Skipped Nodule ID 442 due to high std.
# Processing patient: LIDC-IDRI-0145
# Skipped Nodule ID 445 due to high std.
# Processing patient: LIDC-IDRI-0146
# Processing patient: LIDC-IDRI-0147
# Skipped Nodule ID 448 due to high std.
# Skipped Nodule ID 450 due to high std.
# Skipped Nodule ID 454 due to high std.
# Processing patient: LIDC-IDRI-0148
# Skipped Nodule ID 457 due to high std.
# Processing patient: LIDC-IDRI-0149
# Skipped Nodule ID 459 due to high std.
# Skipped Nodule ID 462 due to high std.
# Processing patient: LIDC-IDRI-0150
# Skipped Nodule ID 467 due to high std.
# Processing patient: LIDC-IDRI-0151
# Skipped Nodule ID 468 due to high std.
# Skipped Nodule ID 469 due to high std.
# Processing patient: LIDC-IDRI-0152
# Skipped Nodule ID 470 due to high std.
# Processing patient: LIDC-IDRI-0153
# Skipped Nodule ID 472 due to high std.
# Processing patient: LIDC-IDRI-0154
# Skipped Nodule ID 474 due to high std.
# Processing patient: LIDC-IDRI-0155
# Processing patient: LIDC-IDRI-0156
# Processing patient: LIDC-IDRI-0157
# Skipped Nodule ID 477 due to high std.
# Processing patient: LIDC-IDRI-0158
# Skipped Nodule ID 480 due to high std.
# Skipped Nodule ID 481 due to high std.
# Processing patient: LIDC-IDRI-0159
# Processing patient: LIDC-IDRI-0160
# Skipped Nodule ID 484 due to high std.
# Processing patient: LIDC-IDRI-0161
# Processing patient: LIDC-IDRI-0162
# Skipped Nodule ID 493 due to high std.
# Processing patient: LIDC-IDRI-0163
# Skipped Nodule ID 494 due to high std.
# Processing patient: LIDC-IDRI-0164
# Skipped Nodule ID 497 due to high std.
# Skipped Nodule ID 503 due to high std.
# Processing patient: LIDC-IDRI-0165
# Processing patient: LIDC-IDRI-0166
# Processing patient: LIDC-IDRI-0167
# Skipped Nodule ID 510 due to high std.
# Processing patient: LIDC-IDRI-0168
# Skipped Nodule ID 511 due to high std.
# Processing patient: LIDC-IDRI-0169
# Skipped Nodule ID 513 due to high std.
# Processing patient: LIDC-IDRI-0170
# Skipped Nodule ID 516 due to high std.
# Skipped Nodule ID 517 due to high std.
# Processing patient: LIDC-IDRI-0171
# Processing patient: LIDC-IDRI-0172
# Skipped Nodule ID 524 due to high std.
# Processing patient: LIDC-IDRI-0173
# Processing patient: LIDC-IDRI-0175
# Processing patient: LIDC-IDRI-0176
# Skipped Nodule ID 527 due to high std.
# Processing patient: LIDC-IDRI-0177
# Processing patient: LIDC-IDRI-0178
# Processing patient: LIDC-IDRI-0179
# Skipped Nodule ID 532 due to high std.
# Skipped Nodule ID 534 due to high std.
# Skipped Nodule ID 540 due to high std.
# Processing patient: LIDC-IDRI-0180
# Processing patient: LIDC-IDRI-0181
# Skipped Nodule ID 544 due to high std.
# Skipped Nodule ID 545 due to high std.
# Skipped Nodule ID 546 due to high std.
# Skipped Nodule ID 550 due to high std.
# Skipped Nodule ID 551 due to high std.
# Processing patient: LIDC-IDRI-0182
# Skipped Nodule ID 554 due to high std.
# Processing patient: LIDC-IDRI-0183
# Skipped Nodule ID 556 due to high std.
# Processing patient: LIDC-IDRI-0184
# Skipped Nodule ID 557 due to high std.
# Processing patient: LIDC-IDRI-0185
# Skipped Nodule ID 558 due to high std.
# Skipped Nodule ID 559 due to high std.
# Processing patient: LIDC-IDRI-0186
# Skipped Nodule ID 568 due to high std.
# Processing patient: LIDC-IDRI-0187
# Skipped Nodule ID 572 due to high std.
# Processing patient: LIDC-IDRI-0188
# Skipped Nodule ID 576 due to high std.
# Skipped Nodule ID 578 due to high std.
# Skipped Nodule ID 579 due to high std.
# Skipped Nodule ID 581 due to high std.
# Processing patient: LIDC-IDRI-0190
# Skipped Nodule ID 584 due to high std.
# Processing patient: LIDC-IDRI-0191
# Skipped Nodule ID 585 due to high std.
# Processing patient: LIDC-IDRI-0192
# Processing patient: LIDC-IDRI-0193
# Skipped Nodule ID 591 due to high std.
# Processing patient: LIDC-IDRI-0194
# Skipped Nodule ID 593 due to high std.
# Skipped Nodule ID 594 due to high std.
# Processing patient: LIDC-IDRI-0195
# Skipped Nodule ID 596 due to high std.
# Skipped Nodule ID 597 due to high std.
# Skipped Nodule ID 598 due to high std.
# Skipped Nodule ID 599 due to high std.
# Skipped Nodule ID 600 due to high std.
# Processing patient: LIDC-IDRI-0196
# Skipped Nodule ID 602 due to high std.
# Processing patient: LIDC-IDRI-0198
# Processing patient: LIDC-IDRI-0199
# Skipped Nodule ID 605 due to high std.
# Processing patient: LIDC-IDRI-0200
# Skipped Nodule ID 609 due to high std.
# Processing patient: LIDC-IDRI-0201
# Skipped Nodule ID 613 due to high std.
# Processing patient: LIDC-IDRI-0202
# Skipped Nodule ID 618 due to high std.
# Processing patient: LIDC-IDRI-0203
# Skipped Nodule ID 620 due to high std.
# Processing patient: LIDC-IDRI-0204
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 621 due to high std.
# Processing patient: LIDC-IDRI-0206
# Skipped Nodule ID 623 due to high std.
# Processing patient: LIDC-IDRI-0207
# Processing patient: LIDC-IDRI-0208
# Skipped Nodule ID 629 due to high std.
# Processing patient: LIDC-IDRI-0209
# Processing patient: LIDC-IDRI-0210
# Processing patient: LIDC-IDRI-0211
# Skipped Nodule ID 633 due to high std.
# Processing patient: LIDC-IDRI-0212
# Skipped Nodule ID 635 due to high std.
# Processing patient: LIDC-IDRI-0213
# Skipped Nodule ID 636 due to high std.
# Processing patient: LIDC-IDRI-0215
# Skipped Nodule ID 638 due to high std.
# Skipped Nodule ID 639 due to high std.
# Processing patient: LIDC-IDRI-0216
# Skipped Nodule ID 641 due to high std.
# Skipped Nodule ID 642 due to high std.
# Processing patient: LIDC-IDRI-0217
# Skipped Nodule ID 643 due to high std.
# Processing patient: LIDC-IDRI-0219
# Processing patient: LIDC-IDRI-0220
# Skipped Nodule ID 647 due to high std.
# Skipped Nodule ID 649 due to high std.
# Processing patient: LIDC-IDRI-0221
# Skipped Nodule ID 650 due to high std.
# Processing patient: LIDC-IDRI-0222
# Skipped Nodule ID 651 due to high std.
# Processing patient: LIDC-IDRI-0223
# Skipped Nodule ID 652 due to high std.
# Skipped Nodule ID 654 due to high std.
# Processing patient: LIDC-IDRI-0227
# Processing patient: LIDC-IDRI-0228
# Skipped Nodule ID 656 due to high std.
# Processing patient: LIDC-IDRI-0229
# Skipped Nodule ID 657 due to high std.
# Skipped Nodule ID 660 due to high std.
# Skipped Nodule ID 662 due to high std.
# Skipped Nodule ID 663 due to high std.
# Processing patient: LIDC-IDRI-0230
# Processing patient: LIDC-IDRI-0231
# Processing patient: LIDC-IDRI-0232
# Processing patient: LIDC-IDRI-0233
# Skipped Nodule ID 671 due to high std.
# Processing patient: LIDC-IDRI-0234
# Processing patient: LIDC-IDRI-0235
# Skipped Nodule ID 674 due to high std.
# Processing patient: LIDC-IDRI-0236
# Processing patient: LIDC-IDRI-0237
# Skipped Nodule ID 680 due to high std.
# Processing patient: LIDC-IDRI-0240
# Skipped Nodule ID 681 due to high std.
# Processing patient: LIDC-IDRI-0241
# Skipped Nodule ID 686 due to high std.
# Skipped Nodule ID 689 due to high std.
# Skipped Nodule ID 690 due to high std.
# Processing patient: LIDC-IDRI-0242
# Skipped Nodule ID 691 due to high std.
# Processing patient: LIDC-IDRI-0243
# Processing patient: LIDC-IDRI-0244
# Skipped Nodule ID 694 due to high std.
# Skipped Nodule ID 695 due to high std.
# Processing patient: LIDC-IDRI-0245
# Processing patient: LIDC-IDRI-0246
# Skipped Nodule ID 698 due to high std.
# Processing patient: LIDC-IDRI-0247
# Skipped Nodule ID 699 due to high std.
# Processing patient: LIDC-IDRI-0248
# Skipped Nodule ID 700 due to high std.
# Processing patient: LIDC-IDRI-0249
# Skipped Nodule ID 702 due to high std.
# Processing patient: LIDC-IDRI-0250
# Skipped Nodule ID 703 due to high std.
# Skipped Nodule ID 704 due to high std.
# Processing patient: LIDC-IDRI-0251
# Processing patient: LIDC-IDRI-0252
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 707 due to high std.
# Processing patient: LIDC-IDRI-0254
# Skipped Nodule ID 710 due to high std.
# Processing patient: LIDC-IDRI-0255
# Processing patient: LIDC-IDRI-0256
# Skipped Nodule ID 713 due to high std.
# Processing patient: LIDC-IDRI-0257
# Processing patient: LIDC-IDRI-0258
# Skipped Nodule ID 716 due to high std.
# Skipped Nodule ID 717 due to high std.
# Processing patient: LIDC-IDRI-0259
# Skipped Nodule ID 718 due to high std.
# Processing patient: LIDC-IDRI-0260
# Skipped Nodule ID 721 due to high std.
# Skipped Nodule ID 722 due to high std.
# Processing patient: LIDC-IDRI-0262
# Processing patient: LIDC-IDRI-0263
# Skipped Nodule ID 724 due to high std.
# Processing patient: LIDC-IDRI-0264
# Skipped Nodule ID 725 due to high std.
# Skipped Nodule ID 726 due to high std.
# Processing patient: LIDC-IDRI-0265
# Skipped Nodule ID 727 due to high std.
# Processing patient: LIDC-IDRI-0266
# Skipped Nodule ID 728 due to high std.
# Processing patient: LIDC-IDRI-0267
# Processing patient: LIDC-IDRI-0268
# Processing patient: LIDC-IDRI-0269
# Processing patient: LIDC-IDRI-0270
# Skipped Nodule ID 733 due to high std.
# Processing patient: LIDC-IDRI-0271
# Skipped Nodule ID 734 due to high std.
# Processing patient: LIDC-IDRI-0272
# Processing patient: LIDC-IDRI-0273
# Processing patient: LIDC-IDRI-0274
# Skipped Nodule ID 738 due to high std.
# Processing patient: LIDC-IDRI-0275
# Processing patient: LIDC-IDRI-0276
# Skipped Nodule ID 740 due to high std.
# Processing patient: LIDC-IDRI-0277
# Skipped Nodule ID 742 due to high std.
# Processing patient: LIDC-IDRI-0278
# Processing patient: LIDC-IDRI-0280
# Processing patient: LIDC-IDRI-0281
# Skipped Nodule ID 746 due to high std.
# Processing patient: LIDC-IDRI-0282
# Processing patient: LIDC-IDRI-0283
# Processing patient: LIDC-IDRI-0284
# Skipped Nodule ID 750 due to high std.
# Skipped Nodule ID 752 due to high std.
# Processing patient: LIDC-IDRI-0285
# Skipped Nodule ID 753 due to high std.
# Processing patient: LIDC-IDRI-0286
# Skipped Nodule ID 755 due to high std.
# Processing patient: LIDC-IDRI-0287
# Processing patient: LIDC-IDRI-0288
# Processing patient: LIDC-IDRI-0289
# Skipped Nodule ID 760 due to high std.
# Skipped Nodule ID 761 due to high std.
# Processing patient: LIDC-IDRI-0290
# Processing patient: LIDC-IDRI-0291
# Processing patient: LIDC-IDRI-0292
# Processing patient: LIDC-IDRI-0294
# Skipped Nodule ID 769 due to high std.
# Processing patient: LIDC-IDRI-0296
# Processing patient: LIDC-IDRI-0297
# Processing patient: LIDC-IDRI-0298
# Skipped Nodule ID 773 due to high std.
# Skipped Nodule ID 775 due to high std.
# Skipped Nodule ID 776 due to high std.
# Skipped Nodule ID 777 due to high std.
# Skipped Nodule ID 778 due to high std.
# Skipped Nodule ID 779 due to high std.
# Processing patient: LIDC-IDRI-0299
# Skipped Nodule ID 782 due to high std.
# Processing patient: LIDC-IDRI-0300
# Skipped Nodule ID 786 due to high std.
# Skipped Nodule ID 787 due to high std.
# Skipped Nodule ID 788 due to high std.
# Processing patient: LIDC-IDRI-0301
# Skipped Nodule ID 790 due to high std.
# Processing patient: LIDC-IDRI-0302
# Processing patient: LIDC-IDRI-0303
# Processing patient: LIDC-IDRI-0304
# Skipped Nodule ID 793 due to high std.
# Processing patient: LIDC-IDRI-0305
# Processing patient: LIDC-IDRI-0308
# Processing patient: LIDC-IDRI-0309
# Processing patient: LIDC-IDRI-0310
# Skipped Nodule ID 809 due to high std.
# Processing patient: LIDC-IDRI-0311
# Skipped Nodule ID 811 due to high std.
# Processing patient: LIDC-IDRI-0312
# Skipped Nodule ID 815 due to high std.
# Processing patient: LIDC-IDRI-0313
# Skipped Nodule ID 816 due to high std.
# Processing patient: LIDC-IDRI-0314
# Skipped Nodule ID 817 due to high std.
# Processing patient: LIDC-IDRI-0315
# Skipped Nodule ID 822 due to high std.
# Skipped Nodule ID 823 due to high std.
# Skipped Nodule ID 825 due to high std.
# Skipped Nodule ID 826 due to high std.
# Skipped Nodule ID 828 due to high std.
# Skipped Nodule ID 829 due to high std.
# Processing patient: LIDC-IDRI-0317
# Skipped Nodule ID 830 due to high std.
# Processing patient: LIDC-IDRI-0318
# Skipped Nodule ID 831 due to high std.
# Processing patient: LIDC-IDRI-0319
# Processing patient: LIDC-IDRI-0320
# Processing patient: LIDC-IDRI-0321
# Skipped Nodule ID 837 due to high std.
# Processing patient: LIDC-IDRI-0323
# Processing patient: LIDC-IDRI-0324
# Skipped Nodule ID 843 due to high std.
# Processing patient: LIDC-IDRI-0325
# Skipped Nodule ID 844 due to high std.
# Processing patient: LIDC-IDRI-0326
# Processing patient: LIDC-IDRI-0328
# Processing patient: LIDC-IDRI-0329
# Skipped Nodule ID 851 due to high std.
# Processing patient: LIDC-IDRI-0332
# Skipped Nodule ID 852 due to high std.
# Skipped Nodule ID 853 due to high std.
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 854 due to high std.
# Processing patient: LIDC-IDRI-0334
# Skipped Nodule ID 858 due to high std.
# Skipped Nodule ID 860 due to high std.
# Skipped Nodule ID 863 due to high std.
# Skipped Nodule ID 864 due to high std.
# Skipped Nodule ID 865 due to high std.
# Skipped Nodule ID 866 due to high std.
# Processing patient: LIDC-IDRI-0335
# Processing patient: LIDC-IDRI-0337
# Skipped Nodule ID 873 due to high std.
# Skipped Nodule ID 874 due to high std.
# Processing patient: LIDC-IDRI-0338
# Skipped Nodule ID 875 due to high std.
# Processing patient: LIDC-IDRI-0339
# Skipped Nodule ID 876 due to high std.
# Processing patient: LIDC-IDRI-0340
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0341
# Skipped Nodule ID 882 due to high std.
# Skipped Nodule ID 883 due to high std.
# Processing patient: LIDC-IDRI-0343
# Skipped Nodule ID 885 due to high std.
# Processing patient: LIDC-IDRI-0344
# Skipped Nodule ID 887 due to high std.
# Processing patient: LIDC-IDRI-0345
# Processing patient: LIDC-IDRI-0346
# Skipped Nodule ID 893 due to high std.
# Skipped Nodule ID 894 due to high std.
# Skipped Nodule ID 895 due to high std.
# Processing patient: LIDC-IDRI-0347
# Skipped Nodule ID 897 due to high std.
# Skipped Nodule ID 899 due to high std.
# Skipped Nodule ID 900 due to high std.
# Processing patient: LIDC-IDRI-0348
# Skipped Nodule ID 902 due to high std.
# Processing patient: LIDC-IDRI-0350
# Processing patient: LIDC-IDRI-0351
# Processing patient: LIDC-IDRI-0352
# Skipped Nodule ID 908 due to high std.
# Processing patient: LIDC-IDRI-0353
# Skipped Nodule ID 910 due to high std.
# Skipped Nodule ID 911 due to high std.
# Processing patient: LIDC-IDRI-0354
# Skipped Nodule ID 912 due to high std.
# Processing patient: LIDC-IDRI-0355
# Processing patient: LIDC-IDRI-0356
# Skipped Nodule ID 918 due to high std.
# Skipped Nodule ID 920 due to high std.
# Processing patient: LIDC-IDRI-0357
# Processing patient: LIDC-IDRI-0358
# Skipped Nodule ID 926 due to high std.
# Skipped Nodule ID 930 due to high std.
# Skipped Nodule ID 931 due to high std.
# Skipped Nodule ID 932 due to high std.
# Skipped Nodule ID 933 due to high std.
# Processing patient: LIDC-IDRI-0359
# Skipped Nodule ID 934 due to high std.
# Skipped Nodule ID 935 due to high std.
# Processing patient: LIDC-IDRI-0360
# Skipped Nodule ID 936 due to high std.
# Skipped Nodule ID 939 due to high std.
# Processing patient: LIDC-IDRI-0362
# Skipped Nodule ID 941 due to high std.
# Processing patient: LIDC-IDRI-0363
# Skipped Nodule ID 942 due to high std.
# Processing patient: LIDC-IDRI-0365
# Skipped Nodule ID 943 due to high std.
# Skipped Nodule ID 944 due to high std.
# Processing patient: LIDC-IDRI-0366
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0367
# Processing patient: LIDC-IDRI-0368
# Skipped Nodule ID 948 due to high std.
# Skipped Nodule ID 952 due to high std.
# Processing patient: LIDC-IDRI-0369
# Skipped Nodule ID 954 due to high std.
# Processing patient: LIDC-IDRI-0370
# Processing patient: LIDC-IDRI-0371
# Processing patient: LIDC-IDRI-0372
# Processing patient: LIDC-IDRI-0373
# Skipped Nodule ID 960 due to high std.
# Processing patient: LIDC-IDRI-0374
# Processing patient: LIDC-IDRI-0375
# Skipped Nodule ID 965 due to high std.
# Processing patient: LIDC-IDRI-0376
# Skipped Nodule ID 966 due to high std.
# Processing patient: LIDC-IDRI-0377
# Skipped Nodule ID 968 due to high std.
# Processing patient: LIDC-IDRI-0378
# Skipped Nodule ID 971 due to high std.
# Processing patient: LIDC-IDRI-0379
# Skipped Nodule ID 972 due to high std.
# Processing patient: LIDC-IDRI-0380
# Skipped Nodule ID 977 due to high std.
# Skipped Nodule ID 978 due to high std.
# Skipped Nodule ID 979 due to high std.
# Processing patient: LIDC-IDRI-0381
# Processing patient: LIDC-IDRI-0384
# Processing patient: LIDC-IDRI-0385
# Skipped Nodule ID 984 due to high std.
# Processing patient: LIDC-IDRI-0386
# Skipped Nodule ID 987 due to high std.
# Skipped Nodule ID 990 due to high std.
# Processing patient: LIDC-IDRI-0387
# Skipped Nodule ID 992 due to high std.
# Skipped Nodule ID 993 due to high std.
# Processing patient: LIDC-IDRI-0388
# Skipped Nodule ID 995 due to high std.
# Processing patient: LIDC-IDRI-0390
# Skipped Nodule ID 1000 due to high std.
# Skipped Nodule ID 1004 due to high std.
# Skipped Nodule ID 1005 due to high std.
# Processing patient: LIDC-IDRI-0392
# Skipped Nodule ID 1009 due to high std.
# Processing patient: LIDC-IDRI-0393
# Processing patient: LIDC-IDRI-0394
# Skipped Nodule ID 1013 due to high std.
# Skipped Nodule ID 1014 due to high std.
# Skipped Nodule ID 1015 due to high std.
# Skipped Nodule ID 1016 due to high std.
# Processing patient: LIDC-IDRI-0395
# Skipped Nodule ID 1019 due to high std.
# Skipped Nodule ID 1021 due to high std.
# Processing patient: LIDC-IDRI-0396
# Processing patient: LIDC-IDRI-0397
# Skipped Nodule ID 1027 due to high std.
# Processing patient: LIDC-IDRI-0398
# Skipped Nodule ID 1029 due to high std.
# Skipped Nodule ID 1031 due to high std.
# Skipped Nodule ID 1038 due to high std.
# Processing patient: LIDC-IDRI-0399
# Processing patient: LIDC-IDRI-0400
# Skipped Nodule ID 1043 due to high std.
# Skipped Nodule ID 1044 due to high std.
# Skipped Nodule ID 1045 due to high std.
# Processing patient: LIDC-IDRI-0402
# Skipped Nodule ID 1048 due to high std.
# Skipped Nodule ID 1049 due to high std.
# Skipped Nodule ID 1050 due to high std.
# Skipped Nodule ID 1056 due to high std.
# Processing patient: LIDC-IDRI-0403
# Processing patient: LIDC-IDRI-0404
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 1058 due to high std.
# Skipped Nodule ID 1059 due to high std.
# Skipped Nodule ID 1061 due to high std.
# Skipped Nodule ID 1062 due to high std.
# Processing patient: LIDC-IDRI-0405
# Skipped Nodule ID 1064 due to high std.
# Processing patient: LIDC-IDRI-0406
# Skipped Nodule ID 1069 due to high std.
# Processing patient: LIDC-IDRI-0407
# Skipped Nodule ID 1071 due to high std.
# Skipped Nodule ID 1072 due to high std.
# Skipped Nodule ID 1073 due to high std.
# Processing patient: LIDC-IDRI-0408
# Processing patient: LIDC-IDRI-0409
# Skipped Nodule ID 1078 due to high std.
# Skipped Nodule ID 1081 due to high std.
# Processing patient: LIDC-IDRI-0411
# Skipped Nodule ID 1085 due to high std.
# Processing patient: LIDC-IDRI-0412
# Skipped Nodule ID 1088 due to high std.
# Skipped Nodule ID 1089 due to high std.
# Processing patient: LIDC-IDRI-0413
# Skipped Nodule ID 1090 due to high std.
# Skipped Nodule ID 1091 due to high std.
# Processing patient: LIDC-IDRI-0414
# Skipped Nodule ID 1093 due to high std.
# Processing patient: LIDC-IDRI-0415
# Skipped Nodule ID 1096 due to high std.
# Skipped Nodule ID 1097 due to high std.
# Skipped Nodule ID 1098 due to high std.
# Skipped Nodule ID 1099 due to high std.
# Skipped Nodule ID 1100 due to high std.
# Skipped Nodule ID 1101 due to high std.
# Processing patient: LIDC-IDRI-0416
# Processing patient: LIDC-IDRI-0419
# Skipped Nodule ID 1105 due to high std.
# Processing patient: LIDC-IDRI-0420
# Processing patient: LIDC-IDRI-0421
# Skipped Nodule ID 1108 due to high std.
# Processing patient: LIDC-IDRI-0423
# Processing patient: LIDC-IDRI-0424
# Skipped Nodule ID 1113 due to high std.
# Processing patient: LIDC-IDRI-0426
# Processing patient: LIDC-IDRI-0427
# Skipped Nodule ID 1117 due to high std.
# Skipped Nodule ID 1118 due to high std.
# Processing patient: LIDC-IDRI-0429
# Skipped Nodule ID 1122 due to high std.
# Processing patient: LIDC-IDRI-0430
# Skipped Nodule ID 1125 due to high std.
# Processing patient: LIDC-IDRI-0431
# Processing patient: LIDC-IDRI-0432
# Processing patient: LIDC-IDRI-0433
# Skipped Nodule ID 1130 due to high std.
# Processing patient: LIDC-IDRI-0434
# Skipped Nodule ID 1133 due to high std.
# Skipped Nodule ID 1134 due to high std.
# Skipped Nodule ID 1135 due to high std.
# Processing patient: LIDC-IDRI-0435
# Skipped Nodule ID 1136 due to high std.
# Skipped Nodule ID 1137 due to high std.
# Skipped Nodule ID 1138 due to high std.
# Skipped Nodule ID 1140 due to high std.
# Skipped Nodule ID 1141 due to high std.
# Processing patient: LIDC-IDRI-0436
# Processing patient: LIDC-IDRI-0437
# Skipped Nodule ID 1145 due to high std.
# Skipped Nodule ID 1147 due to high std.
# Skipped Nodule ID 1148 due to high std.
# Processing patient: LIDC-IDRI-0438
# Skipped Nodule ID 1150 due to high std.
# Processing patient: LIDC-IDRI-0439
# Skipped Nodule ID 1151 due to high std.
# Skipped Nodule ID 1152 due to high std.
# Processing patient: LIDC-IDRI-0440
# Skipped Nodule ID 1153 due to high std.
# Skipped Nodule ID 1154 due to high std.
# Processing patient: LIDC-IDRI-0442
# Skipped Nodule ID 1158 due to high std.
# Skipped Nodule ID 1159 due to high std.
# Skipped Nodule ID 1160 due to high std.
# Skipped Nodule ID 1161 due to high std.
# Processing patient: LIDC-IDRI-0443
# Skipped Nodule ID 1162 due to high std.
# Skipped Nodule ID 1163 due to high std.
# Processing patient: LIDC-IDRI-0444
# Skipped Nodule ID 1164 due to high std.
# Processing patient: LIDC-IDRI-0445
# Processing patient: LIDC-IDRI-0447
# Skipped Nodule ID 1168 due to high std.
# Processing patient: LIDC-IDRI-0448
# Skipped Nodule ID 1175 due to high std.
# Processing patient: LIDC-IDRI-0449
# Processing patient: LIDC-IDRI-0450
# Skipped Nodule ID 1180 due to high std.
# Skipped Nodule ID 1184 due to high std.
# Skipped Nodule ID 1185 due to high std.
# Processing patient: LIDC-IDRI-0451
# Processing patient: LIDC-IDRI-0452
# Skipped Nodule ID 1190 due to high std.
# Processing patient: LIDC-IDRI-0453
# Processing patient: LIDC-IDRI-0454
# Skipped Nodule ID 1192 due to high std.
# Skipped Nodule ID 1193 due to high std.
# Skipped Nodule ID 1194 due to high std.
# Skipped Nodule ID 1195 due to high std.
# Skipped Nodule ID 1198 due to high std.
# Processing patient: LIDC-IDRI-0456
# Skipped Nodule ID 1199 due to high std.
# Skipped Nodule ID 1200 due to high std.
# Processing patient: LIDC-IDRI-0457
# Processing patient: LIDC-IDRI-0458
# Skipped Nodule ID 1205 due to high std.
# Skipped Nodule ID 1206 due to high std.
# Processing patient: LIDC-IDRI-0459
# Processing patient: LIDC-IDRI-0460
# Skipped Nodule ID 1213 due to high std.
# Skipped Nodule ID 1214 due to high std.
# Processing patient: LIDC-IDRI-0461
# Skipped Nodule ID 1221 due to high std.
# Processing patient: LIDC-IDRI-0462
# Skipped Nodule ID 1222 due to high std.
# Skipped Nodule ID 1223 due to high std.
# Skipped Nodule ID 1224 due to high std.
# Processing patient: LIDC-IDRI-0463
# Skipped Nodule ID 1226 due to high std.
# Processing patient: LIDC-IDRI-0464
# Skipped Nodule ID 1229 due to high std.
# Processing patient: LIDC-IDRI-0466
# Skipped Nodule ID 1230 due to high std.
# Skipped Nodule ID 1232 due to high std.
# Processing patient: LIDC-IDRI-0467
# Skipped Nodule ID 1235 due to high std.
# Processing patient: LIDC-IDRI-0468
# Skipped Nodule ID 1236 due to high std.
# Processing patient: LIDC-IDRI-0469
# Skipped Nodule ID 1237 due to high std.
# Skipped Nodule ID 1238 due to high std.
# Skipped Nodule ID 1241 due to high std.
# Processing patient: LIDC-IDRI-0470
# Skipped Nodule ID 1243 due to high std.
# Processing patient: LIDC-IDRI-0471
# Processing patient: LIDC-IDRI-0473
# Skipped Nodule ID 1246 due to high std.
# Skipped Nodule ID 1248 due to high std.
# Skipped Nodule ID 1249 due to high std.
# Processing patient: LIDC-IDRI-0474
# Skipped Nodule ID 1251 due to high std.
# Skipped Nodule ID 1252 due to high std.
# Processing patient: LIDC-IDRI-0475
# Skipped Nodule ID 1257 due to high std.
# Processing patient: LIDC-IDRI-0476
# Skipped Nodule ID 1258 due to high std.
# Skipped Nodule ID 1262 due to high std.
# Processing patient: LIDC-IDRI-0477
# Skipped Nodule ID 1265 due to high std.
# Processing patient: LIDC-IDRI-0478
# Processing patient: LIDC-IDRI-0479
# Skipped Nodule ID 1271 due to high std.
# Skipped Nodule ID 1272 due to high std.
# Processing patient: LIDC-IDRI-0480
# Skipped Nodule ID 1274 due to high std.
# Processing patient: LIDC-IDRI-0481
# Skipped Nodule ID 1278 due to high std.
# Processing patient: LIDC-IDRI-0483
# Processing patient: LIDC-IDRI-0484
# Skipped Nodule ID 1284 due to high std.
# Skipped Nodule ID 1286 due to high std.
# Processing patient: LIDC-IDRI-0485
# Skipped Nodule ID 1288 due to high std.
# Processing patient: LIDC-IDRI-0486
# Skipped Nodule ID 1293 due to high std.
# Processing patient: LIDC-IDRI-0487
# Skipped Nodule ID 1300 due to high std.
# Processing patient: LIDC-IDRI-0488
# Skipped Nodule ID 1304 due to high std.
# Processing patient: LIDC-IDRI-0489
# Skipped Nodule ID 1306 due to high std.
# Skipped Nodule ID 1309 due to high std.
# Processing patient: LIDC-IDRI-0490
# Processing patient: LIDC-IDRI-0491
# Skipped Nodule ID 1323 due to high std.
# Processing patient: LIDC-IDRI-0492
# Processing patient: LIDC-IDRI-0493
# Skipped Nodule ID 1329 due to high std.
# Skipped Nodule ID 1330 due to high std.
# Processing patient: LIDC-IDRI-0494
# Processing patient: LIDC-IDRI-0495
# Processing patient: LIDC-IDRI-0496
# Skipped Nodule ID 1336 due to high std.
# Processing patient: LIDC-IDRI-0497
# Skipped Nodule ID 1338 due to high std.
# Processing patient: LIDC-IDRI-0498
# Skipped Nodule ID 1340 due to high std.
# Processing patient: LIDC-IDRI-0499
# Skipped Nodule ID 1341 due to high std.
# Processing patient: LIDC-IDRI-0500
# Skipped Nodule ID 1348 due to high std.
# Processing patient: LIDC-IDRI-0501
# Skipped Nodule ID 1349 due to high std.
# Skipped Nodule ID 1350 due to high std.
# Processing patient: LIDC-IDRI-0502
# Processing patient: LIDC-IDRI-0503
# Skipped Nodule ID 1353 due to high std.
# Processing patient: LIDC-IDRI-0504
# Processing patient: LIDC-IDRI-0505
# Processing patient: LIDC-IDRI-0507
# Skipped Nodule ID 1357 due to high std.
# Skipped Nodule ID 1359 due to high std.
# Skipped Nodule ID 1360 due to high std.
# Processing patient: LIDC-IDRI-0508
# Processing patient: LIDC-IDRI-0509
# Processing patient: LIDC-IDRI-0510
# Skipped Nodule ID 1368 due to high std.
# Skipped Nodule ID 1369 due to high std.
# Processing patient: LIDC-IDRI-0515
# Skipped Nodule ID 1378 due to high std.
# Processing patient: LIDC-IDRI-0516
# Skipped Nodule ID 1379 due to high std.
# Processing patient: LIDC-IDRI-0517
# Processing patient: LIDC-IDRI-0518
# Skipped Nodule ID 1384 due to high std.
# Processing patient: LIDC-IDRI-0520
# Processing patient: LIDC-IDRI-0521
# Processing patient: LIDC-IDRI-0522
# Skipped Nodule ID 1390 due to high std.
# Processing patient: LIDC-IDRI-0523
# Skipped Nodule ID 1391 due to high std.
# Skipped Nodule ID 1392 due to high std.
# Skipped Nodule ID 1395 due to high std.
# Processing patient: LIDC-IDRI-0524
# Skipped Nodule ID 1396 due to high std.
# Processing patient: LIDC-IDRI-0525
# Skipped Nodule ID 1404 due to high std.
# Processing patient: LIDC-IDRI-0526
# Skipped Nodule ID 1406 due to high std.
# Skipped Nodule ID 1407 due to high std.
# Skipped Nodule ID 1410 due to high std.
# Skipped Nodule ID 1411 due to high std.
# Processing patient: LIDC-IDRI-0527
# Skipped Nodule ID 1412 due to high std.
# Processing patient: LIDC-IDRI-0529
# Skipped Nodule ID 1416 due to high std.
# Processing patient: LIDC-IDRI-0530
# Skipped Nodule ID 1417 due to high std.
# Skipped Nodule ID 1418 due to high std.
# Processing patient: LIDC-IDRI-0532
# Processing patient: LIDC-IDRI-0533
# Skipped Nodule ID 1422 due to high std.
# Processing patient: LIDC-IDRI-0534
# Skipped Nodule ID 1423 due to high std.
# Processing patient: LIDC-IDRI-0535
# Skipped Nodule ID 1425 due to high std.
# Processing patient: LIDC-IDRI-0537
# Skipped Nodule ID 1431 due to high std.
# Processing patient: LIDC-IDRI-0538
# Processing patient: LIDC-IDRI-0539
# Skipped Nodule ID 1433 due to high std.
# Processing patient: LIDC-IDRI-0541
# Processing patient: LIDC-IDRI-0542
# Processing patient: LIDC-IDRI-0543
# Skipped Nodule ID 1441 due to high std.
# Processing patient: LIDC-IDRI-0545
# Processing patient: LIDC-IDRI-0546
# Skipped Nodule ID 1444 due to high std.
# Processing patient: LIDC-IDRI-0547
# Processing patient: LIDC-IDRI-0549
# Skipped Nodule ID 1448 due to high std.
# Skipped Nodule ID 1449 due to high std.
# Skipped Nodule ID 1452 due to high std.
# Processing patient: LIDC-IDRI-0550
# Processing patient: LIDC-IDRI-0551
# Processing patient: LIDC-IDRI-0552
# Processing patient: LIDC-IDRI-0553
# Processing patient: LIDC-IDRI-0554
# Processing patient: LIDC-IDRI-0555
# Skipped Nodule ID 1460 due to high std.
# Processing patient: LIDC-IDRI-0556
# Processing patient: LIDC-IDRI-0557
# Processing patient: LIDC-IDRI-0558
# Processing patient: LIDC-IDRI-0559
# Processing patient: LIDC-IDRI-0560
# Processing patient: LIDC-IDRI-0562
# Skipped Nodule ID 1470 due to high std.
# Skipped Nodule ID 1471 due to high std.
# Processing patient: LIDC-IDRI-0563
# Processing patient: LIDC-IDRI-0565
# Skipped Nodule ID 1475 due to high std.
# Skipped Nodule ID 1476 due to high std.
# Skipped Nodule ID 1477 due to high std.
# Skipped Nodule ID 1478 due to high std.
# Skipped Nodule ID 1479 due to high std.
# Processing patient: LIDC-IDRI-0566
# Skipped Nodule ID 1480 due to high std.
# Processing patient: LIDC-IDRI-0567
# Processing patient: LIDC-IDRI-0568
# Skipped Nodule ID 1484 due to high std.
# Skipped Nodule ID 1485 due to high std.
# Skipped Nodule ID 1486 due to high std.
# Processing patient: LIDC-IDRI-0569
# Skipped Nodule ID 1487 due to high std.
# Skipped Nodule ID 1488 due to high std.
# Processing patient: LIDC-IDRI-0570
# Processing patient: LIDC-IDRI-0571
# Processing patient: LIDC-IDRI-0572
# Processing patient: LIDC-IDRI-0574
# Processing patient: LIDC-IDRI-0575
# Processing patient: LIDC-IDRI-0576
# Skipped Nodule ID 1500 due to high std.
# Skipped Nodule ID 1501 due to high std.
# Processing patient: LIDC-IDRI-0577
# Skipped Nodule ID 1504 due to high std.
# Skipped Nodule ID 1505 due to high std.
# Skipped Nodule ID 1506 due to high std.
# Processing patient: LIDC-IDRI-0578
# Skipped Nodule ID 1508 due to high std.
# Processing patient: LIDC-IDRI-0579
# Processing patient: LIDC-IDRI-0580
# Processing patient: LIDC-IDRI-0581
# Processing patient: LIDC-IDRI-0582
# Skipped Nodule ID 1514 due to high std.
# Skipped Nodule ID 1517 due to high std.
# Skipped Nodule ID 1519 due to high std.
# Processing patient: LIDC-IDRI-0583
# Skipped Nodule ID 1522 due to high std.
# Skipped Nodule ID 1534 due to high std.
# Skipped Nodule ID 1535 due to high std.
# Skipped Nodule ID 1540 due to high std.
# Processing patient: LIDC-IDRI-0584
# Processing patient: LIDC-IDRI-0586
# Skipped Nodule ID 1545 due to high std.
# Processing patient: LIDC-IDRI-0587
# Skipped Nodule ID 1549 due to high std.
# Skipped Nodule ID 1555 due to high std.
# Processing patient: LIDC-IDRI-0588
# Processing patient: LIDC-IDRI-0590
# Skipped Nodule ID 1558 due to high std.
# Processing patient: LIDC-IDRI-0591
# Processing patient: LIDC-IDRI-0592
# Skipped Nodule ID 1560 due to high std.
# Processing patient: LIDC-IDRI-0593
# Processing patient: LIDC-IDRI-0594
# Processing patient: LIDC-IDRI-0595
# Skipped Nodule ID 1567 due to high std.
# Processing patient: LIDC-IDRI-0596
# Skipped Nodule ID 1568 due to high std.
# Processing patient: LIDC-IDRI-0597
# Processing patient: LIDC-IDRI-0598
# Skipped Nodule ID 1571 due to high std.
# Processing patient: LIDC-IDRI-0599
# Processing patient: LIDC-IDRI-0601
# Skipped Nodule ID 1574 due to high std.
# Skipped Nodule ID 1575 due to high std.
# Skipped Nodule ID 1576 due to high std.
# Skipped Nodule ID 1577 due to high std.
# Skipped Nodule ID 1578 due to high std.
# Processing patient: LIDC-IDRI-0602
# Skipped Nodule ID 1580 due to high std.
# Skipped Nodule ID 1582 due to high std.
# Processing patient: LIDC-IDRI-0604
# Skipped Nodule ID 1586 due to high std.
# Processing patient: LIDC-IDRI-0605
# Skipped Nodule ID 1589 due to high std.
# Processing patient: LIDC-IDRI-0606
# Processing patient: LIDC-IDRI-0607
# Processing patient: LIDC-IDRI-0608
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 1605 due to high std.
# Processing patient: LIDC-IDRI-0609
# Skipped Nodule ID 1606 due to high std.
# Processing patient: LIDC-IDRI-0610
# Skipped Nodule ID 1608 due to high std.
# Skipped Nodule ID 1609 due to high std.
# Processing patient: LIDC-IDRI-0611
# Processing patient: LIDC-IDRI-0613
# Processing patient: LIDC-IDRI-0614
# Skipped Nodule ID 1612 due to high std.
# Skipped Nodule ID 1614 due to high std.
# Processing patient: LIDC-IDRI-0615
# Skipped Nodule ID 1615 due to high std.
# Processing patient: LIDC-IDRI-0617
# Skipped Nodule ID 1619 due to high std.
# Skipped Nodule ID 1620 due to high std.
# Processing patient: LIDC-IDRI-0618
# Processing patient: LIDC-IDRI-0619
# Skipped Nodule ID 1622 due to high std.
# Skipped Nodule ID 1623 due to high std.
# Processing patient: LIDC-IDRI-0620
# Skipped Nodule ID 1624 due to high std.
# Skipped Nodule ID 1625 due to high std.
# Processing patient: LIDC-IDRI-0621
# Processing patient: LIDC-IDRI-0624
# Skipped Nodule ID 1633 due to high std.
# Processing patient: LIDC-IDRI-0625
# Processing patient: LIDC-IDRI-0626
# Skipped Nodule ID 1640 due to high std.
# Processing patient: LIDC-IDRI-0628
# Skipped Nodule ID 1646 due to high std.
# Processing patient: LIDC-IDRI-0629
# Processing patient: LIDC-IDRI-0630
# Processing patient: LIDC-IDRI-0631
# Processing patient: LIDC-IDRI-0633
# Processing patient: LIDC-IDRI-0634
# Skipped Nodule ID 1656 due to high std.
# Processing patient: LIDC-IDRI-0635
# Skipped Nodule ID 1657 due to high std.
# Processing patient: LIDC-IDRI-0636
# Skipped Nodule ID 1661 due to high std.
# Skipped Nodule ID 1662 due to high std.
# Processing patient: LIDC-IDRI-0637
# Skipped Nodule ID 1664 due to high std.
# Skipped Nodule ID 1668 due to high std.
# Skipped Nodule ID 1669 due to high std.
# Processing patient: LIDC-IDRI-0638
# Processing patient: LIDC-IDRI-0639
# Skipped Nodule ID 1676 due to high std.
# Skipped Nodule ID 1677 due to high std.
# Processing patient: LIDC-IDRI-0640
# Skipped Nodule ID 1679 due to high std.
# Processing patient: LIDC-IDRI-0641
# Skipped Nodule ID 1681 due to high std.
# Skipped Nodule ID 1683 due to high std.
# Processing patient: LIDC-IDRI-0642
# Skipped Nodule ID 1691 due to high std.
# Processing patient: LIDC-IDRI-0643
# Processing patient: LIDC-IDRI-0644
# Skipped Nodule ID 1696 due to high std.
# Processing patient: LIDC-IDRI-0645
# Processing patient: LIDC-IDRI-0647
# Processing patient: LIDC-IDRI-0648
# Processing patient: LIDC-IDRI-0649
# Skipped Nodule ID 1704 due to high std.
# Skipped Nodule ID 1706 due to high std.
# Skipped Nodule ID 1708 due to high std.
# Skipped Nodule ID 1709 due to high std.
# Skipped Nodule ID 1710 due to high std.
# Skipped Nodule ID 1712 due to high std.
# Skipped Nodule ID 1713 due to high std.
# Processing patient: LIDC-IDRI-0650
# Processing patient: LIDC-IDRI-0651
# Skipped Nodule ID 1716 due to high std.
# Skipped Nodule ID 1717 due to high std.
# Skipped Nodule ID 1718 due to high std.
# Processing patient: LIDC-IDRI-0652
# Processing patient: LIDC-IDRI-0654
# Processing patient: LIDC-IDRI-0655
# Skipped Nodule ID 1722 due to high std.
# Skipped Nodule ID 1727 due to high std.
# Skipped Nodule ID 1728 due to high std.
# Skipped Nodule ID 1729 due to high std.
# Processing patient: LIDC-IDRI-0656
# Skipped Nodule ID 1730 due to high std.
# Processing patient: LIDC-IDRI-0657
# Processing patient: LIDC-IDRI-0658
# Skipped Nodule ID 1733 due to high std.
# Processing patient: LIDC-IDRI-0659
# Processing patient: LIDC-IDRI-0660
# ...
# Skipped Nodule ID 2066 due to high std.
# Skipped Nodule ID 2068 due to high std.
# Skipped Nodule ID 2069 due to high std.
# Processing patient: LIDC-IDRI-0778
# Processing patient: LIDC-IDRI-0779
# Skipped Nodule ID 2072 due to high std.
# Processing patient: LIDC-IDRI-0780
# Processing patient: LIDC-IDRI-0781
# Processing patient: LIDC-IDRI-0782
# Processing patient: LIDC-IDRI-0783
# Processing patient: LIDC-IDRI-0785
# Skipped Nodule ID 2079 due to high std.
# Skipped Nodule ID 2080 due to high std.
# Skipped Nodule ID 2081 due to high std.
# Skipped Nodule ID 2084 due to high std.
# Skipped Nodule ID 2085 due to high std.
# Skipped Nodule ID 2086 due to high std.
# Skipped Nodule ID 2087 due to high std.
# Processing patient: LIDC-IDRI-0786
# Skipped Nodule ID 2088 due to high std.
# Processing patient: LIDC-IDRI-0787
# Processing patient: LIDC-IDRI-0788
# Skipped Nodule ID 2092 due to high std.
# Processing patient: LIDC-IDRI-0789
# Skipped Nodule ID 2096 due to high std.
# Processing patient: LIDC-IDRI-0790
# Skipped Nodule ID 2097 due to high std.
# Skipped Nodule ID 2098 due to high std.
# Processing patient: LIDC-IDRI-0791
# Processing patient: LIDC-IDRI-0792
# Skipped Nodule ID 2100 due to high std.
# Processing patient: LIDC-IDRI-0793
# Processing patient: LIDC-IDRI-0794
# Skipped Nodule ID 2107 due to high std.
# Processing patient: LIDC-IDRI-0795
# Skipped Nodule ID 2108 due to high std.
# Skipped Nodule ID 2109 due to high std.
# Processing patient: LIDC-IDRI-0796
# Processing patient: LIDC-IDRI-0797
# Processing patient: LIDC-IDRI-0798
# Skipped Nodule ID 2114 due to high std.
# Processing patient: LIDC-IDRI-0799
# Processing patient: LIDC-IDRI-0800
# Skipped Nodule ID 2116 due to high std.
# Skipped Nodule ID 2117 due to high std.
# Processing patient: LIDC-IDRI-0801
# Processing patient: LIDC-IDRI-0802
# Processing patient: LIDC-IDRI-0803
# Skipped Nodule ID 2124 due to high std.
# Processing patient: LIDC-IDRI-0805
# Skipped Nodule ID 2126 due to high std.
# Processing patient: LIDC-IDRI-0806
# Skipped Nodule ID 2130 due to high std.
# Skipped Nodule ID 2131 due to high std.
# Skipped Nodule ID 2134 due to high std.
# Skipped Nodule ID 2136 due to high std.
# Processing patient: LIDC-IDRI-0807
# Skipped Nodule ID 2143 due to high std.
# Processing patient: LIDC-IDRI-0809
# Processing patient: LIDC-IDRI-0810
# Processing patient: LIDC-IDRI-0811
# Processing patient: LIDC-IDRI-0812
# Processing patient: LIDC-IDRI-0813
# Skipped Nodule ID 2153 due to high std.
# Skipped Nodule ID 2154 due to high std.
# Processing patient: LIDC-IDRI-0814
# Skipped Nodule ID 2156 due to high std.
# Processing patient: LIDC-IDRI-0815
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 2157 due to high std.
# Processing patient: LIDC-IDRI-0816
# Skipped Nodule ID 2158 due to high std.
# Skipped Nodule ID 2159 due to high std.
# Processing patient: LIDC-IDRI-0817
# Processing patient: LIDC-IDRI-0818
# Processing patient: LIDC-IDRI-0819
# Skipped Nodule ID 2162 due to high std.
# Skipped Nodule ID 2163 due to high std.
# Skipped Nodule ID 2164 due to high std.
# Processing patient: LIDC-IDRI-0820
# Skipped Nodule ID 2167 due to high std.
# Skipped Nodule ID 2168 due to high std.
# Processing patient: LIDC-IDRI-0821
# Processing patient: LIDC-IDRI-0822
# Skipped Nodule ID 2177 due to high std.
# Skipped Nodule ID 2178 due to high std.
# Processing patient: LIDC-IDRI-0823
# Processing patient: LIDC-IDRI-0824
# Processing patient: LIDC-IDRI-0825
# Skipped Nodule ID 2183 due to high std.
# Processing patient: LIDC-IDRI-0826
# Skipped Nodule ID 2184 due to high std.
# Skipped Nodule ID 2185 due to high std.
# Processing patient: LIDC-IDRI-0827
# Skipped Nodule ID 2189 due to high std.
# Processing patient: LIDC-IDRI-0828
# Skipped Nodule ID 2190 due to high std.
# Processing patient: LIDC-IDRI-0829
# Processing patient: LIDC-IDRI-0830
# Processing patient: LIDC-IDRI-0831
# Processing patient: LIDC-IDRI-0832
# Processing patient: LIDC-IDRI-0833
# Processing patient: LIDC-IDRI-0834
# Processing patient: LIDC-IDRI-0835
# Skipped Nodule ID 2202 due to high std.
# Skipped Nodule ID 2203 due to high std.
# Processing patient: LIDC-IDRI-0836
# Processing patient: LIDC-IDRI-0837
# Skipped Nodule ID 2206 due to high std.
# Skipped Nodule ID 2208 due to high std.
# Processing patient: LIDC-IDRI-0838
# Skipped Nodule ID 2209 due to high std.
# Processing patient: LIDC-IDRI-0840
# Processing patient: LIDC-IDRI-0841
# Processing patient: LIDC-IDRI-0842
# Processing patient: LIDC-IDRI-0843
# Skipped Nodule ID 2220 due to high std.
# Skipped Nodule ID 2222 due to high std.
# Skipped Nodule ID 2223 due to high std.
# Processing patient: LIDC-IDRI-0844
# Skipped Nodule ID 2226 due to high std.
# Processing patient: LIDC-IDRI-0845
# Skipped Nodule ID 2229 due to high std.
# Processing patient: LIDC-IDRI-0846
# Skipped Nodule ID 2232 due to high std.
# Processing patient: LIDC-IDRI-0847
# Processing patient: LIDC-IDRI-0848
# Skipped Nodule ID 2234 due to high std.
# Processing patient: LIDC-IDRI-0849
# Skipped Nodule ID 2237 due to high std.
# Skipped Nodule ID 2239 due to high std.
# Processing patient: LIDC-IDRI-0850
# Skipped Nodule ID 2242 due to high std.
# Skipped Nodule ID 2244 due to high std.
# Processing patient: LIDC-IDRI-0851
# Processing patient: LIDC-IDRI-0852
# Skipped Nodule ID 2249 due to high std.
# Skipped Nodule ID 2250 due to high std.
# Processing patient: LIDC-IDRI-0854
# Processing patient: LIDC-IDRI-0855
# Skipped Nodule ID 2257 due to high std.
# Skipped Nodule ID 2258 due to high std.
# Skipped Nodule ID 2259 due to high std.
# Skipped Nodule ID 2261 due to high std.
# Skipped Nodule ID 2262 due to high std.
# Skipped Nodule ID 2265 due to high std.
# Skipped Nodule ID 2266 due to high std.
# Skipped Nodule ID 2268 due to high std.
# Skipped Nodule ID 2270 due to high std.
# Skipped Nodule ID 2272 due to high std.
# Processing patient: LIDC-IDRI-0856
# Processing patient: LIDC-IDRI-0857
# Skipped Nodule ID 2274 due to high std.
# Processing patient: LIDC-IDRI-0858
# Skipped Nodule ID 2278 due to high std.
# Processing patient: LIDC-IDRI-0859
# Skipped Nodule ID 2289 due to high std.
# Processing patient: LIDC-IDRI-0860
# Skipped Nodule ID 2290 due to high std.
# Processing patient: LIDC-IDRI-0861
# Skipped Nodule ID 2293 due to high std.
# Processing patient: LIDC-IDRI-0863
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0864
# Processing patient: LIDC-IDRI-0865
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 2299 due to high std.
# Processing patient: LIDC-IDRI-0866
# Skipped Nodule ID 2300 due to high std.
# Skipped Nodule ID 2302 due to high std.
# Skipped Nodule ID 2308 due to high std.
# Processing patient: LIDC-IDRI-0867
# Skipped Nodule ID 2309 due to high std.
# Skipped Nodule ID 2310 due to high std.
# Processing patient: LIDC-IDRI-0868
# Processing patient: LIDC-IDRI-0869
# Skipped Nodule ID 2314 due to high std.
# Skipped Nodule ID 2315 due to high std.
# Processing patient: LIDC-IDRI-0870
# Skipped Nodule ID 2318 due to high std.
# Skipped Nodule ID 2319 due to high std.
# Skipped Nodule ID 2320 due to high std.
# Skipped Nodule ID 2321 due to high std.
# Skipped Nodule ID 2326 due to high std.
# Skipped Nodule ID 2327 due to high std.
# Processing patient: LIDC-IDRI-0871
# Skipped Nodule ID 2330 due to high std.
# Skipped Nodule ID 2331 due to high std.
# Processing patient: LIDC-IDRI-0872
# Processing patient: LIDC-IDRI-0873
# Processing patient: LIDC-IDRI-0874
# Skipped Nodule ID 2340 due to high std.
# Skipped Nodule ID 2342 due to high std.
# Processing patient: LIDC-IDRI-0875
# Skipped Nodule ID 2345 due to high std.
# Processing patient: LIDC-IDRI-0879
# Skipped Nodule ID 2346 due to high std.
# Skipped Nodule ID 2353 due to high std.
# Processing patient: LIDC-IDRI-0880
# Processing patient: LIDC-IDRI-0882
# Processing patient: LIDC-IDRI-0883
# Processing patient: LIDC-IDRI-0884
# Processing patient: LIDC-IDRI-0886
# Skipped Nodule ID 2366 due to high std.
# Skipped Nodule ID 2367 due to high std.
# Processing patient: LIDC-IDRI-0888
# Processing patient: LIDC-IDRI-0890
# Skipped Nodule ID 2369 due to high std.
# Skipped Nodule ID 2371 due to high std.
# Processing patient: LIDC-IDRI-0892
# Skipped Nodule ID 2372 due to high std.
# Skipped Nodule ID 2373 due to high std.
# Skipped Nodule ID 2374 due to high std.
# Skipped Nodule ID 2375 due to high std.
# Processing patient: LIDC-IDRI-0893
# Skipped Nodule ID 2377 due to high std.
# Processing patient: LIDC-IDRI-0894
# Skipped Nodule ID 2380 due to high std.
# Skipped Nodule ID 2381 due to high std.
# Processing patient: LIDC-IDRI-0895
# Skipped Nodule ID 2386 due to high std.
# Processing patient: LIDC-IDRI-0896
# Skipped Nodule ID 2387 due to high std.
# Skipped Nodule ID 2388 due to high std.
# Processing patient: LIDC-IDRI-0898
# Skipped Nodule ID 2389 due to high std.
# Skipped Nodule ID 2391 due to high std.
# Processing patient: LIDC-IDRI-0899
# Processing patient: LIDC-IDRI-0902
# Skipped Nodule ID 2394 due to high std.
# Skipped Nodule ID 2396 due to high std.
# Processing patient: LIDC-IDRI-0904
# Skipped Nodule ID 2399 due to high std.
# Processing patient: LIDC-IDRI-0905
# Skipped Nodule ID 2401 due to high std.
# Processing patient: LIDC-IDRI-0906
# Skipped Nodule ID 2405 due to high std.
# Processing patient: LIDC-IDRI-0907
# Skipped Nodule ID 2408 due to high std.
# Processing patient: LIDC-IDRI-0908
# Skipped Nodule ID 2409 due to high std.
# Processing patient: LIDC-IDRI-0909
# Skipped Nodule ID 2411 due to high std.
# Processing patient: LIDC-IDRI-0910
# Skipped Nodule ID 2412 due to high std.
# Skipped Nodule ID 2413 due to high std.
# Processing patient: LIDC-IDRI-0911
# Processing patient: LIDC-IDRI-0912
# Skipped Nodule ID 2416 due to high std.
# Skipped Nodule ID 2421 due to high std.
# Processing patient: LIDC-IDRI-0913
# Skipped Nodule ID 2423 due to high std.
# Skipped Nodule ID 2425 due to high std.
# Processing patient: LIDC-IDRI-0914
# Skipped Nodule ID 2426 due to high std.
# Processing patient: LIDC-IDRI-0915
# Skipped Nodule ID 2427 due to high std.
# Processing patient: LIDC-IDRI-0916
# Skipped Nodule ID 2428 due to high std.
# Skipped Nodule ID 2434 due to high std.
# Processing patient: LIDC-IDRI-0917
# Skipped Nodule ID 2439 due to high std.
# Processing patient: LIDC-IDRI-0919
# Skipped Nodule ID 2441 due to high std.
# Processing patient: LIDC-IDRI-0920
# Processing patient: LIDC-IDRI-0921
# Skipped Nodule ID 2443 due to high std.
# Skipped Nodule ID 2446 due to high std.
# Skipped Nodule ID 2447 due to high std.
# Processing patient: LIDC-IDRI-0922
# Processing patient: LIDC-IDRI-0923
# Processing patient: LIDC-IDRI-0924
# Processing patient: LIDC-IDRI-0925
# Skipped Nodule ID 2453 due to high std.
# Processing patient: LIDC-IDRI-0926
# Processing patient: LIDC-IDRI-0928
# Skipped Nodule ID 2455 due to high std.
# Processing patient: LIDC-IDRI-0929
# Processing patient: LIDC-IDRI-0932
# Processing patient: LIDC-IDRI-0933
# Skipped Nodule ID 2464 due to high std.
# Processing patient: LIDC-IDRI-0935
# Processing patient: LIDC-IDRI-0936
# Skipped Nodule ID 2471 due to high std.
# Skipped Nodule ID 2472 due to high std.
# Processing patient: LIDC-IDRI-0938
# Skipped Nodule ID 2473 due to high std.
# Processing patient: LIDC-IDRI-0939
# Skipped Nodule ID 2476 due to high std.
# Processing patient: LIDC-IDRI-0940
# Skipped Nodule ID 2477 due to high std.
# Processing patient: LIDC-IDRI-0941
# Skipped Nodule ID 2479 due to high std.
# Processing patient: LIDC-IDRI-0942
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 2480 due to high std.
# Skipped Nodule ID 2481 due to high std.
# Processing patient: LIDC-IDRI-0943
# Processing patient: LIDC-IDRI-0944
# Skipped Nodule ID 2486 due to high std.
# Processing patient: LIDC-IDRI-0945
# Processing patient: LIDC-IDRI-0946
# Skipped Nodule ID 2488 due to high std.
# Processing patient: LIDC-IDRI-0947
# Skipped Nodule ID 2491 due to high std.
# Processing patient: LIDC-IDRI-0949
# Skipped Nodule ID 2496 due to high std.
# Skipped Nodule ID 2497 due to high std.
# Processing patient: LIDC-IDRI-0950
# Processing patient: LIDC-IDRI-0951
# Skipped Nodule ID 2501 due to high std.
# Skipped Nodule ID 2503 due to high std.
# Processing patient: LIDC-IDRI-0953
# Skipped Nodule ID 2506 due to high std.
# Processing patient: LIDC-IDRI-0955
# Processing patient: LIDC-IDRI-0956
# Skipped Nodule ID 2509 due to high std.
# Skipped Nodule ID 2510 due to high std.
# Processing patient: LIDC-IDRI-0957
# Skipped Nodule ID 2511 due to high std.
# Skipped Nodule ID 2512 due to high std.
# Processing patient: LIDC-IDRI-0958
# Processing patient: LIDC-IDRI-0959
# Processing patient: LIDC-IDRI-0961
# Skipped Nodule ID 2517 due to high std.
# Skipped Nodule ID 2523 due to high std.
# Skipped Nodule ID 2524 due to high std.
# Processing patient: LIDC-IDRI-0962
# Processing patient: LIDC-IDRI-0963
# Skipped Nodule ID 2527 due to high std.
# Processing patient: LIDC-IDRI-0965
# Skipped Nodule ID 2528 due to high std.
# Processing patient: LIDC-IDRI-0966
# Skipped Nodule ID 2529 due to high std.
# Skipped Nodule ID 2530 due to high std.
# Processing patient: LIDC-IDRI-0968
# Skipped Nodule ID 2533 due to high std.
# Processing patient: LIDC-IDRI-0969
# Skipped Nodule ID 2536 due to high std.
# Processing patient: LIDC-IDRI-0971
# Processing patient: LIDC-IDRI-0972
# Processing patient: LIDC-IDRI-0973
# Skipped Nodule ID 2542 due to high std.
# Processing patient: LIDC-IDRI-0974
# Skipped Nodule ID 2545 due to high std.
# Processing patient: LIDC-IDRI-0976
# Processing patient: LIDC-IDRI-0977
# Processing patient: LIDC-IDRI-0978
# Skipped Nodule ID 2552 due to high std.
# Skipped Nodule ID 2555 due to high std.
# Processing patient: LIDC-IDRI-0980
# Skipped Nodule ID 2556 due to high std.
# Skipped Nodule ID 2558 due to high std.
# Processing patient: LIDC-IDRI-0981
# Skipped Nodule ID 2559 due to high std.
# Processing patient: LIDC-IDRI-0982
# Skipped Nodule ID 2560 due to high std.
# Skipped Nodule ID 2561 due to high std.
# Processing patient: LIDC-IDRI-0983
# Processing patient: LIDC-IDRI-0984
# Skipped Nodule ID 2564 due to high std.
# Processing patient: LIDC-IDRI-0985
# Skipped Nodule ID 2565 due to high std.
# Processing patient: LIDC-IDRI-0986
# Processing patient: LIDC-IDRI-0987
# Skipped Nodule ID 2571 due to high std.
# Processing patient: LIDC-IDRI-0989
# Processing patient: LIDC-IDRI-0990
# Processing patient: LIDC-IDRI-0991
# Skipped Nodule ID 2576 due to high std.
# Processing patient: LIDC-IDRI-0993
# Processing patient: LIDC-IDRI-0994
# Skipped Nodule ID 2581 due to high std.
# Skipped Nodule ID 2582 due to high std.
# Processing patient: LIDC-IDRI-0996
# Processing patient: LIDC-IDRI-0997
# Skipped Nodule ID 2589 due to high std.
# Processing patient: LIDC-IDRI-0998
# Skipped Nodule ID 2596 due to high std.
# Skipped Nodule ID 2597 due to high std.
# Skipped Nodule ID 2598 due to high std.
# Skipped Nodule ID 2600 due to high std.
# Processing patient: LIDC-IDRI-0999
# Skipped Nodule ID 2602 due to high std.
# Skipped Nodule ID 2604 due to high std.
# Processing patient: LIDC-IDRI-1000
# Skipped Nodule ID 2606 due to high std.
# Skipped Nodule ID 2608 due to high std.
# Skipped Nodule ID 2609 due to high std.
# Processing patient: LIDC-IDRI-1001
# Skipped Nodule ID 2612 due to high std.
# Processing patient: LIDC-IDRI-1002
# Skipped Nodule ID 2613 due to high std.
# Skipped Nodule ID 2614 due to high std.
# Skipped Nodule ID 2615 due to high std.
# Processing patient: LIDC-IDRI-1003
# Skipped Nodule ID 2618 due to high std.
# Skipped Nodule ID 2619 due to high std.
# Skipped Nodule ID 2620 due to high std.
# Skipped Nodule ID 2622 due to high std.
# Processing patient: LIDC-IDRI-1004
# Skipped Nodule ID 2627 due to high std.
# Processing patient: LIDC-IDRI-1005
# Processing patient: LIDC-IDRI-1006
# Processing patient: LIDC-IDRI-1007
# Skipped Nodule ID 2637 due to high std.
# Skipped Nodule ID 2638 due to high std.
# Processing patient: LIDC-IDRI-1008
# Skipped Nodule ID 2643 due to high std.
# Processing patient: LIDC-IDRI-1009
# Processing patient: LIDC-IDRI-1010
# Processing patient: LIDC-IDRI-1011
# Skipped Nodule ID 2647 due to high std.
# Skipped Nodule ID 2648 due to high std.
# Skipped Nodule ID 2649 due to high std.
# Processing patient: LIDC-IDRI-1012
# Skipped Nodule ID 2651 due to high std.
# ✅ Feature extraction complete and CSV saved.

# %% [markdown]
# #### std_limit = 1.5

# %%
import os
import numpy as np
import pandas as pd
import pylidc as pl
from pylidc.utils import consensus

# Paths
input_directory = "C:/Users/user/Desktop/PI_project/images/LIDC-IDRI"
params_file = "C:/Users/user/Desktop/PI_project/radiomics_config/Params.yaml"
path = "C:/Users/user/Desktop/PI_project/std_limit_1.5"
external_drive_path = "C:/Users/user/Desktop/PI_project"  # Path to save CSV

# ✅ Ensure output folder exists
os.makedirs(path, exist_ok=True)

# Initialize patient folders
patient_folders = sorted(os.listdir(input_directory))
nodule_id = 0

# Dictionary to collect nodule data
nodule_data = {
    'Nodule_id': [],
    'Patient_id': [],
    'Subtlety': [],
    'Internalstructure': [],
    'Calcification': [],
    'Sphericity': [],
    'Margin': [],
    'Lobulation': [],
    'Spiculation': [],
    'Texture': [],
    'Malignancy': []
}

malignancy_names = {
    1: "1-Highly Unlikely",
    2: "2-Moderately Unlikely",
    3: "3-Indeterminate",
    4: "4-Moderately Suspicious",
    5: "5-Highly Suspicious"
}

std_limit = 1.5

# Process each patient
for patient_folder in patient_folders:
    patient_folder_path = os.path.join(input_directory, patient_folder)
    patient_id = os.path.basename(patient_folder_path)
    print(f"Processing patient: {patient_id}")
    
    patient_scans = pl.query(pl.Scan).filter(pl.Scan.patient_id == patient_id, pl.Scan.annotations.any()).all()
    
    for scan in patient_scans:
        nods = scan.cluster_annotations()
        
        for anns in nods:
            nodule_id += 1
            nodule_characteristics = []

            # 50% consensus mask
            cmask, cbbox, masks = consensus(anns, clevel=0.5, pad=[(20, 20), (20, 20), (0, 0)])

            for i, mask in enumerate(masks):
                characteristics = anns[i].feature_vals()
                nodule_characteristics.append(characteristics)

            if nodule_characteristics:
                std_deviations = [np.std(characteristic) for characteristic in zip(*nodule_characteristics)]
                
                # Skip if any feature has std > limit
                if any(std > std_limit for std in std_deviations):
                    print(f"Skipped Nodule ID {nodule_id} due to high std.")
                    continue

                # ✅ Save cmask
                filename = os.path.join(path, f"{nodule_id}_cmask.npy")
                np.save(filename, cmask)

                # Optional volume save — uncomment if needed and storage allows
                # volume = anns[0].scan.to_volume()
                # filename = os.path.join(path, f"{nodule_id}_volume.npy")
                # np.save(filename, volume)

                # Extract characteristics (from first annotation)
                feature_values = {
                    'Nodule_id': nodule_id,
                    'Patient_id': patient_id,
                    'Subtlety': nodule_characteristics[0][0],
                    'Internalstructure': nodule_characteristics[0][1],
                    'Calcification': nodule_characteristics[0][2],
                    'Sphericity': nodule_characteristics[0][3],
                    'Margin': nodule_characteristics[0][4],
                    'Lobulation': nodule_characteristics[0][5],
                    'Spiculation': nodule_characteristics[0][6],
                    'Texture': nodule_characteristics[0][7],
                    'Malignancy': malignancy_names.get(nodule_characteristics[0][8])
                }

                for key, value in feature_values.items():
                    nodule_data[key].append(value)

# Save features to CSV
features = pd.DataFrame(nodule_data)
csv_filename = os.path.join(external_drive_path, 'features_pylidc_1.5.csv')
features.to_csv(csv_filename, index=False)

print("✅ Feature extraction complete and CSV saved.")
# Out:
# Processing patient: LICENSE
# Processing patient: LIDC-IDRI-0001
# Processing patient: LIDC-IDRI-0002
# Processing patient: LIDC-IDRI-0003
# Processing patient: LIDC-IDRI-0004
# Processing patient: LIDC-IDRI-0005
# Processing patient: LIDC-IDRI-0006
# Processing patient: LIDC-IDRI-0007
# Processing patient: LIDC-IDRI-0008
# Skipped Nodule ID 17 due to high std.
# Processing patient: LIDC-IDRI-0009
# Processing patient: LIDC-IDRI-0010
# Processing patient: LIDC-IDRI-0011
# Processing patient: LIDC-IDRI-0012
# Processing patient: LIDC-IDRI-0013
# Processing patient: LIDC-IDRI-0014
# Processing patient: LIDC-IDRI-0015
# Processing patient: LIDC-IDRI-0016
# Skipped Nodule ID 54 due to high std.
# Skipped Nodule ID 55 due to high std.
# Processing patient: LIDC-IDRI-0017
# Processing patient: LIDC-IDRI-0018
# Skipped Nodule ID 61 due to high std.
# Processing patient: LIDC-IDRI-0019
# Processing patient: LIDC-IDRI-0020
# Processing patient: LIDC-IDRI-0021
# Processing patient: LIDC-IDRI-0022
# Processing patient: LIDC-IDRI-0023
# Processing patient: LIDC-IDRI-0024
# Processing patient: LIDC-IDRI-0025
# Processing patient: LIDC-IDRI-0026
# Processing patient: LIDC-IDRI-0027
# Skipped Nodule ID 81 due to high std.
# Processing patient: LIDC-IDRI-0029
# Processing patient: LIDC-IDRI-0030
# Processing patient: LIDC-IDRI-0031
# Processing patient: LIDC-IDRI-0033
# Processing patient: LIDC-IDRI-0034
# Processing patient: LIDC-IDRI-0035
# Processing patient: LIDC-IDRI-0036
# Processing patient: LIDC-IDRI-0037
# Processing patient: LIDC-IDRI-0038
# Processing patient: LIDC-IDRI-0039
# Skipped Nodule ID 104 due to high std.
# Processing patient: LIDC-IDRI-0040
# Processing patient: LIDC-IDRI-0041
# Processing patient: LIDC-IDRI-0042
# Processing patient: LIDC-IDRI-0043
# Processing patient: LIDC-IDRI-0044
# Processing patient: LIDC-IDRI-0045
# Skipped Nodule ID 132 due to high std.
# Processing patient: LIDC-IDRI-0046
# Skipped Nodule ID 144 due to high std.
# Skipped Nodule ID 145 due to high std.
# Processing patient: LIDC-IDRI-0047
# Processing patient: LIDC-IDRI-0048
# Skipped Nodule ID 150 due to high std.
# Skipped Nodule ID 152 due to high std.
# Processing patient: LIDC-IDRI-0049
# Skipped Nodule ID 154 due to high std.
# Skipped Nodule ID 155 due to high std.
# Skipped Nodule ID 164 due to high std.
# Processing patient: LIDC-IDRI-0050
# Skipped Nodule ID 168 due to high std.
# Processing patient: LIDC-IDRI-0051
# Processing patient: LIDC-IDRI-0052
# Processing patient: LIDC-IDRI-0053
# Processing patient: LIDC-IDRI-0054
# Processing patient: LIDC-IDRI-0055
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0056
# Processing patient: LIDC-IDRI-0057
# Processing patient: LIDC-IDRI-0058
# Processing patient: LIDC-IDRI-0059
# Processing patient: LIDC-IDRI-0060
# Processing patient: LIDC-IDRI-0061
# Processing patient: LIDC-IDRI-0063
# Processing patient: LIDC-IDRI-0064
# Processing patient: LIDC-IDRI-0065
# Processing patient: LIDC-IDRI-0066
# Processing patient: LIDC-IDRI-0067
# Skipped Nodule ID 215 due to high std.
# Skipped Nodule ID 217 due to high std.
# Processing patient: LIDC-IDRI-0068
# Processing patient: LIDC-IDRI-0069
# Skipped Nodule ID 224 due to high std.
# Processing patient: LIDC-IDRI-0070
# Processing patient: LIDC-IDRI-0072
# Processing patient: LIDC-IDRI-0073
# Processing patient: LIDC-IDRI-0074
# Processing patient: LIDC-IDRI-0075
# Processing patient: LIDC-IDRI-0076
# Processing patient: LIDC-IDRI-0077
# Processing patient: LIDC-IDRI-0078
# Processing patient: LIDC-IDRI-0079
# Processing patient: LIDC-IDRI-0080
# Skipped Nodule ID 249 due to high std.
# Processing patient: LIDC-IDRI-0081
# Skipped Nodule ID 251 due to high std.
# Processing patient: LIDC-IDRI-0082
# Processing patient: LIDC-IDRI-0083
# Processing patient: LIDC-IDRI-0084
# Processing patient: LIDC-IDRI-0085
# Processing patient: LIDC-IDRI-0086
# Processing patient: LIDC-IDRI-0087
# Processing patient: LIDC-IDRI-0088
# Processing patient: LIDC-IDRI-0089
# Processing patient: LIDC-IDRI-0090
# Processing patient: LIDC-IDRI-0091
# Skipped Nodule ID 274 due to high std.
# Processing patient: LIDC-IDRI-0092
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0093
# Processing patient: LIDC-IDRI-0094
# Processing patient: LIDC-IDRI-0095
# Processing patient: LIDC-IDRI-0096
# Processing patient: LIDC-IDRI-0097
# Processing patient: LIDC-IDRI-0098
# Skipped Nodule ID 288 due to high std.
# Processing patient: LIDC-IDRI-0099
# Processing patient: LIDC-IDRI-0101
# Processing patient: LIDC-IDRI-0102
# Processing patient: LIDC-IDRI-0103
# Processing patient: LIDC-IDRI-0104
# Processing patient: LIDC-IDRI-0105
# Processing patient: LIDC-IDRI-0106
# Processing patient: LIDC-IDRI-0107
# Processing patient: LIDC-IDRI-0108
# Skipped Nodule ID 310 due to high std.
# Processing patient: LIDC-IDRI-0109
# Processing patient: LIDC-IDRI-0110
# Processing patient: LIDC-IDRI-0111
# Processing patient: LIDC-IDRI-0112
# Processing patient: LIDC-IDRI-0113
# Processing patient: LIDC-IDRI-0114
# Processing patient: LIDC-IDRI-0115
# Processing patient: LIDC-IDRI-0116
# Processing patient: LIDC-IDRI-0117
# Skipped Nodule ID 327 due to high std.
# Processing patient: LIDC-IDRI-0118
# Processing patient: LIDC-IDRI-0119
# Processing patient: LIDC-IDRI-0120
# Processing patient: LIDC-IDRI-0121
# Processing patient: LIDC-IDRI-0122
# Processing patient: LIDC-IDRI-0123
# Processing patient: LIDC-IDRI-0124
# Processing patient: LIDC-IDRI-0125
# Processing patient: LIDC-IDRI-0126
# Processing patient: LIDC-IDRI-0127
# Skipped Nodule ID 364 due to high std.
# Processing patient: LIDC-IDRI-0128
# Skipped Nodule ID 367 due to high std.
# Processing patient: LIDC-IDRI-0129
# Skipped Nodule ID 379 due to high std.
# Processing patient: LIDC-IDRI-0130
# Skipped Nodule ID 383 due to high std.
# Skipped Nodule ID 384 due to high std.
# Processing patient: LIDC-IDRI-0131
# Processing patient: LIDC-IDRI-0132
# Processing patient: LIDC-IDRI-0133
# Processing patient: LIDC-IDRI-0134
# Processing patient: LIDC-IDRI-0135
# Processing patient: LIDC-IDRI-0136
# Processing patient: LIDC-IDRI-0137
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0138
# Processing patient: LIDC-IDRI-0139
# Processing patient: LIDC-IDRI-0140
# Processing patient: LIDC-IDRI-0141
# Skipped Nodule ID 430 due to high std.
# Processing patient: LIDC-IDRI-0142
# Processing patient: LIDC-IDRI-0144
# Processing patient: LIDC-IDRI-0145
# Processing patient: LIDC-IDRI-0146
# Processing patient: LIDC-IDRI-0147
# Processing patient: LIDC-IDRI-0148
# Processing patient: LIDC-IDRI-0149
# Processing patient: LIDC-IDRI-0150
# Processing patient: LIDC-IDRI-0151
# Processing patient: LIDC-IDRI-0152
# Processing patient: LIDC-IDRI-0153
# Processing patient: LIDC-IDRI-0154
# Processing patient: LIDC-IDRI-0155
# Processing patient: LIDC-IDRI-0156
# Processing patient: LIDC-IDRI-0157
# Processing patient: LIDC-IDRI-0158
# Skipped Nodule ID 480 due to high std.
# Processing patient: LIDC-IDRI-0159
# Processing patient: LIDC-IDRI-0160
# Processing patient: LIDC-IDRI-0161
# Processing patient: LIDC-IDRI-0162
# Skipped Nodule ID 493 due to high std.
# Processing patient: LIDC-IDRI-0163
# Skipped Nodule ID 494 due to high std.
# Processing patient: LIDC-IDRI-0164
# Processing patient: LIDC-IDRI-0165
# Processing patient: LIDC-IDRI-0166
# Processing patient: LIDC-IDRI-0167
# Processing patient: LIDC-IDRI-0168
# Processing patient: LIDC-IDRI-0169
# Processing patient: LIDC-IDRI-0170
# Skipped Nodule ID 517 due to high std.
# Processing patient: LIDC-IDRI-0171
# Processing patient: LIDC-IDRI-0172
# Processing patient: LIDC-IDRI-0173
# Processing patient: LIDC-IDRI-0175
# Processing patient: LIDC-IDRI-0176
# Processing patient: LIDC-IDRI-0177
# Processing patient: LIDC-IDRI-0178
# Processing patient: LIDC-IDRI-0179
# Processing patient: LIDC-IDRI-0180
# Processing patient: LIDC-IDRI-0181
# Skipped Nodule ID 550 due to high std.
# Processing patient: LIDC-IDRI-0182
# Processing patient: LIDC-IDRI-0183
# Processing patient: LIDC-IDRI-0184
# Processing patient: LIDC-IDRI-0185
# Processing patient: LIDC-IDRI-0186
# Processing patient: LIDC-IDRI-0187
# Skipped Nodule ID 572 due to high std.
# Processing patient: LIDC-IDRI-0188
# Processing patient: LIDC-IDRI-0190
# Processing patient: LIDC-IDRI-0191
# Processing patient: LIDC-IDRI-0192
# Processing patient: LIDC-IDRI-0193
# Processing patient: LIDC-IDRI-0194
# Processing patient: LIDC-IDRI-0195
# Skipped Nodule ID 599 due to high std.
# Processing patient: LIDC-IDRI-0196
# Processing patient: LIDC-IDRI-0198
# Processing patient: LIDC-IDRI-0199
# Processing patient: LIDC-IDRI-0200
# Processing patient: LIDC-IDRI-0201
# Processing patient: LIDC-IDRI-0202
# Skipped Nodule ID 618 due to high std.
# Processing patient: LIDC-IDRI-0203
# Processing patient: LIDC-IDRI-0204
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 621 due to high std.
# Processing patient: LIDC-IDRI-0206
# Processing patient: LIDC-IDRI-0207
# Processing patient: LIDC-IDRI-0208
# Skipped Nodule ID 629 due to high std.
# Processing patient: LIDC-IDRI-0209
# Processing patient: LIDC-IDRI-0210
# Processing patient: LIDC-IDRI-0211
# Processing patient: LIDC-IDRI-0212
# Processing patient: LIDC-IDRI-0213
# Processing patient: LIDC-IDRI-0215
# Skipped Nodule ID 638 due to high std.
# Skipped Nodule ID 639 due to high std.
# Processing patient: LIDC-IDRI-0216
# Processing patient: LIDC-IDRI-0217
# Processing patient: LIDC-IDRI-0219
# Processing patient: LIDC-IDRI-0220
# Processing patient: LIDC-IDRI-0221
# Processing patient: LIDC-IDRI-0222
# Processing patient: LIDC-IDRI-0223
# Skipped Nodule ID 652 due to high std.
# Skipped Nodule ID 654 due to high std.
# Processing patient: LIDC-IDRI-0227
# Processing patient: LIDC-IDRI-0228
# Processing patient: LIDC-IDRI-0229
# Skipped Nodule ID 657 due to high std.
# Processing patient: LIDC-IDRI-0230
# Processing patient: LIDC-IDRI-0231
# Processing patient: LIDC-IDRI-0232
# Processing patient: LIDC-IDRI-0233
# Processing patient: LIDC-IDRI-0234
# Processing patient: LIDC-IDRI-0235
# Processing patient: LIDC-IDRI-0236
# Processing patient: LIDC-IDRI-0237
# Skipped Nodule ID 680 due to high std.
# Processing patient: LIDC-IDRI-0240
# Processing patient: LIDC-IDRI-0241
# Skipped Nodule ID 689 due to high std.
# Skipped Nodule ID 690 due to high std.
# Processing patient: LIDC-IDRI-0242
# Skipped Nodule ID 691 due to high std.
# Processing patient: LIDC-IDRI-0243
# Processing patient: LIDC-IDRI-0244
# Processing patient: LIDC-IDRI-0245
# Processing patient: LIDC-IDRI-0246
# Skipped Nodule ID 698 due to high std.
# Processing patient: LIDC-IDRI-0247
# Processing patient: LIDC-IDRI-0248
# Processing patient: LIDC-IDRI-0249
# Processing patient: LIDC-IDRI-0250
# Processing patient: LIDC-IDRI-0251
# Processing patient: LIDC-IDRI-0252
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0254
# Processing patient: LIDC-IDRI-0255
# Processing patient: LIDC-IDRI-0256
# Processing patient: LIDC-IDRI-0257
# Processing patient: LIDC-IDRI-0258
# Processing patient: LIDC-IDRI-0259
# Processing patient: LIDC-IDRI-0260
# Processing patient: LIDC-IDRI-0262
# Processing patient: LIDC-IDRI-0263
# Processing patient: LIDC-IDRI-0264
# Processing patient: LIDC-IDRI-0265
# Processing patient: LIDC-IDRI-0266
# Processing patient: LIDC-IDRI-0267
# Processing patient: LIDC-IDRI-0268
# Processing patient: LIDC-IDRI-0269
# Processing patient: LIDC-IDRI-0270
# Skipped Nodule ID 733 due to high std.
# Processing patient: LIDC-IDRI-0271
# Processing patient: LIDC-IDRI-0272
# Processing patient: LIDC-IDRI-0273
# Processing patient: LIDC-IDRI-0274
# Processing patient: LIDC-IDRI-0275
# Processing patient: LIDC-IDRI-0276
# Processing patient: LIDC-IDRI-0277
# Processing patient: LIDC-IDRI-0278
# Processing patient: LIDC-IDRI-0280
# Processing patient: LIDC-IDRI-0281
# Skipped Nodule ID 746 due to high std.
# Processing patient: LIDC-IDRI-0282
# Processing patient: LIDC-IDRI-0283
# Processing patient: LIDC-IDRI-0284
# Processing patient: LIDC-IDRI-0285
# Processing patient: LIDC-IDRI-0286
# Processing patient: LIDC-IDRI-0287
# Processing patient: LIDC-IDRI-0288
# Processing patient: LIDC-IDRI-0289
# Processing patient: LIDC-IDRI-0290
# Processing patient: LIDC-IDRI-0291
# Processing patient: LIDC-IDRI-0292
# Processing patient: LIDC-IDRI-0294
# Skipped Nodule ID 769 due to high std.
# Processing patient: LIDC-IDRI-0296
# Processing patient: LIDC-IDRI-0297
# Processing patient: LIDC-IDRI-0298
# Skipped Nodule ID 778 due to high std.
# Processing patient: LIDC-IDRI-0299
# Processing patient: LIDC-IDRI-0300
# Processing patient: LIDC-IDRI-0301
# Processing patient: LIDC-IDRI-0302
# Processing patient: LIDC-IDRI-0303
# Processing patient: LIDC-IDRI-0304
# Processing patient: LIDC-IDRI-0305
# Processing patient: LIDC-IDRI-0308
# Processing patient: LIDC-IDRI-0309
# Processing patient: LIDC-IDRI-0310
# Processing patient: LIDC-IDRI-0311
# Processing patient: LIDC-IDRI-0312
# Processing patient: LIDC-IDRI-0313
# Skipped Nodule ID 816 due to high std.
# Processing patient: LIDC-IDRI-0314
# Processing patient: LIDC-IDRI-0315
# Skipped Nodule ID 826 due to high std.
# Skipped Nodule ID 828 due to high std.
# Processing patient: LIDC-IDRI-0317
# Processing patient: LIDC-IDRI-0318
# Processing patient: LIDC-IDRI-0319
# Processing patient: LIDC-IDRI-0320
# Processing patient: LIDC-IDRI-0321
# Processing patient: LIDC-IDRI-0323
# Processing patient: LIDC-IDRI-0324
# Processing patient: LIDC-IDRI-0325
# Processing patient: LIDC-IDRI-0326
# Processing patient: LIDC-IDRI-0328
# Processing patient: LIDC-IDRI-0329
# Processing patient: LIDC-IDRI-0332
# Skipped Nodule ID 852 due to high std.
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0334
# Skipped Nodule ID 863 due to high std.
# Skipped Nodule ID 864 due to high std.
# Processing patient: LIDC-IDRI-0335
# Processing patient: LIDC-IDRI-0337
# Skipped Nodule ID 873 due to high std.
# Processing patient: LIDC-IDRI-0338
# Processing patient: LIDC-IDRI-0339
# Skipped Nodule ID 876 due to high std.
# Processing patient: LIDC-IDRI-0340
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0341
# Processing patient: LIDC-IDRI-0343
# Processing patient: LIDC-IDRI-0344
# Processing patient: LIDC-IDRI-0345
# Processing patient: LIDC-IDRI-0346
# Processing patient: LIDC-IDRI-0347
# Skipped Nodule ID 900 due to high std.
# Processing patient: LIDC-IDRI-0348
# Skipped Nodule ID 902 due to high std.
# Processing patient: LIDC-IDRI-0350
# Processing patient: LIDC-IDRI-0351
# Processing patient: LIDC-IDRI-0352
# Skipped Nodule ID 908 due to high std.
# Processing patient: LIDC-IDRI-0353
# Skipped Nodule ID 911 due to high std.
# Processing patient: LIDC-IDRI-0354
# Skipped Nodule ID 912 due to high std.
# Processing patient: LIDC-IDRI-0355
# Processing patient: LIDC-IDRI-0356
# Processing patient: LIDC-IDRI-0357
# Processing patient: LIDC-IDRI-0358
# Skipped Nodule ID 933 due to high std.
# Processing patient: LIDC-IDRI-0359
# Skipped Nodule ID 934 due to high std.
# Skipped Nodule ID 935 due to high std.
# Processing patient: LIDC-IDRI-0360
# Skipped Nodule ID 936 due to high std.
# Processing patient: LIDC-IDRI-0362
# Processing patient: LIDC-IDRI-0363
# Processing patient: LIDC-IDRI-0365
# Processing patient: LIDC-IDRI-0366
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0367
# Processing patient: LIDC-IDRI-0368
# Processing patient: LIDC-IDRI-0369
# Processing patient: LIDC-IDRI-0370
# Processing patient: LIDC-IDRI-0371
# Processing patient: LIDC-IDRI-0372
# Processing patient: LIDC-IDRI-0373
# Skipped Nodule ID 960 due to high std.
# Processing patient: LIDC-IDRI-0374
# Processing patient: LIDC-IDRI-0375
# Skipped Nodule ID 965 due to high std.
# Processing patient: LIDC-IDRI-0376
# Processing patient: LIDC-IDRI-0377
# Processing patient: LIDC-IDRI-0378
# Processing patient: LIDC-IDRI-0379
# Skipped Nodule ID 972 due to high std.
# Processing patient: LIDC-IDRI-0380
# Skipped Nodule ID 977 due to high std.
# Skipped Nodule ID 978 due to high std.
# Skipped Nodule ID 979 due to high std.
# Processing patient: LIDC-IDRI-0381
# Processing patient: LIDC-IDRI-0384
# Processing patient: LIDC-IDRI-0385
# Processing patient: LIDC-IDRI-0386
# Skipped Nodule ID 990 due to high std.
# Processing patient: LIDC-IDRI-0387
# Processing patient: LIDC-IDRI-0388
# Processing patient: LIDC-IDRI-0390
# Processing patient: LIDC-IDRI-0392
# Processing patient: LIDC-IDRI-0393
# Processing patient: LIDC-IDRI-0394
# Skipped Nodule ID 1013 due to high std.
# Skipped Nodule ID 1016 due to high std.
# Processing patient: LIDC-IDRI-0395
# Processing patient: LIDC-IDRI-0396
# Processing patient: LIDC-IDRI-0397
# Processing patient: LIDC-IDRI-0398
# Processing patient: LIDC-IDRI-0399
# Processing patient: LIDC-IDRI-0400
# Processing patient: LIDC-IDRI-0402
# Processing patient: LIDC-IDRI-0403
# Processing patient: LIDC-IDRI-0404
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Skipped Nodule ID 1059 due to high std.
# Processing patient: LIDC-IDRI-0405
# Skipped Nodule ID 1064 due to high std.
# Processing patient: LIDC-IDRI-0406
# Skipped Nodule ID 1069 due to high std.
# Processing patient: LIDC-IDRI-0407
# Skipped Nodule ID 1071 due to high std.
# Skipped Nodule ID 1073 due to high std.
# Processing patient: LIDC-IDRI-0408
# Processing patient: LIDC-IDRI-0409
# Processing patient: LIDC-IDRI-0411
# Processing patient: LIDC-IDRI-0412
# Processing patient: LIDC-IDRI-0413
# Processing patient: LIDC-IDRI-0414
# Processing patient: LIDC-IDRI-0415
# Skipped Nodule ID 1096 due to high std.
# Skipped Nodule ID 1097 due to high std.
# Skipped Nodule ID 1098 due to high std.
# Skipped Nodule ID 1100 due to high std.
# Skipped Nodule ID 1101 due to high std.
# Processing patient: LIDC-IDRI-0416
# Processing patient: LIDC-IDRI-0419
# Processing patient: LIDC-IDRI-0420
# Processing patient: LIDC-IDRI-0421
# Processing patient: LIDC-IDRI-0423
# Processing patient: LIDC-IDRI-0424
# Processing patient: LIDC-IDRI-0426
# Processing patient: LIDC-IDRI-0427
# Skipped Nodule ID 1117 due to high std.
# Processing patient: LIDC-IDRI-0429
# Processing patient: LIDC-IDRI-0430
# Processing patient: LIDC-IDRI-0431
# Processing patient: LIDC-IDRI-0432
# Processing patient: LIDC-IDRI-0433
# Processing patient: LIDC-IDRI-0434
# Skipped Nodule ID 1133 due to high std.
# Processing patient: LIDC-IDRI-0435
# Processing patient: LIDC-IDRI-0436
# Processing patient: LIDC-IDRI-0437
# Processing patient: LIDC-IDRI-0438
# Processing patient: LIDC-IDRI-0439
# Processing patient: LIDC-IDRI-0440
# Skipped Nodule ID 1153 due to high std.
# Processing patient: LIDC-IDRI-0442
# Skipped Nodule ID 1158 due to high std.
# Processing patient: LIDC-IDRI-0443
# Skipped Nodule ID 1162 due to high std.
# Processing patient: LIDC-IDRI-0444
# Skipped Nodule ID 1164 due to high std.
# Processing patient: LIDC-IDRI-0445
# Processing patient: LIDC-IDRI-0447
# Processing patient: LIDC-IDRI-0448
# Processing patient: LIDC-IDRI-0449
# Processing patient: LIDC-IDRI-0450
# Processing patient: LIDC-IDRI-0451
# Processing patient: LIDC-IDRI-0452
# Skipped Nodule ID 1190 due to high std.
# Processing patient: LIDC-IDRI-0453
# Processing patient: LIDC-IDRI-0454
# Processing patient: LIDC-IDRI-0456
# Skipped Nodule ID 1200 due to high std.
# Processing patient: LIDC-IDRI-0457
# Processing patient: LIDC-IDRI-0458
# Processing patient: LIDC-IDRI-0459
# Processing patient: LIDC-IDRI-0460
# Processing patient: LIDC-IDRI-0461
# Processing patient: LIDC-IDRI-0462
# Processing patient: LIDC-IDRI-0463
# Processing patient: LIDC-IDRI-0464
# Processing patient: LIDC-IDRI-0466
# Skipped Nodule ID 1232 due to high std.
# Processing patient: LIDC-IDRI-0467
# Processing patient: LIDC-IDRI-0468
# Processing patient: LIDC-IDRI-0469
# Skipped Nodule ID 1237 due to high std.
# Processing patient: LIDC-IDRI-0470
# Processing patient: LIDC-IDRI-0471
# Processing patient: LIDC-IDRI-0473
# Skipped Nodule ID 1249 due to high std.
# Processing patient: LIDC-IDRI-0474
# Processing patient: LIDC-IDRI-0475
# Skipped Nodule ID 1257 due to high std.
# Processing patient: LIDC-IDRI-0476
# Processing patient: LIDC-IDRI-0477
# Processing patient: LIDC-IDRI-0478
# Processing patient: LIDC-IDRI-0479
# Skipped Nodule ID 1271 due to high std.
# Processing patient: LIDC-IDRI-0480
# Processing patient: LIDC-IDRI-0481
# Processing patient: LIDC-IDRI-0483
# Processing patient: LIDC-IDRI-0484
# Processing patient: LIDC-IDRI-0485
# Processing patient: LIDC-IDRI-0486
# Processing patient: LIDC-IDRI-0487
# Processing patient: LIDC-IDRI-0488
# Processing patient: LIDC-IDRI-0489
# Skipped Nodule ID 1306 due to high std.
# Processing patient: LIDC-IDRI-0490
# Processing patient: LIDC-IDRI-0491
# Skipped Nodule ID 1323 due to high std.
# Processing patient: LIDC-IDRI-0492
# Processing patient: LIDC-IDRI-0493
# Processing patient: LIDC-IDRI-0494
# Processing patient: LIDC-IDRI-0495
# Processing patient: LIDC-IDRI-0496
# Skipped Nodule ID 1336 due to high std.
# Processing patient: LIDC-IDRI-0497
# Processing patient: LIDC-IDRI-0498
# Processing patient: LIDC-IDRI-0499
# Processing patient: LIDC-IDRI-0500
# Processing patient: LIDC-IDRI-0501
# Processing patient: LIDC-IDRI-0502
# Processing patient: LIDC-IDRI-0503
# Processing patient: LIDC-IDRI-0504
# Processing patient: LIDC-IDRI-0505
# Processing patient: LIDC-IDRI-0507
# Skipped Nodule ID 1359 due to high std.
# Processing patient: LIDC-IDRI-0508
# Processing patient: LIDC-IDRI-0509
# Processing patient: LIDC-IDRI-0510
# Processing patient: LIDC-IDRI-0515
# Processing patient: LIDC-IDRI-0516
# Processing patient: LIDC-IDRI-0517
# Processing patient: LIDC-IDRI-0518
# Skipped Nodule ID 1384 due to high std.
# Processing patient: LIDC-IDRI-0520
# Processing patient: LIDC-IDRI-0521
# Processing patient: LIDC-IDRI-0522
# Processing patient: LIDC-IDRI-0523
# Processing patient: LIDC-IDRI-0524
# Processing patient: LIDC-IDRI-0525
# Processing patient: LIDC-IDRI-0526
# Skipped Nodule ID 1410 due to high std.
# Processing patient: LIDC-IDRI-0527
# Processing patient: LIDC-IDRI-0529
# Skipped Nodule ID 1416 due to high std.
# Processing patient: LIDC-IDRI-0530
# Processing patient: LIDC-IDRI-0532
# Processing patient: LIDC-IDRI-0533
# Processing patient: LIDC-IDRI-0534
# Processing patient: LIDC-IDRI-0535
# Processing patient: LIDC-IDRI-0537
# Processing patient: LIDC-IDRI-0538
# Processing patient: LIDC-IDRI-0539
# Processing patient: LIDC-IDRI-0541
# Processing patient: LIDC-IDRI-0542
# Processing patient: LIDC-IDRI-0543
# Processing patient: LIDC-IDRI-0545
# Processing patient: LIDC-IDRI-0546
# Processing patient: LIDC-IDRI-0547
# Processing patient: LIDC-IDRI-0549
# Processing patient: LIDC-IDRI-0550
# Processing patient: LIDC-IDRI-0551
# Processing patient: LIDC-IDRI-0552
# Processing patient: LIDC-IDRI-0553
# Processing patient: LIDC-IDRI-0554
# Processing patient: LIDC-IDRI-0555
# Processing patient: LIDC-IDRI-0556
# Processing patient: LIDC-IDRI-0557
# Processing patient: LIDC-IDRI-0558
# Processing patient: LIDC-IDRI-0559
# Processing patient: LIDC-IDRI-0560
# Processing patient: LIDC-IDRI-0562
# Skipped Nodule ID 1471 due to high std.
# Processing patient: LIDC-IDRI-0563
# Processing patient: LIDC-IDRI-0565
# Skipped Nodule ID 1477 due to high std.
# Processing patient: LIDC-IDRI-0566
# Processing patient: LIDC-IDRI-0567
# Processing patient: LIDC-IDRI-0568
# Processing patient: LIDC-IDRI-0569
# Processing patient: LIDC-IDRI-0570
# Processing patient: LIDC-IDRI-0571
# Processing patient: LIDC-IDRI-0572
# Processing patient: LIDC-IDRI-0574
# Processing patient: LIDC-IDRI-0575
# Processing patient: LIDC-IDRI-0576
# Skipped Nodule ID 1501 due to high std.
# Processing patient: LIDC-IDRI-0577
# Processing patient: LIDC-IDRI-0578
# Processing patient: LIDC-IDRI-0579
# Processing patient: LIDC-IDRI-0580
# Processing patient: LIDC-IDRI-0581
# Processing patient: LIDC-IDRI-0582
# Processing patient: LIDC-IDRI-0583
# Skipped Nodule ID 1540 due to high std.
# Processing patient: LIDC-IDRI-0584
# Processing patient: LIDC-IDRI-0586
# Skipped Nodule ID 1545 due to high std.
# Processing patient: LIDC-IDRI-0587
# Skipped Nodule ID 1549 due to high std.
# Skipped Nodule ID 1555 due to high std.
# Processing patient: LIDC-IDRI-0588
# Processing patient: LIDC-IDRI-0590
# Skipped Nodule ID 1558 due to high std.
# Processing patient: LIDC-IDRI-0591
# Processing patient: LIDC-IDRI-0592
# Processing patient: LIDC-IDRI-0593
# Processing patient: LIDC-IDRI-0594
# Processing patient: LIDC-IDRI-0595
# Processing patient: LIDC-IDRI-0596
# Processing patient: LIDC-IDRI-0597
# Processing patient: LIDC-IDRI-0598
# Processing patient: LIDC-IDRI-0599
# Processing patient: LIDC-IDRI-0601
# Skipped Nodule ID 1574 due to high std.
# Skipped Nodule ID 1576 due to high std.
# Skipped Nodule ID 1577 due to high std.
# Processing patient: LIDC-IDRI-0602
# Processing patient: LIDC-IDRI-0604
# Processing patient: LIDC-IDRI-0605
# Processing patient: LIDC-IDRI-0606
# Processing patient: LIDC-IDRI-0607
# Processing patient: LIDC-IDRI-0608
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0609
# Processing patient: LIDC-IDRI-0610
# Processing patient: LIDC-IDRI-0611
# Processing patient: LIDC-IDRI-0613
# Processing patient: LIDC-IDRI-0614
# Processing patient: LIDC-IDRI-0615
# Processing patient: LIDC-IDRI-0617
# Processing patient: LIDC-IDRI-0618
# Processing patient: LIDC-IDRI-0619
# Processing patient: LIDC-IDRI-0620
# Skipped Nodule ID 1624 due to high std.
# Skipped Nodule ID 1625 due to high std.
# Processing patient: LIDC-IDRI-0621
# Processing patient: LIDC-IDRI-0624
# Skipped Nodule ID 1633 due to high std.
# Processing patient: LIDC-IDRI-0625
# Processing patient: LIDC-IDRI-0626
# Processing patient: LIDC-IDRI-0628
# Processing patient: LIDC-IDRI-0629
# Processing patient: LIDC-IDRI-0630
# Processing patient: LIDC-IDRI-0631
# Processing patient: LIDC-IDRI-0633
# Processing patient: LIDC-IDRI-0634
# Processing patient: LIDC-IDRI-0635
# Processing patient: LIDC-IDRI-0636
# Processing patient: LIDC-IDRI-0637
# Processing patient: LIDC-IDRI-0638
# Processing patient: LIDC-IDRI-0639
# Processing patient: LIDC-IDRI-0640
# Skipped Nodule ID 1679 due to high std.
# Processing patient: LIDC-IDRI-0641
# Skipped Nodule ID 1683 due to high std.
# Processing patient: LIDC-IDRI-0642
# Processing patient: LIDC-IDRI-0643
# Processing patient: LIDC-IDRI-0644
# Processing patient: LIDC-IDRI-0645
# Processing patient: LIDC-IDRI-0647
# Processing patient: LIDC-IDRI-0648
# Processing patient: LIDC-IDRI-0649
# Processing patient: LIDC-IDRI-0650
# Processing patient: LIDC-IDRI-0651
# Skipped Nodule ID 1716 due to high std.
# Skipped Nodule ID 1717 due to high std.
# Processing patient: LIDC-IDRI-0652
# Processing patient: LIDC-IDRI-0654
# Processing patient: LIDC-IDRI-0655
# Processing patient: LIDC-IDRI-0656
# Processing patient: LIDC-IDRI-0657
# Processing patient: LIDC-IDRI-0658
# Skipped Nodule ID 1733 due to high std.
# Processing patient: LIDC-IDRI-0659
# Processing patient: LIDC-IDRI-0660
# Processing patient: LIDC-IDRI-0661
# Processing patient: LIDC-IDRI-0662
# Processing patient: LIDC-IDRI-0663
# Skipped Nodule ID 1759 due to high std.
# Processing patient: LIDC-IDRI-0664
# Processing patient: LIDC-IDRI-0666
# Processing patient: LIDC-IDRI-0669
# Processing patient: LIDC-IDRI-0670
# Processing patient: LIDC-IDRI-0671
# Processing patient: LIDC-IDRI-0672
# Processing patient: LIDC-IDRI-0673
# Processing patient: LIDC-IDRI-0674
# Processing patient: LIDC-IDRI-0675
# Processing patient: LIDC-IDRI-0676
# Skipped Nodule ID 1787 due to high std.
# Processing patient: LIDC-IDRI-0677
# Processing patient: LIDC-IDRI-0678
# Processing patient: LIDC-IDRI-0680
# Processing patient: LIDC-IDRI-0681
# Skipped Nodule ID 1793 due to high std.
# Processing patient: LIDC-IDRI-0682
# Skipped Nodule ID 1796 due to high std.
# Processing patient: LIDC-IDRI-0684
# Skipped Nodule ID 1797 due to high std.
# Processing patient: LIDC-IDRI-0686
# Skipped Nodule ID 1802 due to high std.
# Skipped Nodule ID 1809 due to high std.
# Skipped Nodule ID 1812 due to high std.
# Skipped Nodule ID 1813 due to high std.
# Processing patient: LIDC-IDRI-0687
# Processing patient: LIDC-IDRI-0688
# Processing patient: LIDC-IDRI-0692
# Processing patient: LIDC-IDRI-0693
# Processing patient: LIDC-IDRI-0694
# Processing patient: LIDC-IDRI-0695
# Processing patient: LIDC-IDRI-0696
# Processing patient: LIDC-IDRI-0697
# Processing patient: LIDC-IDRI-0698
# Processing patient: LIDC-IDRI-0699
# Processing patient: LIDC-IDRI-0700
# Processing patient: LIDC-IDRI-0701
# Processing patient: LIDC-IDRI-0702
# Processing patient: LIDC-IDRI-0703
# Skipped Nodule ID 1857 due to high std.
# Processing patient: LIDC-IDRI-0704
# Processing patient: LIDC-IDRI-0705
# Processing patient: LIDC-IDRI-0706
# Processing patient: LIDC-IDRI-0707
# Processing patient: LIDC-IDRI-0708
# Processing patient: LIDC-IDRI-0709
# Processing patient: LIDC-IDRI-0712
# Processing patient: LIDC-IDRI-0713
# Processing patient: LIDC-IDRI-0714
# Processing patient: LIDC-IDRI-0715
# Skipped Nodule ID 1888 due to high std.
# Processing patient: LIDC-IDRI-0717
# Processing patient: LIDC-IDRI-0719
# Processing patient: LIDC-IDRI-0720
# Skipped Nodule ID 1893 due to high std.
# Processing patient: LIDC-IDRI-0721
# Processing patient: LIDC-IDRI-0722
# Processing patient: LIDC-IDRI-0723
# Processing patient: LIDC-IDRI-0724
# Processing patient: LIDC-IDRI-0725
# Processing patient: LIDC-IDRI-0726
# Processing patient: LIDC-IDRI-0727
# Processing patient: LIDC-IDRI-0728
# Processing patient: LIDC-IDRI-0729
# Processing patient: LIDC-IDRI-0730
# Skipped Nodule ID 1915 due to high std.
# Processing patient: LIDC-IDRI-0732
# Processing patient: LIDC-IDRI-0733
# Processing patient: LIDC-IDRI-0734
# Processing patient: LIDC-IDRI-0735
# Processing patient: LIDC-IDRI-0736
# Processing patient: LIDC-IDRI-0739
# Processing patient: LIDC-IDRI-0740
# Processing patient: LIDC-IDRI-0741
# Processing patient: LIDC-IDRI-0742
# Skipped Nodule ID 1943 due to high std.
# Processing patient: LIDC-IDRI-0743
# Skipped Nodule ID 1956 due to high std.
# Processing patient: LIDC-IDRI-0744
# Processing patient: LIDC-IDRI-0747
# Processing patient: LIDC-IDRI-0748
# Processing patient: LIDC-IDRI-0749
# Processing patient: LIDC-IDRI-0750
# Processing patient: LIDC-IDRI-0751
# Skipped Nodule ID 1985 due to high std.
# Processing patient: LIDC-IDRI-0752
# Processing patient: LIDC-IDRI-0753
# Skipped Nodule ID 1989 due to high std.
# Processing patient: LIDC-IDRI-0754
# Skipped Nodule ID 1991 due to high std.
# Processing patient: LIDC-IDRI-0756
# Processing patient: LIDC-IDRI-0757
# Processing patient: LIDC-IDRI-0758
# Processing patient: LIDC-IDRI-0759
# Skipped Nodule ID 1999 due to high std.
# Skipped Nodule ID 2002 due to high std.
# Processing patient: LIDC-IDRI-0761
# Processing patient: LIDC-IDRI-0762
# Processing patient: LIDC-IDRI-0763
# Processing patient: LIDC-IDRI-0765
# Processing patient: LIDC-IDRI-0766
# Skipped Nodule ID 2022 due to high std.
# Processing patient: LIDC-IDRI-0767
# Processing patient: LIDC-IDRI-0768
# Processing patient: LIDC-IDRI-0769
# Processing patient: LIDC-IDRI-0770
# Processing patient: LIDC-IDRI-0771
# Processing patient: LIDC-IDRI-0772
# Skipped Nodule ID 2041 due to high std.
# Processing patient: LIDC-IDRI-0773
# Processing patient: LIDC-IDRI-0775
# Skipped Nodule ID 2049 due to high std.
# Skipped Nodule ID 2052 due to high std.
# Skipped Nodule ID 2054 due to high std.
# Skipped Nodule ID 2056 due to high std.
# Processing patient: LIDC-IDRI-0776
# Processing patient: LIDC-IDRI-0777
# Skipped Nodule ID 2064 due to high std.
# Skipped Nodule ID 2065 due to high std.
# Skipped Nodule ID 2066 due to high std.
# Skipped Nodule ID 2068 due to high std.
# Skipped Nodule ID 2069 due to high std.
# Processing patient: LIDC-IDRI-0778
# Processing patient: LIDC-IDRI-0779
# Processing patient: LIDC-IDRI-0780
# Processing patient: LIDC-IDRI-0781
# Processing patient: LIDC-IDRI-0782
# Processing patient: LIDC-IDRI-0783
# Processing patient: LIDC-IDRI-0785
# Skipped Nodule ID 2079 due to high std.
# Skipped Nodule ID 2084 due to high std.
# Processing patient: LIDC-IDRI-0786
# Processing patient: LIDC-IDRI-0787
# Processing patient: LIDC-IDRI-0788
# Skipped Nodule ID 2092 due to high std.
# Processing patient: LIDC-IDRI-0789
# Processing patient: LIDC-IDRI-0790
# Processing patient: LIDC-IDRI-0791
# Processing patient: LIDC-IDRI-0792
# Processing patient: LIDC-IDRI-0793
# Processing patient: LIDC-IDRI-0794
# Processing patient: LIDC-IDRI-0795
# Skipped Nodule ID 2108 due to high std.
# Processing patient: LIDC-IDRI-0796
# Processing patient: LIDC-IDRI-0797
# Processing patient: LIDC-IDRI-0798
# Skipped Nodule ID 2114 due to high std.
# Processing patient: LIDC-IDRI-0799
# Processing patient: LIDC-IDRI-0800
# Skipped Nodule ID 2117 due to high std.
# Processing patient: LIDC-IDRI-0801
# Processing patient: LIDC-IDRI-0802
# Processing patient: LIDC-IDRI-0803
# Processing patient: LIDC-IDRI-0805
# Processing patient: LIDC-IDRI-0806
# Processing patient: LIDC-IDRI-0807
# Processing patient: LIDC-IDRI-0809
# Processing patient: LIDC-IDRI-0810
# Processing patient: LIDC-IDRI-0811
# Processing patient: LIDC-IDRI-0812
# Processing patient: LIDC-IDRI-0813
# Processing patient: LIDC-IDRI-0814
# Processing patient: LIDC-IDRI-0815
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0816
# Skipped Nodule ID 2158 due to high std.
# Processing patient: LIDC-IDRI-0817
# Processing patient: LIDC-IDRI-0818
# Processing patient: LIDC-IDRI-0819
# Processing patient: LIDC-IDRI-0820
# Processing patient: LIDC-IDRI-0821
# Processing patient: LIDC-IDRI-0822
# Skipped Nodule ID 2177 due to high std.
# Processing patient: LIDC-IDRI-0823
# Processing patient: LIDC-IDRI-0824
# Processing patient: LIDC-IDRI-0825
# Skipped Nodule ID 2183 due to high std.
# Processing patient: LIDC-IDRI-0826
# Skipped Nodule ID 2184 due to high std.
# Processing patient: LIDC-IDRI-0827
# Processing patient: LIDC-IDRI-0828
# Processing patient: LIDC-IDRI-0829
# Processing patient: LIDC-IDRI-0830
# Processing patient: LIDC-IDRI-0831
# Processing patient: LIDC-IDRI-0832
# Processing patient: LIDC-IDRI-0833
# Processing patient: LIDC-IDRI-0834
# Processing patient: LIDC-IDRI-0835
# Processing patient: LIDC-IDRI-0836
# Processing patient: LIDC-IDRI-0837
# Skipped Nodule ID 2206 due to high std.
# Skipped Nodule ID 2208 due to high std.
# Processing patient: LIDC-IDRI-0838
# Processing patient: LIDC-IDRI-0840
# Processing patient: LIDC-IDRI-0841
# Processing patient: LIDC-IDRI-0842
# Processing patient: LIDC-IDRI-0843
# Skipped Nodule ID 2222 due to high std.
# Processing patient: LIDC-IDRI-0844
# Processing patient: LIDC-IDRI-0845
# Skipped Nodule ID 2229 due to high std.
# Processing patient: LIDC-IDRI-0846
# Processing patient: LIDC-IDRI-0847
# Processing patient: LIDC-IDRI-0848
# Processing patient: LIDC-IDRI-0849
# Processing patient: LIDC-IDRI-0850
# Skipped Nodule ID 2244 due to high std.
# Processing patient: LIDC-IDRI-0851
# Processing patient: LIDC-IDRI-0852
# Skipped Nodule ID 2250 due to high std.
# Processing patient: LIDC-IDRI-0854
# Processing patient: LIDC-IDRI-0855
# Skipped Nodule ID 2259 due to high std.
# Skipped Nodule ID 2261 due to high std.
# Skipped Nodule ID 2266 due to high std.
# Skipped Nodule ID 2268 due to high std.
# Skipped Nodule ID 2270 due to high std.
# Skipped Nodule ID 2272 due to high std.
# Processing patient: LIDC-IDRI-0856
# Processing patient: LIDC-IDRI-0857
# Processing patient: LIDC-IDRI-0858
# Processing patient: LIDC-IDRI-0859
# Skipped Nodule ID 2289 due to high std.
# Processing patient: LIDC-IDRI-0860
# Skipped Nodule ID 2290 due to high std.
# Processing patient: LIDC-IDRI-0861
# Processing patient: LIDC-IDRI-0863
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0864
# Processing patient: LIDC-IDRI-0865
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0866
# Processing patient: LIDC-IDRI-0867
# Processing patient: LIDC-IDRI-0868
# Processing patient: LIDC-IDRI-0869
# Processing patient: LIDC-IDRI-0870
# Processing patient: LIDC-IDRI-0871
# Processing patient: LIDC-IDRI-0872
# Processing patient: LIDC-IDRI-0873
# Processing patient: LIDC-IDRI-0874
# Processing patient: LIDC-IDRI-0875
# Processing patient: LIDC-IDRI-0879
# Processing patient: LIDC-IDRI-0880
# Processing patient: LIDC-IDRI-0882
# Processing patient: LIDC-IDRI-0883
# Processing patient: LIDC-IDRI-0884
# Processing patient: LIDC-IDRI-0886
# Processing patient: LIDC-IDRI-0888
# Processing patient: LIDC-IDRI-0890
# Processing patient: LIDC-IDRI-0892
# Skipped Nodule ID 2373 due to high std.
# Processing patient: LIDC-IDRI-0893
# Processing patient: LIDC-IDRI-0894
# Processing patient: LIDC-IDRI-0895
# Processing patient: LIDC-IDRI-0896
# Skipped Nodule ID 2388 due to high std.
# Processing patient: LIDC-IDRI-0898
# Processing patient: LIDC-IDRI-0899
# Processing patient: LIDC-IDRI-0902
# Processing patient: LIDC-IDRI-0904
# Processing patient: LIDC-IDRI-0905
# Processing patient: LIDC-IDRI-0906
# Processing patient: LIDC-IDRI-0907
# Processing patient: LIDC-IDRI-0908
# Skipped Nodule ID 2409 due to high std.
# Processing patient: LIDC-IDRI-0909
# Processing patient: LIDC-IDRI-0910
# Skipped Nodule ID 2412 due to high std.
# Processing patient: LIDC-IDRI-0911
# Processing patient: LIDC-IDRI-0912
# Skipped Nodule ID 2416 due to high std.
# Processing patient: LIDC-IDRI-0913
# Processing patient: LIDC-IDRI-0914
# Processing patient: LIDC-IDRI-0915
# Processing patient: LIDC-IDRI-0916
# Processing patient: LIDC-IDRI-0917
# Processing patient: LIDC-IDRI-0919
# Processing patient: LIDC-IDRI-0920
# Processing patient: LIDC-IDRI-0921
# Skipped Nodule ID 2446 due to high std.
# Processing patient: LIDC-IDRI-0922
# Processing patient: LIDC-IDRI-0923
# Processing patient: LIDC-IDRI-0924
# Processing patient: LIDC-IDRI-0925
# Processing patient: LIDC-IDRI-0926
# Processing patient: LIDC-IDRI-0928
# Processing patient: LIDC-IDRI-0929
# Processing patient: LIDC-IDRI-0932
# Processing patient: LIDC-IDRI-0933
# Processing patient: LIDC-IDRI-0935
# Processing patient: LIDC-IDRI-0936
# Processing patient: LIDC-IDRI-0938
# Processing patient: LIDC-IDRI-0939
# Processing patient: LIDC-IDRI-0940
# Processing patient: LIDC-IDRI-0941
# Processing patient: LIDC-IDRI-0942
# Failed to reduce all groups to <= 4 Annotations.
# Some nodules may be close and must be grouped manually.
# Processing patient: LIDC-IDRI-0943
# Processing patient: LIDC-IDRI-0944
# Skipped Nodule ID 2486 due to high std.
# Processing patient: LIDC-IDRI-0945
# Processing patient: LIDC-IDRI-0946
# Processing patient: LIDC-IDRI-0947
# Processing patient: LIDC-IDRI-0949
# Skipped Nodule ID 2496 due to high std.
# Processing patient: LIDC-IDRI-0950
# Processing patient: LIDC-IDRI-0951
# Processing patient: LIDC-IDRI-0953
# Skipped Nodule ID 2506 due to high std.
# Processing patient: LIDC-IDRI-0955
# Processing patient: LIDC-IDRI-0956
# Skipped Nodule ID 2509 due to high std.
# Skipped Nodule ID 2510 due to high std.
# Processing patient: LIDC-IDRI-0957
# Processing patient: LIDC-IDRI-0958
# Processing patient: LIDC-IDRI-0959
# Processing patient: LIDC-IDRI-0961
# Skipped Nodule ID 2517 due to high std.
# Skipped Nodule ID 2523 due to high std.
# Processing patient: LIDC-IDRI-0962
# Processing patient: LIDC-IDRI-0963
# Processing patient: LIDC-IDRI-0965
# Processing patient: LIDC-IDRI-0966
# Processing patient: LIDC-IDRI-0968
# Skipped Nodule ID 2533 due to high std.
# Processing patient: LIDC-IDRI-0969
# Skipped Nodule ID 2536 due to high std.
# Processing patient: LIDC-IDRI-0971
# Processing patient: LIDC-IDRI-0972
# Processing patient: LIDC-IDRI-0973
# Processing patient: LIDC-IDRI-0974
# Processing patient: LIDC-IDRI-0976
# Processing patient: LIDC-IDRI-0977
# Processing patient: LIDC-IDRI-0978
# Processing patient: LIDC-IDRI-0980
# Skipped Nodule ID 2556 due to high std.
# Processing patient: LIDC-IDRI-0981
# Processing patient: LIDC-IDRI-0982
# Processing patient: LIDC-IDRI-0983
# Processing patient: LIDC-IDRI-0984
# Skipped Nodule ID 2564 due to high std.
# Processing patient: LIDC-IDRI-0985
# Processing patient: LIDC-IDRI-0986
# Processing patient: LIDC-IDRI-0987
# Skipped Nodule ID 2571 due to high std.
# Processing patient: LIDC-IDRI-0989
# Processing patient: LIDC-IDRI-0990
# Processing patient: LIDC-IDRI-0991
# Processing patient: LIDC-IDRI-0993
# Processing patient: LIDC-IDRI-0994
# Skipped Nodule ID 2581 due to high std.
# Skipped Nodule ID 2582 due to high std.
# Processing patient: LIDC-IDRI-0996
# Processing patient: LIDC-IDRI-0997
# Processing patient: LIDC-IDRI-0998
# Skipped Nodule ID 2597 due to high std.
# Processing patient: LIDC-IDRI-0999
# Processing patient: LIDC-IDRI-1000
# Skipped Nodule ID 2606 due to high std.
# Skipped Nodule ID 2608 due to high std.
# Skipped Nodule ID 2609 due to high std.
# Processing patient: LIDC-IDRI-1001
# Processing patient: LIDC-IDRI-1002
# Processing patient: LIDC-IDRI-1003
# Skipped Nodule ID 2622 due to high std.
# Processing patient: LIDC-IDRI-1004
# Processing patient: LIDC-IDRI-1005
# Processing patient: LIDC-IDRI-1006
# Processing patient: LIDC-IDRI-1007
# Processing patient: LIDC-IDRI-1008
# Processing patient: LIDC-IDRI-1009
# Processing patient: LIDC-IDRI-1010
# Processing patient: LIDC-IDRI-1011
# Skipped Nodule ID 2647 due to high std.
# Processing patient: LIDC-IDRI-1012
# Skipped Nodule ID 2651 due to high std.
# ✅ Feature extraction complete and CSV saved.
# LIDC-IDRI-0943
# LIDC-IDRI-0944
# Nodule ID 2486
# LIDC-IDRI-0945
# LIDC-IDRI-0946
# LIDC-IDRI-0947
# LIDC-IDRI-0949
# Nodule ID 2496
# LIDC-IDRI-0950
# LIDC-IDRI-0951
# LIDC-IDRI-0953
# Nodule ID 2506
# LIDC-IDRI-0955
# LIDC-IDRI-0956
# Nodule ID 2509
# Nodule ID 2510
# LIDC-IDRI-0957
# LIDC-IDRI-0958
# LIDC-IDRI-0959
# LIDC-IDRI-0961
# Nodule ID 2517
# Nodule ID 2523
# LIDC-IDRI-0962
# LIDC-IDRI-0963
# LIDC-IDRI-0965
# LIDC-IDRI-0966
# LIDC-IDRI-0968
# Nodule ID 2533
# LIDC-IDRI-0969
# Nodule ID 2536
# LIDC-IDRI-0971
# LIDC-IDRI-0972
# LIDC-IDRI-0973
# LIDC-IDRI-0974
# LIDC-IDRI-0976
# LIDC-IDRI-0977
# LIDC-IDRI-0978
# LIDC-IDRI-0980
# Nodule ID 2556
# LIDC-IDRI-0981
# LIDC-IDRI-0982
# LIDC-IDRI-0983
# LIDC-IDRI-0984
# Nodule ID 2564
# LIDC-IDRI-0985
# LIDC-IDRI-0986
# LIDC-IDRI-0987
# Nodule ID 2571
# LIDC-IDRI-0989
# LIDC-IDRI-0990
# LIDC-IDRI-0991
# LIDC-IDRI-0993
# LIDC-IDRI-0994
# Nodule ID 2581
# Nodule ID 2582
# LIDC-IDRI-0996
# LIDC-IDRI-0997
# LIDC-IDRI-0998
# Nodule ID 2597
# LIDC-IDRI-0999
# LIDC-IDRI-1000
# Nodule ID 2606
# Nodule ID 2608
# Nodule ID 2609
# LIDC-IDRI-1001
# LIDC-IDRI-1002
# LIDC-IDRI-1003
# Nodule ID 2622
# LIDC-IDRI-1004
# LIDC-IDRI-1005
# LIDC-IDRI-1006
# LIDC-IDRI-1007
# LIDC-IDRI-1008
# LIDC-IDRI-1009
# LIDC-IDRI-1010
# LIDC-IDRI-1011
# Nodule ID 2647
# LIDC-IDRI-1012
# Nodule ID 2651
